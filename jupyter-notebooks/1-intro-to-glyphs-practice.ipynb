# %% [markdown]
# ## Where to start?
# - The **`bokeh.plotting`** API is a great balance between ease of use and customization

# %% [markdown]
# ### Other Options
# - **`bokeh.models`**
#     - low level plotting with high degree of customization.
# - **`bokeh.charts`**
#     - high level plotting that is very easy to use with less customization.
#     - Easy to generate charts quickly.

# %% [markdown]
# ### bokeh.plotting
#
# * centered around the **`figure()`** method.
#     * basic empty plot with default values.

# %% [markdown]
# ## Base figure
# * Need three items:
#     * figure
#     * output_notebook or output_file
#     * show

# %%
# base figure with no data input
# from bokeh.io import output_notebook, show
# from bokeh.plotting import figure

# create a blank figure named p
# call output_notebook()
# display the blank figure
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c3d79116-7fc7-42d8-b2be-9d5151326d71">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ece10cb1-1710-49f2-aa2b-83976a95b869"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ece10cb1-1710-49f2-aa2b-83976a95b869");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ece10cb1-1710-49f2-aa2b-83976a95b869");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ece10cb1-1710-49f2-aa2b-83976a95b869' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0fc915b8-e884-45bf-9a31-8a572dbcd2ce":{"roots":{"references":[{"attributes":{"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"},"ticker":{"id":"73f167c7-a5e6-4f2f-9f38-0e0e67d47c33","type":"BasicTicker"}},"id":"cc2bbaac-8642-459c-925c-7db80edd622e","type":"Grid"},{"attributes":{"overlay":{"id":"4ffcf081-456c-4d48-b2ac-b1318c7b0cf4","type":"BoxAnnotation"},"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"}},"id":"687a9ff3-4b6f-4f0b-b832-149ec16ad1db","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"}},"id":"a42d3a24-c2e7-4d20-979d-3491df1e51b2","type":"ResetTool"},{"attributes":{"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"}},"id":"88a9a17f-1f81-4dc0-b4d4-59cdf5601a1b","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4ffcf081-456c-4d48-b2ac-b1318c7b0cf4","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"e8896263-23ea-4d7f-bd43-6bf687069155","type":"BasicTickFormatter"},"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"},"ticker":{"id":"73f167c7-a5e6-4f2f-9f38-0e0e67d47c33","type":"BasicTicker"}},"id":"64061029-bc31-41fe-9663-a2ec5ce57c20","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"3d4e5fab-f7be-4e47-913e-f7ad52ca939a","type":"Title"},{"attributes":{},"id":"e8896263-23ea-4d7f-bd43-6bf687069155","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"}},"id":"ca187131-9e90-491d-a83d-27caabe340d3","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"}},"id":"e8a970bc-a8a5-438f-bec5-6a8758155ea1","type":"SaveTool"},{"attributes":{"below":[{"id":"64061029-bc31-41fe-9663-a2ec5ce57c20","type":"LinearAxis"}],"left":[{"id":"4e38270d-70ba-464f-bb04-5ed7d57e3076","type":"LinearAxis"}],"renderers":[{"id":"64061029-bc31-41fe-9663-a2ec5ce57c20","type":"LinearAxis"},{"id":"cc2bbaac-8642-459c-925c-7db80edd622e","type":"Grid"},{"id":"4e38270d-70ba-464f-bb04-5ed7d57e3076","type":"LinearAxis"},{"id":"d93135d1-680f-4cdf-a762-fab9c90eb843","type":"Grid"},{"id":"4ffcf081-456c-4d48-b2ac-b1318c7b0cf4","type":"BoxAnnotation"}],"title":{"id":"3d4e5fab-f7be-4e47-913e-f7ad52ca939a","type":"Title"},"tool_events":{"id":"90891e5e-ab41-4cbf-a6cc-221363bf1e05","type":"ToolEvents"},"toolbar":{"id":"7e3d360b-5805-478b-8bbf-b02033d4bef7","type":"Toolbar"},"x_range":{"id":"02e05f21-e8d6-4e83-b73a-0224e5b44fa6","type":"DataRange1d"},"y_range":{"id":"cde1301a-3951-40e9-b1a2-c0654c2d776f","type":"DataRange1d"}},"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"}},"id":"e0936f21-bcae-4674-9019-1bae73c96a2c","type":"HelpTool"},{"attributes":{},"id":"90891e5e-ab41-4cbf-a6cc-221363bf1e05","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"},"ticker":{"id":"71b3d1ff-8a6f-4de8-97d7-e36b27521529","type":"BasicTicker"}},"id":"d93135d1-680f-4cdf-a762-fab9c90eb843","type":"Grid"},{"attributes":{"callback":null},"id":"cde1301a-3951-40e9-b1a2-c0654c2d776f","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"88a9a17f-1f81-4dc0-b4d4-59cdf5601a1b","type":"PanTool"},{"id":"ca187131-9e90-491d-a83d-27caabe340d3","type":"WheelZoomTool"},{"id":"687a9ff3-4b6f-4f0b-b832-149ec16ad1db","type":"BoxZoomTool"},{"id":"e8a970bc- ...

# %% [markdown]
# <img src="images/blank-figure.png">

# %% [markdown]
# ## Modifying the Figure Size
# * **`plot_height`** & **`plot_width`**

# %%
# Making the chart a bit smaller so we don't take up so much real estate
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure() # modify the plot width and plot height to your liking
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b1b7790c-097a-48ae-9420-f6d3bded885b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="812be256-aacd-45ab-ae58-b966e32ca330"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("812be256-aacd-45ab-ae58-b966e32ca330");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("812be256-aacd-45ab-ae58-b966e32ca330");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '812be256-aacd-45ab-ae58-b966e32ca330' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c9b0bee8-14a8-4417-8a98-8c7e34b3eeec":{"roots":{"references":[{"attributes":{},"id":"71ae5145-9506-457e-af08-9a7adbade074","type":"ToolEvents"},{"attributes":{"plot":{"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"}},"id":"8657266c-31bb-42bc-8333-1e9f0ac3264c","type":"SaveTool"},{"attributes":{"plot":{"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"}},"id":"6229e228-044e-40af-aa37-9947622458a5","type":"ResetTool"},{"attributes":{"plot":null,"text":""},"id":"44582067-e120-4555-8de7-8ae8796509ea","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"801f7afd-ce5c-4753-be41-6c9e4f1d51f5","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"650282df-b031-42ef-9e47-fd2a6486af0a","type":"BasicTickFormatter"},"plot":{"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"},"ticker":{"id":"8aca9ab4-d2c4-44dd-92e4-63a4bd513cfc","type":"BasicTicker"}},"id":"56cf6ca7-b2ab-412b-864c-7da4b59c4262","type":"LinearAxis"},{"attributes":{"plot":{"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"},"ticker":{"id":"51524102-31d1-4659-b1d4-f1d7caa9faa8","type":"BasicTicker"}},"id":"8d2e41d2-1ffd-4572-99e6-a5a387702477","type":"Grid"},{"attributes":{},"id":"8aca9ab4-d2c4-44dd-92e4-63a4bd513cfc","type":"BasicTicker"},{"attributes":{},"id":"650282df-b031-42ef-9e47-fd2a6486af0a","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"}},"id":"e07cc777-cb42-47d7-b04f-12c2be8c000e","type":"PanTool"},{"attributes":{"callback":null},"id":"8ff50ae2-14b4-42ad-8ba5-88e3dc878438","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e07cc777-cb42-47d7-b04f-12c2be8c000e","type":"PanTool"},{"id":"d2bec044-aa44-41ed-88b3-334fbc8e933d","type":"WheelZoomTool"},{"id":"a61892cd-33de-46a0-aaca-07c0db3d4dd9","type":"BoxZoomTool"},{"id":"8657266c-31bb-42bc-8333-1e9f0ac3264c","type":"SaveTool"},{"id":"6229e228-044e-40af-aa37-9947622458a5","type":"ResetTool"},{"id":"329a1282-718f-4340-ab4a-c1b9602b495c","type":"HelpTool"}]},"id":"d9b6375e-efe5-4cd6-9526-35de1d5b5df9","type":"Toolbar"},{"attributes":{"below":[{"id":"70c65167-4227-4767-85db-a46808101c8c","type":"LinearAxis"}],"left":[{"id":"56cf6ca7-b2ab-412b-864c-7da4b59c4262","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"70c65167-4227-4767-85db-a46808101c8c","type":"LinearAxis"},{"id":"8d2e41d2-1ffd-4572-99e6-a5a387702477","type":"Grid"},{"id":"56cf6ca7-b2ab-412b-864c-7da4b59c4262","type":"LinearAxis"},{"id":"79499d69-3db6-428c-9a8b-b29bf50b8dfc","type":"Grid"},{"id":"801f7afd-ce5c-4753-be41-6c9e4f1d51f5","type":"BoxAnnotation"}],"title":{"id":"44582067-e120-4555-8de7-8ae8796509ea","type":"Title"},"tool_events":{"id":"71ae5145-9506-457e-af08-9a7adbade074","type":"ToolEvents"},"toolbar":{"id":"d9b6375e-efe5-4cd6-9526-35de1d5b5df9","type":"Toolbar"},"x_range":{"id":"8ff50ae2-14b4-42ad-8ba5-88e3dc878438","type":"DataRange1d"},"y_range":{"id":"c3477ea3-1b1a-4598-8176-c9bc6ba0d112","type":"DataRange1d"}},"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"88735e42-8ea8-4c57-8c63-c1ccb80347bb","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"},"ticker":{"id":"8aca9ab4-d2c4-44dd-92e4-63a4bd513cfc","type":"BasicTicker"}},"id":"79499d69-3db6-428c-9a8b-b29bf50b8dfc","type":"Grid"},{"attributes":{"plot":{"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"}},"id":"329a1282-718f-4340-ab4a-c ...

# %% [markdown]
# <img src="images/blank-figure-small.png">

# %% [markdown]
# ## Introduction to Glyphs
# Bokeh uses **`"Glyphs"`** which are the base visual structures to overlay on top of any plots.

# %% [markdown]
# - glyphs add visual shapes to the empty **`figure()`** plot

# %% [markdown]
# - glyphs can take on a number of different shapes
#     - i.e. circle, diamond, arc, asterisk, patch, cross, etc.

# %% [markdown]
# - visual shapes can be customized by modifying glyph properties
#     - i.e. color, alpha, size, radius, angle, hover_color, etc.

# %% [markdown]
# ## Adding a Single Circle Glyph
# * Added a circle glyph with **`p.circle()`** to the plot **`p`**
# * defined the x and y coordinate values within **`p.circle()`**
# * **`output_notebook()`** and **`show(p)`**

# %%
# base figure with one circle glyph
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure() # modify plot width and plot height
p.circle() # define x and y coordinates to plot to the blank figure
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e6962577-81c8-47fd-bd51-13a99b047ac6">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="15740c11-77e0-4809-b37c-4056cbd9aea4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("15740c11-77e0-4809-b37c-4056cbd9aea4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("15740c11-77e0-4809-b37c-4056cbd9aea4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '15740c11-77e0-4809-b37c-4056cbd9aea4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6c6116c9-e827-4e6e-b191-d6d522c10120":{"roots":{"references":[{"attributes":{"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"},"ticker":{"id":"9f8a6845-ee3c-4b85-b692-0f61360d3462","type":"BasicTicker"}},"id":"898c4430-87c0-4426-a952-fc0185310752","type":"Grid"},{"attributes":{"formatter":{"id":"742dd8bb-f852-45ee-8786-e4bb4352a182","type":"BasicTickFormatter"},"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"},"ticker":{"id":"9f8a6845-ee3c-4b85-b692-0f61360d3462","type":"BasicTicker"}},"id":"86efc48f-0de1-4f4c-b4d6-6414b95be65e","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"2d04a986-a968-4c1f-a8c5-62f4e48bd073","type":"Title"},{"attributes":{"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"}},"id":"88530ec5-fddb-46cf-8bc4-f12404f37d07","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"value":5},"y":{"value":10}},"id":"a5b2c010-394d-462f-863a-dc97b1e01883","type":"Circle"},{"attributes":{"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"}},"id":"2b574a77-4541-462f-9a39-f461e929ee6a","type":"ResetTool"},{"attributes":{"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"}},"id":"32d8ff32-7c2e-40bc-aafc-e0fea00d9601","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"},"ticker":{"id":"dcaa7f74-3ee2-4eb3-96c6-652e2beafc29","type":"BasicTicker"}},"id":"46ad843c-9068-4481-a5d7-3e809a489be1","type":"Grid"},{"attributes":{"callback":null},"id":"a6474290-865c-4ea3-afee-e5d103e85971","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8e99a925-b358-4bce-bdce-ce55f9f89487","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"}},"id":"a112e6b2-cdad-4799-9853-d49ef60bb6d9","type":"HelpTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"value":5},"y":{"value":10}},"id":"72b0b6aa-28fe-46b7-939b-50084f5a69f2","type":"Circle"},{"attributes":{},"id":"fe1e3f70-db01-4e37-8611-8b03c53b4ce5","type":"BasicTickFormatter"},{"attributes":{},"id":"9f8a6845-ee3c-4b85-b692-0f61360d3462","type":"BasicTicker"},{"attributes":{},"id":"dcaa7f74-3ee2-4eb3-96c6-652e2beafc29","type":"BasicTicker"},{"attributes":{"callback":null,"data":{}},"id":"1970ac80-0393-409d-8ed7-38ae191bad17","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"}},"id":"928e77f2-3202-4d6f-af92-7ac1c0631917","type":"WheelZoomTool"},{"attributes":{},"id":"742dd8bb-f852-45ee-8786-e4bb4352a182","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"32d8ff32-7c2e-40bc-aafc-e0fea00d9601","type":"PanTool"},{"id":"928e77f2-3202-4d6f-af92-7ac1c0631917","type":"WheelZoomTool"},{"id":"519869b4-d098-45e7-a87e-4affa7144d9c","type":"BoxZoomTool"},{"id":"88530ec5-fddb-46cf-8bc4-f12404f37d07","type":"SaveTool"},{"id":"2b574a77-4541-462f-9a39-f461e929ee6a","type":"ResetTool"},{"id":"a112e6b2-cdad-4799-9853-d49ef60bb6d9","type":"HelpTool"}]},"id":"614c039d-2179-496e-83f8-bcaaa6d27fc1","type":"Toolbar"},{"attributes":{},"id":"53e6fd93-c12d-4495-a71d-540243833914","type":"ToolEvents"},{"attributes":{"below":[{"id":"86efc48f-0de1-4f4c-b4d6-6414b95be65e","type":"LinearAxis"}],"left":[{"id":"14db6ce0-ab58-4eb8-be29-0906831c2515","type":"LinearAxis"}],"plot_height":300,"pl ...

# %% [markdown]
# ## Passing Lists of Values

# %%
# base figure with one multiple circle points
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure(plot_width=300, plot_height=300)
# create a circle glpyh and pass a list of values into x and y coordinates to plot
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1c46f60e-0b69-4247-b47a-7e06ba3816df">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="31cb6faf-d452-4b9c-8a91-c6630f4e5fee"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("31cb6faf-d452-4b9c-8a91-c6630f4e5fee");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("31cb6faf-d452-4b9c-8a91-c6630f4e5fee");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '31cb6faf-d452-4b9c-8a91-c6630f4e5fee' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"eedd5ce4-046e-4c85-a837-fbe684a4b382":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7bd8aa7d-abd1-4357-a2bd-c3cee90c0b7e","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"7bd8aa7d-abd1-4357-a2bd-c3cee90c0b7e","type":"BoxAnnotation"},"plot":{"id":"86102801-def2-4c17-b97d-3c204b73a233","subtype":"Figure","type":"Plot"}},"id":"6933e741-220e-420c-b913-5e3da3425cdd","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"86102801-def2-4c17-b97d-3c204b73a233","subtype":"Figure","type":"Plot"}},"id":"5b34fea4-7fbe-48bf-a003-52a664899efe","type":"SaveTool"},{"attributes":{"formatter":{"id":"5a0d901a-f943-49b5-8e5f-5e306e8905ae","type":"BasicTickFormatter"},"plot":{"id":"86102801-def2-4c17-b97d-3c204b73a233","subtype":"Figure","type":"Plot"},"ticker":{"id":"7657e2be-f9d3-4642-b2ea-60ed398ccbc2","type":"BasicTicker"}},"id":"27d447a6-5242-4a5a-9865-ceb7c2b716b9","type":"LinearAxis"},{"attributes":{},"id":"5a0d901a-f943-49b5-8e5f-5e306e8905ae","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"86102801-def2-4c17-b97d-3c204b73a233","subtype":"Figure","type":"Plot"}},"id":"6ed4dc5c-51d7-42b4-8a35-8834c9d6a72a","type":"ResetTool"},{"attributes":{"plot":{"id":"86102801-def2-4c17-b97d-3c204b73a233","subtype":"Figure","type":"Plot"}},"id":"1a07c62c-2303-489d-ac84-57f73397126b","type":"HelpTool"},{"attributes":{},"id":"7657e2be-f9d3-4642-b2ea-60ed398ccbc2","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"86102801-def2-4c17-b97d-3c204b73a233","subtype":"Figure","type":"Plot"},"ticker":{"id":"7657e2be-f9d3-4642-b2ea-60ed398ccbc2","type":"BasicTicker"}},"id":"3825919d-bd77-4931-b777-cfe63fef06d4","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"3099f204-d97c-413a-acf5-2143ff1bb73e","type":"Title"},{"attributes":{"plot":{"id":"86102801-def2-4c17-b97d-3c204b73a233","subtype":"Figure","type":"Plot"}},"id":"29c22abd-a858-4a9e-9795-9eaacf5cb922","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"00b39e9e-f06d-4cc0-9bd6-76819778ea64","type":"LinearAxis"}],"left":[{"id":"27d447a6-5242-4a5a-9865-ceb7c2b716b9","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"00b39e9e-f06d-4cc0-9bd6-76819778ea64","type":"LinearAxis"},{"id":"b84e4d32-d75f-4ae0-9463-0865fdb068e5","type":"Grid"},{"id":"27d447a6-5242-4a5a-9865-ceb7c2b716b9","type":"LinearAxis"},{"id":"3825919d-bd77-4931-b777-cfe63fef06d4","type":"Grid"},{"id":"7bd8aa7d-abd1-4357-a2bd-c3cee90c0b7e","type":"BoxAnnotation"}],"title":{"id":"3099f204-d97c-413a-acf5-2143ff1bb73e","type":"Title"},"tool_events":{"id":"aa066a3c-e99c-46ee-96ef-3ce16ea6fec3","type":"ToolEvents"},"toolbar":{"id":"527c9eef-849f-4d5f-af11-947d61735c31","type":"Toolbar"},"x_range":{"id":"348288d9-1d1d-4559-b5ac-0724ef4c7953","type":"DataRange1d"},"y_range":{"id":"1b3f7491-cb20-4a0b-955a-f23080c7bf6e","type":"DataRange1d"}},"id":"86102801-def2-4c17-b97d-3c204b73a233","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"95b27295-eabb-40f4-a4e0-c09e8f86f96b","type":"BasicTickFormatter"},"plot":{"id":"86102801-def2-4c17-b97d-3c204b73a233","subtype":"Figure","type":"Plot"},"ticker":{"id":"aada98e3-fa43-491f-9ad5-db4d80de2bd1","type":"BasicTicker"}},"id":"00b39e9e-f06d-4cc0-9bd6-76819778ea64","type":"LinearAxis"},{"attributes":{"plot":{"id":"86102801-def2-4c17-b97d-3c204b73a233","subtype":"Figure","type":"Plot"},"ticker":{"id":"aada98e3-fa43-491f-9ad5-db4d80de2bd1","type":"BasicTicker"}},"id":"b84e4d32-d75f-4ae0-9463-0865fdb068e5","type":"Grid"},{"attributes":{},"id":"aada98e3-fa43-491f-9ad5-db4d80de2bd1","type":"BasicTicker"},{"attributes":{"plot":{"id":"86102801-def2-4c17-b97d-3c204b73a233","subtype":"Figure","type":"Plot"}},"id":"ae116f0d- ...

# %% [markdown]
# ## Default Figure Properties
# * Axes automatically fit the data points
# * Figure attributes take on default values that can be modified
# * Glyphs are assigned default values that can be modified

# %% [markdown]
# ## Modifying Glyph Properties
# * Properties can take single fixed values or any valid sequence of values
# * Three common properties we modify are as follows:

# %% [markdown]
# ### size
# - modifies the diameter of the circle you create for **`p.circle()`**

# %% [markdown]
# ### alpha
# - A value from 0 to 1 indicating the level of transparency of the glyph
#     - 0 being fully transparent and 1 being completely non-transparent

# %% [markdown]
# ### color
# - Color value of the glyph.
#     - Can take a Xterm 256 values, Hex values and other color palettes.

# %% [markdown]
# ## Modifying Size, Alpha & Color

# %%
# base figure with one multiple circle points
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure(plot_width=300, plot_height=300)

p.circle(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4]) # modify the size, alpha and color attribute of the points created

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f2388e85-9619-4bb8-b9a0-96a27ada44c9">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="08828d15-457c-487a-9baf-5577051daedd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("08828d15-457c-487a-9baf-5577051daedd");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("08828d15-457c-487a-9baf-5577051daedd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '08828d15-457c-487a-9baf-5577051daedd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8675d6b5-504f-440f-8e22-6f63dd6f0f32":{"roots":{"references":[{"attributes":{"plot":{"id":"8b8b2e6b-270c-4103-84f9-44e6d190abe7","subtype":"Figure","type":"Plot"},"ticker":{"id":"2391b8f8-649c-4416-8606-ba8afd088db7","type":"BasicTicker"}},"id":"d00f1e37-d6a6-4e65-9046-58309cd560a8","type":"Grid"},{"attributes":{"plot":{"id":"8b8b2e6b-270c-4103-84f9-44e6d190abe7","subtype":"Figure","type":"Plot"}},"id":"5c6e4346-6ebb-4367-a0b4-71827964709b","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"8b8b2e6b-270c-4103-84f9-44e6d190abe7","subtype":"Figure","type":"Plot"},"ticker":{"id":"ea51e4f3-4b25-45bc-90fa-9a0e3765aec8","type":"BasicTicker"}},"id":"d47bf36e-9330-4b08-993f-914112e97c42","type":"Grid"},{"attributes":{"callback":null},"id":"e2a1b984-cee5-4032-96da-d4e4f94e6fe4","type":"DataRange1d"},{"attributes":{"data_source":{"id":"dc098632-dd08-4755-bf45-79afc6cc1e23","type":"ColumnDataSource"},"glyph":{"id":"d01ec19b-9c93-461c-9327-5cf8d49adb68","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6bb07ecd-e367-4773-8feb-a5a30b701a78","type":"Circle"},"selection_glyph":null},"id":"367db1cc-80b2-468c-9209-7ca4352fb598","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"36a8dc33-5ede-4d54-970c-bd179b238787","type":"BasicTickFormatter"},"plot":{"id":"8b8b2e6b-270c-4103-84f9-44e6d190abe7","subtype":"Figure","type":"Plot"},"ticker":{"id":"ea51e4f3-4b25-45bc-90fa-9a0e3765aec8","type":"BasicTicker"}},"id":"89b3b87e-e483-4908-b947-7e20b3963373","type":"LinearAxis"},{"attributes":{"plot":{"id":"8b8b2e6b-270c-4103-84f9-44e6d190abe7","subtype":"Figure","type":"Plot"}},"id":"da49547e-1799-4e3d-9703-93009dae70ab","type":"ResetTool"},{"attributes":{},"id":"ea51e4f3-4b25-45bc-90fa-9a0e3765aec8","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"b5eb8635-3dba-4eff-8678-992c34b1f488","type":"Title"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d01ec19b-9c93-461c-9327-5cf8d49adb68","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"dc098632-dd08-4755-bf45-79afc6cc1e23","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"d224397f-6e02-40cf-b1ce-815e12c995ce","type":"DataRange1d"},{"attributes":{"below":[{"id":"fe7d1e3a-d5cd-47e2-ad96-7cbaa5e1dfa2","type":"LinearAxis"}],"left":[{"id":"89b3b87e-e483-4908-b947-7e20b3963373","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"fe7d1e3a-d5cd-47e2-ad96-7cbaa5e1dfa2","type":"LinearAxis"},{"id":"d00f1e37-d6a6-4e65-9046-58309cd560a8","type":"Grid"},{"id":"89b3b87e-e483-4908-b947-7e20b3963373","type":"LinearAxis"},{"id":"d47bf36e-9330-4b08-993f-914112e97c42","type":"Grid"},{"id":"c5bc301c-cad8-4d6d-aa4e-c53ba54dfcf8","type":"BoxAnnotation"},{"id":"367db1cc-80b2-468c-9209-7ca4352fb598","type":"GlyphRenderer"}],"title":{"id":"b5eb8635-3dba-4eff-8678-992c34b1f488","type":"Title"},"tool_events":{"id":"40aa3ace-1eb8-4895-bc69-d8557dab5e7d","type":"ToolEvents"},"toolbar":{"id":"d18b38ce-131e-4242-9e31-bfb87c61885b","type":"Toolbar"},"x_range":{"id":"e2a1b984-cee5-4032-96da-d4e4f94e6fe4","type":"DataRange1d"},"y_range":{"id":"d224397f-6e02-40cf-b1ce-815e12c995ce","type":"DataRange1d"}},"id":"8b8b2e6b-270c-4103-84f9-44e6d190abe7","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"36a8dc33-5ede-4d54-970c-bd179b238787","type":"BasicTickFormatter"},{"attributes":{},"id":"2391b8f8-649c-4416-8606-ba8afd088db7","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5c6e4346-6ebb-4367-a0b4-71827964709b","type":"PanTool"},{"id":"f7e540ea-71b5-4266-b076-2fe482bba4e3","type":"WheelZoomTool"},{"id":"988c5fba-9431-4908-a314-40b04e5a5601","type":"BoxZoomTool"},{"id":"cb218999-44b7-4c80-8a98-72ed51ec8330","type":"SaveTool"},{"id":"da49547e-1799-4e3d-9703-93009dae70ab","type":"ResetTool" ...

# %% [markdown]
# ## Using Lists to Modify Glyph Properties

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create lists for the properties to modify
color_list = [] # create list of colors
size_list = [] # create a list of sizes
alpha_list = [] # create a list of alpha values

# create the plot
p = figure(plot_width=300, plot_height=300)

# add the circle glyph
p.circle(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4]) # set size, alpha and color to the above defined lists

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="23eb4584-ca3b-46ce-8669-c10c07a07785">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="28b10832-a5fe-46fc-ab74-1b67bd8f0f5b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("28b10832-a5fe-46fc-ab74-1b67bd8f0f5b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("28b10832-a5fe-46fc-ab74-1b67bd8f0f5b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '28b10832-a5fe-46fc-ab74-1b67bd8f0f5b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"199f6800-f5e0-474f-9b42-26b47a4d13cf":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"17c699cf-aea3-46c8-8c77-cda85465008d","subtype":"Figure","type":"Plot"},"ticker":{"id":"c6b1ebce-5968-4d64-9b8b-7d7d7143f278","type":"BasicTicker"}},"id":"478f0e5f-ccc2-456b-96d4-d6b7bb2a522f","type":"Grid"},{"attributes":{},"id":"c6b1ebce-5968-4d64-9b8b-7d7d7143f278","type":"BasicTicker"},{"attributes":{"plot":{"id":"17c699cf-aea3-46c8-8c77-cda85465008d","subtype":"Figure","type":"Plot"}},"id":"c8bc8db3-6ccd-4712-88fb-6feeb377ccd0","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4d34a332-93f4-4508-9a90-9ac023dbe0a1","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"774e0cc5-e5cc-455d-be1a-8060dea1e62e","type":"Circle"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4bd443be-d63c-4371-a9fc-226ff21b17f2","type":"Circle"},{"attributes":{"overlay":{"id":"4d34a332-93f4-4508-9a90-9ac023dbe0a1","type":"BoxAnnotation"},"plot":{"id":"17c699cf-aea3-46c8-8c77-cda85465008d","subtype":"Figure","type":"Plot"}},"id":"c50d986a-6c1e-401d-a635-2ff8b6221169","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":""},"id":"b1cf0f7d-44ec-4a6a-87ed-389566a9edaa","type":"Title"},{"attributes":{"plot":{"id":"17c699cf-aea3-46c8-8c77-cda85465008d","subtype":"Figure","type":"Plot"}},"id":"d18b1125-97f1-406f-a546-1d346b0983e3","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"a6ad4791-b2a6-4de6-bf40-563794bf4163","type":"ColumnDataSource"},{"attributes":{},"id":"ee538da0-8763-42a0-bf29-c07459c91e35","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"17c699cf-aea3-46c8-8c77-cda85465008d","subtype":"Figure","type":"Plot"}},"id":"f83b7628-a46b-4138-a2bb-45c158ff6b0f","type":"HelpTool"},{"attributes":{"plot":{"id":"17c699cf-aea3-46c8-8c77-cda85465008d","subtype":"Figure","type":"Plot"}},"id":"a2488d41-4b35-4edd-aa73-b9eff8e676ea","type":"ResetTool"},{"attributes":{},"id":"603767c7-e2b4-4d76-bf01-e609ec0fbe72","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"17c699cf-aea3-46c8-8c77-cda85465008d","subtype":"Figure","type":"Plot"}},"id":"8078d4bc-c4ae-4aff-b6d4-dfa56c0f53ea","type":"SaveTool"},{"attributes":{"formatter":{"id":"ee538da0-8763-42a0-bf29-c07459c91e35","type":"BasicTickFormatter"},"plot":{"id":"17c699cf-aea3-46c8-8c77-cda85465008d","subtype":"Figure","type":"Plot"},"ticker":{"id":"20809cc6-9ebd-41ae-a14c-6e230e8bae39","type":"BasicTicker"}},"id":"7d30a353-e2de-46a4-8cc0-d813e1ed7170","type":"LinearAxis"},{"attributes":{"callback":null},"id":"944a5cc6-d688-4030-a529-9ff2ea5cd7dc","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c8bc8db3-6ccd-4712-88fb-6feeb377ccd0","type":"PanTool"},{"id":"d18b1125-97f1-406f-a546-1d346b0983e3","type":"WheelZoomTool"},{"id":"c50d986a-6c1e-401d-a635-2ff8b6221169","type":"BoxZoomTool"},{"id":"8078d4bc-c4ae-4aff-b6d4-dfa56c0f53ea","type":"SaveTool"},{"id":"a2488d41-4b35-4edd-aa73-b9eff8e676ea","type":"ResetTool"},{"id":"f83b7628-a46b-4138-a2bb-45c158ff6b0f","type":"HelpTool"}]},"id":"0f03be3b-d6ab-4d6b-9ad7-17f4fe780c6e","type":"Toolbar"},{"attributes":{"callback":null},"id":"76912a4f-0900-409d-ba3c-6881c318e845","type":"DataRange1d"},{"attributes":{},"id":"eaa3b0ef-6061-428a-9e68-207f4e79f39e","type":"ToolEvents"},{"attributes":{"below":[{"id":"7d30a353-e2de-46a4-8cc0-d813e1ed7170","type":"LinearAxis"}],"lef ...

# %% [markdown]
# ## Plotting other glyph shapes

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create the plot
p = figure(plot_width=300, plot_height=300)

# add a line glyph

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="32a2e9a8-4d75-4f83-b93e-1bfb4dedb869">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e0feae07-7a73-437f-945e-00ea7d518d54"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e0feae07-7a73-437f-945e-00ea7d518d54");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e0feae07-7a73-437f-945e-00ea7d518d54");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e0feae07-7a73-437f-945e-00ea7d518d54' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"604a5ffe-6b11-4b30-81c2-539eec6c9f0c":{"roots":{"references":[{"attributes":{"plot":{"id":"ef0f2feb-8b20-4b80-a37a-1523350c0b34","subtype":"Figure","type":"Plot"}},"id":"7d7d567a-69cc-4926-8313-16599d78baee","type":"HelpTool"},{"attributes":{"plot":{"id":"ef0f2feb-8b20-4b80-a37a-1523350c0b34","subtype":"Figure","type":"Plot"}},"id":"f18764cf-51b8-4260-a4e9-2c3537d6899b","type":"ResetTool"},{"attributes":{"callback":null},"id":"8c897a24-dedf-4da8-93ea-674765c793d9","type":"DataRange1d"},{"attributes":{},"id":"248e1e9b-1dfd-468f-939f-f2be7bf941fd","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"ef0f2feb-8b20-4b80-a37a-1523350c0b34","subtype":"Figure","type":"Plot"}},"id":"2ff01cdd-d311-4fce-8d13-a711a11d66a4","type":"SaveTool"},{"attributes":{},"id":"63718405-6f8f-4888-84e9-25fdd34f510f","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"248e1e9b-1dfd-468f-939f-f2be7bf941fd","type":"BasicTickFormatter"},"plot":{"id":"ef0f2feb-8b20-4b80-a37a-1523350c0b34","subtype":"Figure","type":"Plot"},"ticker":{"id":"1c850bd4-8aec-4a66-b55d-df2039fa8ba3","type":"BasicTicker"}},"id":"999e7a03-5151-4b37-991f-7f629a4657eb","type":"LinearAxis"},{"attributes":{"formatter":{"id":"63718405-6f8f-4888-84e9-25fdd34f510f","type":"BasicTickFormatter"},"plot":{"id":"ef0f2feb-8b20-4b80-a37a-1523350c0b34","subtype":"Figure","type":"Plot"},"ticker":{"id":"f7692ded-d9ba-4cdf-a488-b8491eb92813","type":"BasicTicker"}},"id":"0c8452c8-e941-4ec7-8fd3-e319b74a5a7c","type":"LinearAxis"},{"attributes":{},"id":"f7692ded-d9ba-4cdf-a488-b8491eb92813","type":"BasicTicker"},{"attributes":{},"id":"1c850bd4-8aec-4a66-b55d-df2039fa8ba3","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"ef0f2feb-8b20-4b80-a37a-1523350c0b34","subtype":"Figure","type":"Plot"},"ticker":{"id":"1c850bd4-8aec-4a66-b55d-df2039fa8ba3","type":"BasicTicker"}},"id":"5085a97c-c37d-4fe8-824a-734dc48082b5","type":"Grid"},{"attributes":{"below":[{"id":"0c8452c8-e941-4ec7-8fd3-e319b74a5a7c","type":"LinearAxis"}],"left":[{"id":"999e7a03-5151-4b37-991f-7f629a4657eb","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"0c8452c8-e941-4ec7-8fd3-e319b74a5a7c","type":"LinearAxis"},{"id":"91837ded-9ed8-420a-9856-390ecd26446e","type":"Grid"},{"id":"999e7a03-5151-4b37-991f-7f629a4657eb","type":"LinearAxis"},{"id":"5085a97c-c37d-4fe8-824a-734dc48082b5","type":"Grid"},{"id":"a1c377e5-e1ef-494f-8655-f809ecf53a9a","type":"BoxAnnotation"}],"title":{"id":"a4a24128-14d6-4544-91c3-2f346368d6bb","type":"Title"},"tool_events":{"id":"3bdca358-2d42-4328-a1e5-5b273181d451","type":"ToolEvents"},"toolbar":{"id":"a5622f72-cfb6-4fa9-a7b3-11037e7dd3a0","type":"Toolbar"},"x_range":{"id":"8c897a24-dedf-4da8-93ea-674765c793d9","type":"DataRange1d"},"y_range":{"id":"376fcf0a-a7e3-4622-9260-893a51a4cc64","type":"DataRange1d"}},"id":"ef0f2feb-8b20-4b80-a37a-1523350c0b34","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"08f3326c-92a6-41c7-a06a-46b2be2b2526","type":"PanTool"},{"id":"3b283530-cfcd-4dad-9fdc-8401479c3127","type":"WheelZoomTool"},{"id":"f5c7ae57-c3ac-407c-9360-d172f2eb31ca","type":"BoxZoomTool"},{"id":"2ff01cdd-d311-4fce-8d13-a711a11d66a4","type":"SaveTool"},{"id":"f18764cf-51b8-4260-a4e9-2c3537d6899b","type":"ResetTool"},{"id":"7d7d567a-69cc-4926-8313-16599d78baee","type":"HelpTool"}]},"id":"a5622f72-cfb6-4fa9-a7b3-11037e7dd3a0","type":"Toolbar"},{"attributes":{},"id":"3bdca358-2d42-4328-a1e5-5b273181d451","type":"ToolEvents"},{"attributes":{"callback":null},"id":"376fcf0a-a7e3-4622-9260-893a51a4cc64","type":"DataRange1d"},{"attributes":{"plot":{"id":"ef0f2feb-8b20-4b80-a37a-1523350c0b34","subtype":"Figure","type":"Plot"}},"id":"3b283530-cfcd-4dad-9fdc-8401479c3127","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"ef0f2feb-8b20-4b80-a37a-1523350c0b34","subtype":"Figure","type":"Plot"}},"id":"08f3326c-92a6-41c7-a06a-46b2be2b2526","type":"PanTool"},{"attribut ...

# %% [markdown]
# ## Plotting Multiple Line Glyphs
# * Use **`p.line()`** twice to create two line glyphs
# * You can also use **`p.multi_line()`** and pass a list of lists as the x & y coordinates to create multiple lines.

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create the plot
p = figure(plot_width=300, plot_height=300)

# add multiple line glyphs

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="666636dc-3335-4fca-aa58-0de573243f02">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d644cf8c-fbf9-4f12-9442-5a8b726cda9c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d644cf8c-fbf9-4f12-9442-5a8b726cda9c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d644cf8c-fbf9-4f12-9442-5a8b726cda9c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd644cf8c-fbf9-4f12-9442-5a8b726cda9c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"795847c2-5e69-41af-857b-97e3123f1e7b":{"roots":{"references":[{"attributes":{},"id":"fddbfafe-9229-4c37-93c7-01cb374165b2","type":"BasicTicker"},{"attributes":{"plot":{"id":"825f3402-b211-4535-94e5-82d282f07cfc","subtype":"Figure","type":"Plot"},"ticker":{"id":"fddbfafe-9229-4c37-93c7-01cb374165b2","type":"BasicTicker"}},"id":"0063ad25-c878-438a-843b-e70013735d5a","type":"Grid"},{"attributes":{"formatter":{"id":"1d0b5cb9-89ed-4e95-a23d-a1d2eebfc78f","type":"BasicTickFormatter"},"plot":{"id":"825f3402-b211-4535-94e5-82d282f07cfc","subtype":"Figure","type":"Plot"},"ticker":{"id":"45a46d06-ac2b-42b0-a331-7bca97488e40","type":"BasicTicker"}},"id":"feed16ac-f94b-4192-b7ee-fe91b146c6b0","type":"LinearAxis"},{"attributes":{},"id":"45a46d06-ac2b-42b0-a331-7bca97488e40","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"825f3402-b211-4535-94e5-82d282f07cfc","subtype":"Figure","type":"Plot"},"ticker":{"id":"45a46d06-ac2b-42b0-a331-7bca97488e40","type":"BasicTicker"}},"id":"c129f00a-fe32-46d3-b4e1-86ac2a228c2e","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"15c7326f-dd8c-47d8-a80d-d8a0f9ed6a54","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"c4df5f6b-1c4b-4db3-b09d-724f85a6784e","type":"DataRange1d"},{"attributes":{"formatter":{"id":"3f7531b3-430e-4c48-be65-49ba5e13b2a6","type":"BasicTickFormatter"},"plot":{"id":"825f3402-b211-4535-94e5-82d282f07cfc","subtype":"Figure","type":"Plot"},"ticker":{"id":"fddbfafe-9229-4c37-93c7-01cb374165b2","type":"BasicTicker"}},"id":"3d9ddaed-ca3d-46d8-a272-2dec88f652a0","type":"LinearAxis"},{"attributes":{},"id":"1d0b5cb9-89ed-4e95-a23d-a1d2eebfc78f","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"825f3402-b211-4535-94e5-82d282f07cfc","subtype":"Figure","type":"Plot"}},"id":"4c608017-1bdb-49c7-9235-604b6e38801d","type":"PanTool"},{"attributes":{"callback":null},"id":"08a69061-5ebd-48ec-b7dd-e2ec5241dbb1","type":"DataRange1d"},{"attributes":{"plot":{"id":"825f3402-b211-4535-94e5-82d282f07cfc","subtype":"Figure","type":"Plot"}},"id":"18714001-fe09-42bb-8d75-3ebb2e80a4c5","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"15c7326f-dd8c-47d8-a80d-d8a0f9ed6a54","type":"BoxAnnotation"},"plot":{"id":"825f3402-b211-4535-94e5-82d282f07cfc","subtype":"Figure","type":"Plot"}},"id":"41453f68-b265-4381-a8b1-2584df610f73","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"825f3402-b211-4535-94e5-82d282f07cfc","subtype":"Figure","type":"Plot"}},"id":"3b9c3a6f-13e4-4ef4-858f-18cb14c59145","type":"SaveTool"},{"attributes":{},"id":"3f7531b3-430e-4c48-be65-49ba5e13b2a6","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"825f3402-b211-4535-94e5-82d282f07cfc","subtype":"Figure","type":"Plot"}},"id":"3994f255-0c98-43da-9dd1-13c7eef481b5","type":"ResetTool"},{"attributes":{"plot":{"id":"825f3402-b211-4535-94e5-82d282f07cfc","subtype":"Figure","type":"Plot"}},"id":"b58cf917-02e7-4980-a83f-bbd0941bfaa6","type":"HelpTool"},{"attributes":{},"id":"18c61d51-ad89-43ae-971e-7bed76a83134","type":"ToolEvents"},{"attributes":{"below":[{"id":"3d9ddaed-ca3d-46d8-a272-2dec88f652a0","type":"LinearAxis"}],"left":[{"id":"feed16ac-f94b-4192-b7ee-fe91b146c6b0","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"3d9ddaed-ca3d-46d8-a272-2dec88f652a0","type":"LinearAxis"},{"id":"0063ad25-c878-438a-843b-e70013735d5a","type":"Grid"},{"id":"feed16ac-f94b-4192-b7ee-fe91b146c6b0","type":"LinearAxis"},{"id":"c129f00a-fe32-46d3-b4e1-86ac2a228c2e","type":"Grid"},{"id":"15c7326f-dd8c-47d8-a80d-d8a0f9ed6a54","type":"BoxAnnotation"}],"title":{"id":"513b54c9-2ae0-46f9-a800-1be0e6b356f6","type":"Title"},"tool_events":{"id":"18c61d51-ad89-43ae-971e-7bed76a83134","type":"To ...

# %% [markdown]
# ## Creating Patch Glyphs
# * patches are single polygonal patch shapes created from a sequence of x and y coordinates
# * The patch glyph will automatically connect the first point and the last point.
# * Use **`patches()`** and pass a list of lists to create multiple patch glyphs in one line.

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create the plot
p = figure(plot_width=300, plot_height=300)

# add multiple patch glyphs

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="78b920e4-833a-4513-91fc-127507df0bb6">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3625b415-e7e7-4b3b-9c75-56d6d5e4cf43"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3625b415-e7e7-4b3b-9c75-56d6d5e4cf43");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3625b415-e7e7-4b3b-9c75-56d6d5e4cf43");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3625b415-e7e7-4b3b-9c75-56d6d5e4cf43' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9b44a578-a44c-4c06-bc13-4ea1bbb1e0a9":{"roots":{"references":[{"attributes":{},"id":"6c7f3001-e492-4a09-8674-870b978e4c2d","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"0a507264-0ff7-4969-ad51-77dc0fc451e2","type":"Title"},{"attributes":{"plot":{"id":"48abfc0f-a834-4c68-8a19-a4194f65a6e7","subtype":"Figure","type":"Plot"}},"id":"7470e231-b2c7-471d-b984-ccf339c36025","type":"HelpTool"},{"attributes":{"overlay":{"id":"c2dd92e8-08ac-438b-9896-a4e000e49479","type":"BoxAnnotation"},"plot":{"id":"48abfc0f-a834-4c68-8a19-a4194f65a6e7","subtype":"Figure","type":"Plot"}},"id":"670682b5-21fc-45f6-8a5e-a77ad837533c","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"48abfc0f-a834-4c68-8a19-a4194f65a6e7","subtype":"Figure","type":"Plot"}},"id":"aa6eee3b-1baf-471c-92eb-f968822deb1a","type":"WheelZoomTool"},{"attributes":{},"id":"9ec565e2-7a4b-4d1c-af57-d430b6641b48","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"48abfc0f-a834-4c68-8a19-a4194f65a6e7","subtype":"Figure","type":"Plot"}},"id":"15d5a2a4-a424-4843-8138-23053c89ff1f","type":"ResetTool"},{"attributes":{"plot":{"id":"48abfc0f-a834-4c68-8a19-a4194f65a6e7","subtype":"Figure","type":"Plot"}},"id":"b856df4a-2624-482a-9edc-902ed3988149","type":"SaveTool"},{"attributes":{"callback":null},"id":"a7dcd88f-51fd-42f6-9ad2-9bbbbbf9970d","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f2abe48a-106e-4445-8dfb-90dffb72e452","type":"PanTool"},{"id":"aa6eee3b-1baf-471c-92eb-f968822deb1a","type":"WheelZoomTool"},{"id":"670682b5-21fc-45f6-8a5e-a77ad837533c","type":"BoxZoomTool"},{"id":"b856df4a-2624-482a-9edc-902ed3988149","type":"SaveTool"},{"id":"15d5a2a4-a424-4843-8138-23053c89ff1f","type":"ResetTool"},{"id":"7470e231-b2c7-471d-b984-ccf339c36025","type":"HelpTool"}]},"id":"b0add122-df46-41d0-9541-d94861554261","type":"Toolbar"},{"attributes":{"formatter":{"id":"9ec565e2-7a4b-4d1c-af57-d430b6641b48","type":"BasicTickFormatter"},"plot":{"id":"48abfc0f-a834-4c68-8a19-a4194f65a6e7","subtype":"Figure","type":"Plot"},"ticker":{"id":"5f56e598-dd79-46fe-a415-1f37cc2a6d36","type":"BasicTicker"}},"id":"d9db524a-2bb2-4a53-9bc3-0df370fa4b75","type":"LinearAxis"},{"attributes":{"callback":null},"id":"1233cb64-ea3f-42f3-b4b4-7c067ea3ffec","type":"DataRange1d"},{"attributes":{},"id":"4086d63c-5d3b-4b57-8c6e-2f52b414dd04","type":"ToolEvents"},{"attributes":{"below":[{"id":"c25ef5ab-387d-423f-9901-df33eee7cbc3","type":"LinearAxis"}],"left":[{"id":"d9db524a-2bb2-4a53-9bc3-0df370fa4b75","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"c25ef5ab-387d-423f-9901-df33eee7cbc3","type":"LinearAxis"},{"id":"a5f19bd8-4366-4625-9a65-4de895e1deb6","type":"Grid"},{"id":"d9db524a-2bb2-4a53-9bc3-0df370fa4b75","type":"LinearAxis"},{"id":"209d9477-c550-44f9-8938-11a74aa48daf","type":"Grid"},{"id":"c2dd92e8-08ac-438b-9896-a4e000e49479","type":"BoxAnnotation"}],"title":{"id":"0a507264-0ff7-4969-ad51-77dc0fc451e2","type":"Title"},"tool_events":{"id":"4086d63c-5d3b-4b57-8c6e-2f52b414dd04","type":"ToolEvents"},"toolbar":{"id":"b0add122-df46-41d0-9541-d94861554261","type":"Toolbar"},"x_range":{"id":"1233cb64-ea3f-42f3-b4b4-7c067ea3ffec","type":"DataRange1d"},"y_range":{"id":"a7dcd88f-51fd-42f6-9ad2-9bbbbbf9970d","type":"DataRange1d"}},"id":"48abfc0f-a834-4c68-8a19-a4194f65a6e7","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"6c7f3001-e492-4a09-8674-870b978e4c2d","type":"BasicTickFormatter"},"plot":{"id":"48abfc0f-a834-4c68-8a19-a4194f65a6e7","subtype":"Figure","type":"Plot"},"ticker":{"id":"b4372085-990d-4dc6-a4c0-55249c5b2133","type":"BasicTicker"}},"id":"c25ef5ab-387d-423f-9901-df33eee7cbc3","type":"LinearAxis"},{"attributes":{"plot":{"id":"48abfc0f-a834-4c68-8a19-a4194f65a6e7","subtype":"Figure","type":"Plot"},"ticker":{"id":"b4372085-990d-4dc6-a4c0-55249c5b2133","type":"BasicTicker"}},"id":"a5f19bd8-4366-4625-9a65-4de895e1deb6","type":"Grid"},{"attribu ...
