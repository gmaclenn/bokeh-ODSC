# 19        Closed                  Case Closed Case Invalid No eform
# 20        Closed  Case Closed Case Noted looks like duplicate  r...
# 21        Closed  Case Closed Case Resolved We have checked all ...
# 22        Closed  Case Closed. Closed date : 2015-05-08 14:57:18...
# 23        Closed  Case Closed. Closed date : 2016-02-03 12:46:18...
# 24        Closed  Case Closed. Closed date : 2016-05-04 13:16:43...
# 25        Closed  Case Closed Case Resolved tree debris that was...
# 26        Closed                          Case Closed Case Resolved
# 27        Closed         Case Closed Case Resolved pick up dead cat
# 28        Closed  Case Closed. Closed date : 2016-06-10 11:49:09...
# 29        Closed                             Case Closed Case Noted
# ...          ...                                                ...
# 1970      Closed  Case Closed. Closed date : 2016-02-13 15:58:37...
# 1971      Closed  Case Closed Case Resolved cart 513-0005534 del...
# 1972        Open                                                NaN
# 1973      Closed  Case Closed Case Resolved Case resolved  infor...
# 1974      Closed  Case Closed Case Resolved Stickers placed at l...
# 1975      Closed  Case Closed. Closed date : 2016-11-28 16:31:40...
# 1976      Closed  Case Closed. Closed date : 2015-06-18 12:41:56...
# 1977      Closed                          Case Closed Case Resolved
# 1978      Closed  Case Closed. Closed date : 2016-05-16 06:31:34...
# 1979      Closed         Case Closed Case Resolved grafitti removed
# 1980      Closed  Case Closed Case Noted  Thank yo for your requ...
# 1981      Closed  Case Closed. Closed date : 2015-08-24 07:35:52...
# 1982      Closed  Case Closed. Closed date : 2016-04-01 08:06:27...
# 1983      Closed  Case Closed Case Noted sent inspection and fou...
# 1984      Closed                   Case Closed Bulk Item Automation
# 1985      Closed  Case Closed Case Resolved Case resolved. Stick...
# 1986      Closed  Case Closed Case Noted went to location did no...
# 1987      Closed  Case Closed Case Resolved Marked completed at ...
# 1988      Closed                             Case Closed Case Noted
# 1989        Open                                                NaN
# 1990      Closed  Case Closed. Closed date : 2016-03-06 15:04:28...
# 1991      Closed  Case Closed. Closed date : 2016-10-02 11:11:49...
# 1992      Closed                          Case Closed Case Resolved
# 1993      Closed  Case Closed. Closed date : 2015-06-02 10:13:46...
# 1994      Closed  Case Closed Case Resolved Two vehicles tickete...
# 1995      Closed  Case Closed. Closed date : 2016-04-11 16:24:36...
# 1996      Closed                          Case Closed Case Resolved
# 1997      Closed  Case Closed Case Resolved deliver recycle stic...
# 1998      Closed  Case Closed. Closed date : 2016-11-08 12:09:58...
# 1999      Closed  Case Closed. Closed date : 2016-09-14 11:48:18...
#
#                                       CASE_TITLE  \
# 0                                    Sign Repair
# 1                               outage///printed
# 2                               Metrolist Survey
# 3                       Request for Snow Plowing
# 4                Sidewalk Repair/Concrete/Dist 6
# 5                   Graffiti: Ward 22  2202  RIP
# 6                   Requests for Street Cleaning
# 7                  Missed Recycling: District 03
# 8                           Street Light Outages
# 9                           Street Light Outages
# 10                                 CE Collection
# 11                              Metrolist Survey
# 12                Heat - Excessive  Insufficient
# 13                           Parking Enforcement
# 14                        Animal Generic Request
# 15                  Requests for Street Cleaning
# 16                           Parking Enforcement
# 17                              Graffiti Removal
# 18                   Schedule a Bulk Item Pickup
# 19                   Schedule a Bulk Item Pickup
# 20                          Street Light Outages
# 21                         Traffic Signal Repair
# 22                   Sidewalk Repair (Make Safe)
# 23                         Illegal Rooming House
# 24                              Graffiti Removal
# 25                              Tree Emergencies
# 26                   Schedule a Bulk Item Pickup
# 27                           Pick up Dead Animal
# 28                           Empty Litter Basket
# 29                              Other: Complaint
# ...                                          ...
# 1970                         Empty Litter Basket
# 1971                  Request for Recycling Cart
# 1972                 Building Inspection Request
# 1973                                    Call Log
# 1974                             Sticker Request
# 1975                   Schedule Bulk Item Pickup
# 1976  Street Light Outages //SENT TO MAVERICK //
# 1977                    Request for Snow Plowing
# 1978            Sidewalk Repair/Concrete/ Dist 7
# 1979                                PWD Graffiti
# 1980                    Request for Snow Plowing
# 1981                 Building Inspection Request
# 1982                         Parking Enforcement
# 1983                Requests for Street Cleaning
# 1984                 Schedule a Bulk Item Pickup
# 1985                             Sticker Request
# 1986                         Pick up Dead Animal
# 1987                Requests for Street Cleaning
# 1988                             Sidewalk Repair
# 1989                      Animal Generic Request
# 1990                   Traffic Signal Inspection
# 1991         Improper Storage of Trash (Barrels)
# 1992                       Traffic Signal Repair
# 1993                   Pothole Repair (Internal)
# 1994                         Parking Enforcement
# 1995                                    Call Log
# 1996                  Request for Pothole Repair
# 1997                             Sticker Request
# 1998                  Request for Pothole Repair
# 1999                          Abandoned Vehicles
#
#                                 SUBJECT         ...          precinct  \
# 0     Transportation - Traffic Division         ...              0308
# 1               Public Works Department         ...              1404
# 2                          Civil Rights         ...               NaN
# 3               Public Works Department         ...              1502
# 4               Public Works Department         ...              2009
# 5                   Property Management         ...              2202
# 6               Public Works Department         ...              0107
# 7               Public Works Department         ...              1504
# 8               Public Works Department         ...              0204
# 9               Public Works Department         ...              1207
# 10              Public Works Department         ...              0306
# 11                         Civil Rights         ...               NaN
# 12                Inspectional Services         ...              1409
# 13    Transportation - Traffic Division         ...              0903
# 14                       Animal Control         ...              0308
# 15              Public Works Department         ...              1820
# 16    Transportation - Traffic Division         ...              2003
# 17                  Property Management         ...              1907
# 18              Public Works Department         ...              1819
# 19              Public Works Department         ...              1409
# 20              Public Works Department         ...              1201
# 21    Transportation - Traffic Division         ...              0501
# 22              Public Works Department         ...              2211
# 23                Inspectional Services         ...              1301
# 24                  Property Management         ...              0308
# 25        Parks & Recreation Department         ...              1005
# 26              Public Works Department         ...              0806
# 27              Public Works Department         ...              1103
# 28              Public Works Department         ...              2202
# 29              Mayor's 24 Hour Hotline         ...               NaN
# ...                                 ...         ...               ...
# 1970            Public Works Department         ...              0401
# 1971            Public Works Department         ...              1304
# 1972              Inspectional Services         ...              1812
# 1973              Disability Department         ...               NaN
# 1974            Public Works Department         ...              0804
# 1975            Public Works Department         ...              2012
# 1976            Public Works Department         ...              1612
# 1977            Public Works Department         ...              0509
# 1978            Public Works Department         ...              1602
# 1979            Public Works Department         ...              1109
# 1980            Public Works Department         ...              1204
# 1981              Inspectional Services         ...              0203
# 1982  Transportation - Traffic Division         ...               NaN
# 1983            Public Works Department         ...              0506
# 1984            Public Works Department         ...              0803
# 1985            Public Works Department         ...              1903
# 1986            Public Works Department         ...              0905
# 1987            Public Works Department         ...              1606
# 1988            Public Works Department         ...              1607
# 1989                     Animal Control         ...              1004
# 1990  Transportation - Traffic Division         ...              1105
# 1991            Public Works Department         ...              0708
# 1992  Transportation - Traffic Division         ...              0904
# 1993            Public Works Department         ...              2013
# 1994  Transportation - Traffic Division         ...              1907
# 1995              Disability Department         ...               NaN
# 1996            Public Works Department         ...              2112
# 1997            Public Works Department         ...              1912
# 1998            Public Works Department         ...              1807
# 1999  Transportation - Traffic Division         ...              0807
#
#      land_usage                             LOCATION_STREET_NAME  \
# 0           NaN           INTERSECTION Devonshire St & Summer St
# 1            RL                                     0 Geneva Ave
# 2           NaN                                              NaN
# 3            R3                                    52 Everton St
# 4            R1                                     19 Brahms St
# 5             C                                       40 Rugg Rd
# 6            R1                                    166 Brooks St
# 7            R3                                      27 Hecla St
# 8            CM                           191-193 Bunker Hill St
# 9             A                                172-176 Seaver St
# 10            E                                  1 City Hall Plz
# 11          NaN                                              NaN
# 12            A                                      11 Abbot St
# 13           R1                                     38 Sussex St
# 14            I                              107-129 Kingston St
# 15          NaN          INTERSECTION W Milton St & Readville St
# 16           R2                                    23 Willers St
# 17           CM                                  11 Weld Hill St
# 18           R1                                       19 Joan Rd
# 19          NaN                            83 Fermoy Heights Ave
# 20           R4                                    132 Warren St
# 21          NaN            INTERSECTION Arlington St & Herald St
# 22           R1                                  26-28 Newton St
# 23           RC                            168-170 Blue Hill Ave
# 24            C                                   20 Kneeland St
# 25           R3                                      73 Heath St
# 26            E                               115 Southampton St
# 27           R1                                 167 Harrishof St
# 28            C                                   214 Lincoln St
# 29          NaN                                              NaN
# ...         ...                                              ...
# 1970         R2                                  24 Clarendon St
# 1971         R1                                   51 Hartford St
# 1972        NaN                                    3-5 Summer St
# 1973        NaN                                              NaN
# 1974         R3                                1111 Harrison Ave
# 1975         R1                                        4 Kirk St
# 1976          C                                     41 Hallet St
# 1977         CM                             302 Commonwealth Ave
# 1978         R2                                  23 Neponset Ave
# 1979        NaN               INTERSECTION Mcbride St & South St
# 1980          A                                     15 Alaska St
# 1981         CM                               22 Mount Vernon St
# 1982        NaN                                      1 Hadley St
# 1983        NaN  INTERSECTION Berkeley St & Public Alley No. 420
# 1984          A                            28 Mount Pleasant Ave
# 1985         CD                                    11 Barbara St
# 1986         CM                                 19-21 Norfolk St
# 1987         R1                                   96 Wrentham St
# 1988         R2                                   56 Boutwell St
# 1989         CM                                     386 Riverway
# 1990        NaN        INTERSECTION Beethoven St & Washington St
# 1991         R3                               635 Dorchester Ave
# 1992        NaN            INTERSECTION Prentiss St & Tremont St
# 1993        NaN             INTERSECTION Dent St & Westmount Ave
# 1994        NaN               INTERSECTION Varney St & Wenham St
# 1995        NaN                                              NaN
# 1996        NaN                                 60 Washington St
# 1997         R1                                   47 Waterman Rd
# 1998        NaN         INTERSECTION Canterbury St & Cummins Hwy
# 1999          E                                     8 Dunmore St
#
#      LOCATION_ZIPCODE Property_Type Property_ID LATITUDE  LONGITUDE  \
# 0                 NaN  Intersection      4053.0  42.3537   -71.0580
# 1              2121.0       Address     63245.0  42.3594   -71.0587
# 2                 NaN           NaN         NaN  42.3594   -71.0587
# 3              2121.0       Address     55313.0  42.3042   -71.0716
# 1999           2119.0       Address    164593.0  42.3261   -71.0749
#
#                     Source    Geocoded_Location
# 0         Constituent Call   (42.3537, -71.058)
# 1       Employee Generated               (0, 0)
# 2       Employee Generated               (0, 0)
# 3         Constituent Call  (42.3042, -71.0716)
# 4          City Worker App  (42.2777, -71.1397)
# 5             Self Service  (42.3558, -71.1356)
# 6       Employee Generated  (42.3795, -71.0357)
# 7         Constituent Call     (42.307, -71.06)
# 8         Constituent Call   (42.379, -71.0616)
# 9     Citizens Connect App  (42.3086, -71.0897)
# 10         City Worker App  (42.3603, -71.0583)
# 11      Employee Generated               (0, 0)
# 12            Self Service  (42.2972, -71.0865)
# 13    Citizens Connect App   (42.336, -71.0839)
# 14        Constituent Call  (42.3521, -71.0596)
# 15         City Worker App  (42.2382, -71.1357)
# 16        Constituent Call  (42.2595, -71.1503)
# 17    Citizens Connect App  (42.2986, -71.1137)
# 18        Constituent Call  (42.2536, -71.1435)
# 19        Constituent Call   (42.296, -71.0904)
# 20      Maximo Integration  (42.3261, -71.0831)
# 21            Self Service  (42.3475, -71.0686)
# 22        Constituent Call  (42.3565, -71.1638)
# 23        Constituent Call   (42.319, -71.0776)
# 24    Citizens Connect App  (42.3509, -71.0621)
# 25        Constituent Call  (42.3265, -71.1007)
# 26      Employee Generated  (42.3317, -71.0695)
# 27        Constituent Call   (42.3182, -71.092)
# 28    Citizens Connect App  (42.3578, -71.1371)
# 29        Constituent Call               (0, 0)
# ...                    ...                  ...
# 1970  Citizens Connect App   (42.345, -71.0726)
# 1971       City Worker App  (42.3149, -71.0733)
# 1972      Constituent Call  (42.2564, -71.1255)
# 1973      Constituent Call               (0, 0)
# 1974          Self Service  (42.3309, -71.0814)
# 1975          Self Service   (42.288, -71.1592)
# 1976  Citizens Connect App  (42.2827, -71.0474)
# 1977      Constituent Call  (42.3495, -71.0853)
# 1978       City Worker App  (42.2965, -71.0557)
# 1979       City Worker App  (42.3059, -71.1148)
# 1980      Constituent Call  (42.3211, -71.0791)
# 1981      Constituent Call  (42.3753, -71.0586)
# 1982  Citizens Connect App  (42.3827, -71.0798)
# 1983      Constituent Call  (42.3544, -71.0746)
# 1984    Employee Generated  (42.3274, -71.0792)
# 1985          Self Service  (42.3212, -71.1114)
# 1986      Constituent Call   (42.3286, -71.091)
# 1987       City Worker App  (42.2885, -71.0588)
# 1988       City Worker App  (42.2908, -71.0526)
# 1989      Constituent Call  (42.3327, -71.1119)
# 1990  Citizens Connect App               (0, 0)
# 1991  Citizens Connect App  (42.3281, -71.0572)
# 1992      Constituent Call  (42.3329, -71.0924)
# 1993    Employee Generated   (42.282, -71.1618)
# 1994      Constituent Call  (42.2959, -71.1152)
# 1995      Constituent Call               (0, 0)
# 1996      Constituent Call  (42.3433, -71.1424)
# 1997          Self Service  (42.2875, -71.1123)
# 1998  Citizens Connect App               (0, 0)
# 1999      Constituent Call  (42.3261, -71.0749)
#
# [2000 rows x 34 columns]

# %% [markdown]
# ### Creating a basic Histogram
# Uses high level plotting features. The bokeh.charts modules.

# %%
## CREATING A BASIC HISTOGRAM WITH BOKEH

from bokeh.charts import Histogram, output_file, show
from bokeh.sampledata.iris import flowers as df

p = Histogram(df, 'petal_length', bins=10, color='species')

output_file('histogram.html')

show(p)

# %% [markdown]
# ### Creating a basic Scatter Plot

# %%
from bokeh.charts import Scatter
from bokeh.sampledata.iris import flowers as df

p = Scatter(df, x='petal_length', y='sepal_length', color='species')

output_file('basic_scatter.html')

show(p)

# %% [markdown]
# ## Using the current document (curdoc)
# Wont run in a jupyter notebook. Need to run `bokeh serve --show name_of_python_file.py`

# %%
# Perform necessary imports
from bokeh.io import curdoc
from bokeh.plotting import figure

# Create a new plot: plot
plot = figure()

# Add a line to the plot
plot.line(x=[1,2,3,4,5], y=[2,5,4,6,7])

# Add the plot to the current document
curdoc().add_root(plot)

# %% [markdown]
# # `NEED TO USE BOKEH SERVE FOR THE FOLLOWING`
# ## Interactive Elements

# %% [markdown]
# ### Building the plot

# %%
# Perform necessary imports
from bokeh.io import curdoc
from bokeh.plotting import figure

# Create a new plot: plot
plot = figure()

# Add a line to the plot
plot.line(x=[1,2,3,4,5], y=[2,5,4,6,7])

# Add the plot to the current document
curdoc().add_root(plot)

# %% [markdown]
# ### Combining Plots into layouts

# %%
# Perform the necessary imports
from bokeh.io import curdoc
from bokeh.layouts import widgetbox
from bokeh.models import Slider

# Create a slider: slider
slider = Slider(title='my slider', start=0, end=10, step=0.1, value=2)

# Create a widgetbox layout: layout
layout = widgetbox(slider)

# Add the layout to the current document
curdoc().add_root(layout)

# %%
# Create ColumnDataSource: source
source = ColumnDataSource(data={'x':x, 'y':y})

# Add a line to the plot
plot.line('x', 'y', source=source)

# Create a column layout: layout
layout = column(widgetbox(slider), plot)

# Add the layout to the current document
curdoc().add_root(layout)

# %%
# Define a callback function: callback
def callback(attr, old, new):

    # Read the current value of the slider: scale
    scale = slider.value

    # Compute the updated y using np.sin(scale/x): new_y
    new_y = np.sin(scale/x)

    # Update source with the new data values
    source.data = {'x': x, 'y': new_y}

# Attach the callback to the 'value' property of slider
slider.on_change('value', callback)

# Create layout and add to current document
layout = column(widgetbox(slider), plot)
curdoc().add_root(layout)

# %% [markdown]
# ## Buttons

# %%
# Example code on how to create a button
from bokeh.models import Button

button = Button(label='Export to CSV')

def export_to_csv():
    # Export the file to CSV
    
button.on_click(export_to_csv)

# %%
## WORKING WITH COLOR MAPPING

#Import CategoricalColorMapper from bokeh.models
from bokeh.models import CategoricalColorMapper

# Convert df to a ColumnDataSource: source
source = ColumnDataSource(df)

# Make a CategoricalColorMapper object: color_mapper
color_mapper = CategoricalColorMapper(factors=['Europe', 'Asia', 'US'],
                                      palette=['red', 'green', 'blue'])

# Add a circle glyph to the figure p
p.circle('weight', 'mpg', source=source,
            color=dict(field='origin', transform=color_mapper),
            legend='origin')

# Specify the name of the output file and show the result
output_file('colormap.html')
show(p)

# %%
sr.Source.unique()
# Out:
# array(['City Worker App', 'Citizens Connect App'], dtype=object)

# %%
from bokeh.models import CategoricalColorMapper

source = ColumnDataSource(sr)

# Make a CategoricalColorMapper object: color_mapper
color_mapper = CategoricalColorMapper(factors=['City Worker App', 'Citizens Connect App'],
                                      palette=['red', 'green'])

p = Bar(sr['Source'].value_counts(), legend='top_right', color=color_mapper)
output_file('source.html')
show(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-159-41b32bef3d0b> in <module>()
#       7                                       palette=['red', 'green'])
#       8
# ----> 9 p = Bar(sr['Source'].value_counts(), legend='top_right', color=color_mapper)
#      10 output_file('source.html')
#      11 show(p)
#
# /usr/local/lib/python3.6/site-packages/bokeh/charts/builders/bar_builder.py in Bar(data, label, values, color, stack, group, agg, xscale, yscale, xgrid, ygrid, continuous_range, **kw)
#     319     kw['y_range'] = y_range
#     320
# --> 321     chart = create_and_build(BarBuilder, data, **kw)
#     322
#     323     # hide x labels if there is a single value, implying stacking only
#
# /usr/local/lib/python3.6/site-packages/bokeh/charts/builder.py in create_and_build(builder_class, *data, **kws)
#      54     chart_kws = {k: v for k, v in kws.items() if k not in builder_props}
#      55     chart = Chart(**chart_kws)
# ---> 56     chart.add_builder(builder)
#      57     chart.start_plot()
#      58
#
# /usr/local/lib/python3.6/site-packages/bokeh/charts/chart.py in add_builder(self, builder)
#     151     def add_builder(self, builder):
#     152         self._builders.append(builder)
# --> 153         builder.create(self)
#     154
#     155     def add_ranges(self, dim, range):
#
# /usr/local/lib/python3.6/site-packages/bokeh/charts/builder.py in create(self, chart)
#     510         if chart is None:
#     511             chart = Chart()
# --> 512         chart.add_renderers(self, renderers)
#     513
#     514         # handle ranges after renders, since ranges depend on aggregations
#
# /usr/local/lib/python3.6/site-packages/bokeh/charts/chart.py in add_renderers(self, builder, renderers)
#     146
#     147     def add_renderers(self, builder, renderers):
# --> 148         self.renderers += renderers
#     149         self._renderer_map.extend({ r._id : builder for r in renderers })
#     150
#
# /usr/local/lib/python3.6/site-packages/bokeh/core/property/containers.py in wrapper(self, *args, **kwargs)
#      74     def wrapper(self, *args, **kwargs):
#      75         old = self._saved_copy()
# ---> 76         result = func(self, *args, **kwargs)
#      77         self._notify_owners(old)
#      78         return result
#
# /usr/local/lib/python3.6/site-packages/bokeh/core/property/containers.py in __iadd__(self, y)
#     170     @notify_owner
#     171     def __iadd__(self, y):
# --> 172         return super(PropertyValueList, self).__iadd__(y)
#     173
#     174     # x *= y
#
# /usr/local/lib/python3.6/site-packages/bokeh/charts/builders/bar_builder.py in yield_renderers(self)
#     212             bg = self.glyph(label=group.label,
#     213                             x_label=self._get_label(group['label']),
# --> 214                             values=group.data[self.values.selection].values,
#     215                             agg=stats[self.agg](),
#     216                             width=self.bar_width,
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3550                         loc = indexer.item()
#    3551                     else:
# -> 3552                         raise ValueError("cannot label index with a null key")
#    3553
#    3554             return self.iget(loc, fastpath=fastpath)
#
# ValueError: cannot label index with a null key

# %%
lat = service_requests['LATITUDE']
lon = service_requests['LONGITUDE']
type(lat)
# Out:
# pandas.core.series.Series

# %%
from bokeh.io import output_file, show
from bokeh.models import GeoJSONDataSource
from bokeh.plotting import figure
from bokeh.sampledata.sample_geojson import geojson

geo_source = GeoJSONDataSource(geojson=geojson)

p = figure()
p.circle(x='x', y='y', alpha=0.9, source=geo_source)
output_file("geojson.html")
show(p)

# %%
from bokeh.io import output_file, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)

map_options = GMapOptions(lat=42.3601, lng=-71.0589, map_type="roadmap", zoom=11)

plot = GMapPlot(
    x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options,
)
plot.title.text = "Boston 311 Requests"

# For GMaps to function, Google requires you obtain and enable an API key:
#
#     https://developers.google.com/maps/documentation/javascript/get-api-key
#
# Replace the value below with your personal API key:
plot.api_key = "AIzaSyCdTbc-8f6EL4suuX8NX-526HR6oHm8q3c"

source = ColumnDataSource(
    data=dict(
        lat=service_requests['LATITUDE'],
        lon=service_requests['LONGITUDE'],
        src=service_requests['Source'],
    )
)

tooltips = [('Source', '@src')]

circle = Circle(x="lon", y="lat", size=3, fill_color="red", fill_alpha=0.4, line_color=None)
plot.add_glyph(source, circle)


plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool(), HoverTool())
output_file("gmap_plot.html")
show(plot)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-150-076c2ab47385> in <module>()
#      28 tooltips = [('Source', '@src')]
#      29
# ---> 30 circle = Circle(x="lon", y="lat", size=3, fill_color="red", fill_alpha=0.4, line_color=None, tooltip=tooltips)
#      31 plot.add_glyph(source, circle)
#      32
#
# /usr/local/lib/python3.6/site-packages/bokeh/model.py in __init__(self, **kwargs)
#     224         self._id = kwargs.pop("id", make_id())
#     225         self._document = None
# --> 226         super(Model, self).__init__(**kwargs)
#     227         default_theme.apply_to_model(self)
#     228
#
# /usr/local/lib/python3.6/site-packages/bokeh/core/has_props.py in __init__(self, **properties)
#     239
#     240         for name, value in properties.items():
# --> 241             setattr(self, name, value)
#     242
#     243     def __setattr__(self, name, value):
#
# /usr/local/lib/python3.6/site-packages/bokeh/core/has_props.py in __setattr__(self, name, value)
#     275
#     276             raise AttributeError("unexpected attribute '%s' to %s, %s attributes are %s" %
# --> 277                 (name, self.__class__.__name__, text, nice_join(matches)))
#     278
#     279     def __str__(self):
#
# AttributeError: unexpected attribute 'tooltip' to Circle, possible attributes are angle, angle_units, fill_alpha, fill_color, js_event_callbacks, js_property_callbacks, line_alpha, line_cap, line_color, line_dash, line_dash_offset, line_join, line_width, name, radius, radius_dimension, radius_units, size, subscribed_events, tags, x or y

# %%
cs = sr['CASE_STATUS'].value_counts()

# %%
from bokeh.plotting import figure, show, output_file
from bokeh.charts import Bar

p = figure(plot_width=300, plot_height=300)

p.circle([1, 2, 3], [1, 2, 3], fill_color='yellow')

output_file("basic_circles.html")

show(p)

# %%
a = pd.to_datetime(service_requests['OPEN_DT'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/tslib.pyx in pandas.tslib.array_to_datetime (pandas/tslib.c:44368)()
#
# pandas/src/datetime.pxd in datetime._string_to_dts (pandas/tslib.c:95676)()
#
# ValueError: Error parsing datetime string "04/25/2014 03:55:32 PM" at position 2
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-d8816930cb61> in <module>()
# ----> 1 a = pd.to_datetime(service_requests['OPEN_DT'])
#
# /usr/local/lib/python3.6/site-packages/pandas/util/decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# /usr/local/lib/python3.6/site-packages/pandas/tseries/tools.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, coerce, unit, infer_datetime_format)
#     419     elif isinstance(arg, ABCSeries):
#     420         from pandas import Series
# --> 421         values = _convert_listlike(arg._values, False, format)
#     422         return Series(values, index=arg.index, name=arg.name)
#     423     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# /usr/local/lib/python3.6/site-packages/pandas/tseries/tools.py in _convert_listlike(arg, box, format, name, tz)
#     399                     dayfirst=dayfirst,
#     400                     yearfirst=yearfirst,
# --> 401                     require_iso8601=require_iso8601
#     402                 )
#     403
#
# pandas/tslib.pyx in pandas.tslib.array_to_datetime (pandas/tslib.c:46691)()
#
# pandas/tslib.pyx in pandas.tslib.array_to_datetime (pandas/tslib.c:44777)()
#
# pandas/tslib.pyx in pandas.tslib.parse_datetime_string (pandas/tslib.c:35434)()
#
# /usr/local/lib/python3.6/site-packages/dateutil/parser.py in parse(timestr, parserinfo, **kwargs)
#    1068
#    1069
# -> 1070 def parse(timestr, parserinfo=None, **kwargs):
#    1071     """
#    1072
#
# KeyboardInterrupt:

# %%
output_file('case_status.html')

p = Bar(service_requests['CASE_STATUS'].value_counts(), legend='top_right', tools='hover', color='Source')

show(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-cdd41d733bc4> in <module>()
#       1 output_file('case_status.html')
#       2
# ----> 3 p = Bar(service_requests['CASE_STATUS'].value_counts(), legend='top_right', tools='hover', color='Source')
#       4
#       5 show(p)
#
# /usr/local/lib/python3.6/site-packages/bokeh/charts/builders/bar_builder.py in Bar(data, label, values, color, stack, group, agg, xscale, yscale, xgrid, ygrid, continuous_range, **kw)
#     319     kw['y_range'] = y_range
#     320
# --> 321     chart = create_and_build(BarBuilder, data, **kw)
#     322
#     323     # hide x labels if there is a single value, implying stacking only
#
# /usr/local/lib/python3.6/site-packages/bokeh/charts/builder.py in create_and_build(builder_class, *data, **kws)
#      54     chart_kws = {k: v for k, v in kws.items() if k not in builder_props}
#      55     chart = Chart(**chart_kws)
# ---> 56     chart.add_builder(builder)
#      57     chart.start_plot()
#      58
#
# /usr/local/lib/python3.6/site-packages/bokeh/charts/chart.py in add_builder(self, builder)
#     151     def add_builder(self, builder):
#     152         self._builders.append(builder)
# --> 153         builder.create(self)
#     154
#     155     def add_ranges(self, dim, range):
#
# /usr/local/lib/python3.6/site-packages/bokeh/charts/builder.py in create(self, chart)
#     510         if chart is None:
#     511             chart = Chart()
# --> 512         chart.add_renderers(self, renderers)
#     513
#     514         # handle ranges after renders, since ranges depend on aggregations
#
# /usr/local/lib/python3.6/site-packages/bokeh/charts/chart.py in add_renderers(self, builder, renderers)
#     146
#     147     def add_renderers(self, builder, renderers):
# --> 148         self.renderers += renderers
#     149         self._renderer_map.extend({ r._id : builder for r in renderers })
#     150
#
# /usr/local/lib/python3.6/site-packages/bokeh/core/property/containers.py in wrapper(self, *args, **kwargs)
#      74     def wrapper(self, *args, **kwargs):
#      75         old = self._saved_copy()
# ---> 76         result = func(self, *args, **kwargs)
#      77         self._notify_owners(old)
#      78         return result
#
# /usr/local/lib/python3.6/site-packages/bokeh/core/property/containers.py in __iadd__(self, y)
#     170     @notify_owner
#     171     def __iadd__(self, y):
# --> 172         return super(PropertyValueList, self).__iadd__(y)
#     173
#     174     # x *= y
#
# /usr/local/lib/python3.6/site-packages/bokeh/charts/builders/bar_builder.py in yield_renderers(self)
#     212             bg = self.glyph(label=group.label,
#     213                             x_label=self._get_label(group['label']),
# --> 214                             values=group.data[self.values.selection].values,
#     215                             agg=stats[self.agg](),
#     216                             width=self.bar_width,
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3550                         loc = indexer.item()
#    3551                     else:
# -> 3552                         raise ValueError("cannot label index with a null key")
#    3553
#    3554             return self.iget(loc, fastpath=fastpath)
#
# ValueError: cannot label index with a null key

# %%
## STAMEN TONER
from bokeh.io import output_file, show
from bokeh.plotting import figure, ColumnDataSource, gmap, GMap
from bokeh.models import DataRange1d
from bokeh.tile_providers import STAMEN_TONER

# 42.3564/-71.0168
bound = 20000000 # meters
fig = figure(tools='pan, wheel_zoom', x_range=(-7925000, -7900000), y_range=(5195000, 5230000))
fig.axis.visible = True
fig.add_tile(STAMEN_TONER)


source = ColumnDataSource(
    data=dict(
        lat=lat_wm,
        lon=lon_wm,
    )
)

circle = Circle(x="lon", y="lat", size=3, fill_color="blue", fill_alpha=0.3, line_color=None)
fig.add_glyph(source, circle)

output_file("stamen_toner_plot.html")
show(fig)

# %%
from bokeh.models import Circle, Line, Triangle, Rect, Text

# %%
## How to add layers
plot = Plot()
plot.add_glyph()
plot.add_layout()
plot.add_tools()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-65d882c759f3> in <module>()
# ----> 1 plot = Plot(**plot_options)
#
# NameError: name 'Plot' is not defined

# %%
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)

# %%
## How to add layers
plot = Plot()
plot.add_glyph()
plot.add_layout()
plot.add_tools()

# %%
sr.columns
# Out:
# Index(['Unnamed: 0', 'CASE_ENQUIRY_ID', 'OPEN_DT', 'TARGET_DT', 'CLOSED_DT',
#        'OnTime_Status', 'CASE_STATUS', 'CLOSURE_REASON', 'CASE_TITLE',
#        'SUBJECT', 'REASON', 'TYPE', 'QUEUE', 'Department', 'SubmittedPhoto',
#        'ClosedPhoto', 'Location', 'fire_district', 'pwd_district',
#        'city_council_district', 'police_district', 'neighborhood',
#        'neighborhood_services_district', 'ward', 'precinct', 'land_usage',
#        'LOCATION_STREET_NAME', 'LOCATION_ZIPCODE', 'Property_Type',
#        'Property_ID', 'LATITUDE', 'LONGITUDE', 'Source', 'Geocoded_Location'],
#       dtype='object')

# %%
import pandas as pd
# %time df = pd.read_csv('../../Downloads/311__Service_Requests.csv',usecols= \
                       ['LATITUDE', 'LONGITUDE', 'OPEN_DT', 'Source', 'Geocoded_Location', 'REASON'])
df.tail()
# Out:
# CPU times: user 3.57 s, sys: 257 ms, total: 3.82 s
# Wall time: 3.84 s
#                        OPEN_DT                            REASON  LATITUDE  \
# 950878  03/12/2017 08:45:08 PM  Enforcement & Abandoned Vehicles   42.3353
# 950879  03/12/2017 05:16:49 PM  Enforcement & Abandoned Vehicles   42.3312
# 950880  03/12/2017 03:33:33 PM  Enforcement & Abandoned Vehicles   42.3594
# 950881  03/12/2017 02:53:21 PM  Enforcement & Abandoned Vehicles   42.2914
# 950882  02/10/2017 10:23:00 AM                           Housing   42.3159
#
#         LONGITUDE                Source    Geocoded_Location
# 950878   -71.0254  Citizens Connect App  (42.3353, -71.0254)
# 950879   -71.0988  Citizens Connect App  (42.3312, -71.0988)
# 950880   -71.0587  Citizens Connect App               (0, 0)
# 950881   -71.0518  Citizens Connect App  (42.2914, -71.0518)
# 950882   -71.0897      Constituent Call  (42.3159, -71.0897)

# %%
req_open = pd.to_datetime(df['OPEN_DT'])

# %%
# del df['OPEN_DT']
df_dt = pd.concat([df, req_open], axis=1)

# %%
df_dt['OPEN_DT']
# Out:
# 0        2013-11-01 09:27:19
# 1        2015-01-06 15:26:49
# 2        2013-10-11 09:54:20
# 3        2013-02-10 15:12:43
# 4        2015-10-23 14:27:00
# 5        2012-07-27 09:43:38
# 6        2013-05-21 15:24:54
# 7        2012-03-14 15:54:15
# 8        2012-10-03 11:56:43
# 9        2012-10-26 09:31:12
# 10       2016-08-27 10:21:43
# 11       2013-10-08 09:41:45
# 12       2015-03-05 13:07:52
# 13       2016-07-26 08:43:35
# 14       2016-08-01 16:07:00
# 15       2013-08-02 14:19:44
# 16       2016-09-13 19:19:00
# 17       2011-09-05 12:59:31
# 18       2016-02-22 08:58:00
# 19       2015-01-03 14:08:59
# 20       2014-10-31 08:19:34
# 21       2014-05-22 19:28:49
# 22       2015-05-06 15:30:00
# 23       2016-01-27 08:41:00
# 24       2016-05-03 12:13:00
# 25       2013-07-01 07:40:52
# 26       2011-12-16 11:32:08
# 27       2014-05-03 12:20:54
# 28       2016-06-10 11:32:52
# 29       2011-07-14 10:41:28
#                  ...
# 950853   2017-03-12 14:21:00
# 950854   2017-03-12 15:56:02
# 950855   2017-03-12 14:45:22
# 950856   2017-03-12 09:43:00
# 950857   2017-03-11 15:53:13
# 950858   2016-12-12 13:45:00
# 950859   2017-03-12 13:31:41
# 950860   2017-03-12 11:49:33
# 950861   2017-03-10 13:56:02
# 950862   2017-02-10 19:54:00
# 950863   2017-03-12 15:10:28
# 950864   2017-03-12 14:42:00
# 950865   2017-03-12 08:13:38
# 950866   2017-03-12 06:48:00
# 950867   2017-03-12 20:23:09
# 950868   2017-03-12 14:37:38
# 950869   2017-03-12 19:02:49
# 950870   2017-03-10 17:25:34
# 950871   2017-03-12 12:33:00
# 950872   2017-03-12 12:57:00
# 950873   2017-03-11 17:10:00
# 950874   2017-03-12 11:34:19
# 950875   2017-03-12 21:40:01
# 950876   2017-03-11 07:32:00
# 950877   2017-03-12 13:17:09
# 950878   2017-03-12 20:45:08
# 950879   2017-03-12 17:16:49
# 950880   2017-03-12 15:33:33
# 950881   2017-03-12 14:53:21
# 950882   2017-02-10 10:23:00
# Name: OPEN_DT, dtype: datetime64[ns]

# %%
import math

def geographic_to_web_mercator(x_lon, y_lat):   
    if abs(x_lon) <= 180 and abs(y_lat) < 90:          
        num = x_lon * 0.017453292519943295         
        x = 6378137.0 * num         
        a = y_lat * 0.017453292519943295          
        x_mercator = x         
        y_mercator = 3189068.5 * math.log((1.0 + math.sin(a)) / (1.0 - math.sin(a)))         
        return x_mercator, y_mercator      
    else:         
        print('Invalid coordinate values for conversion')    
        
def geo_to_web_lon(x_lon):
    num = x_lon * 0.017453292519943295
    x = 6378137.0 * num
    return x

def geo_to_web_lat(y_lat):
    a = y_lat * 0.017453292519943295
    y_mercator = 3189068.5 * math.log((1.0 + math.sin(a)) / (1.0 - math.sin(a)))
    return y_mercator


# Python implementation
# Python Implementation by Paulo Silva, based on all code published above, 13:32, 15.2.2008

import math

def merc_x(lon):
    r_major=6378137.000
    return r_major*math.radians(lon)

def merc_y(lat):
    if lat>89.5:lat=89.5
    if lat<-89.5:lat=-89.5
    r_major=6378137.000
    r_minor=6356752.3142
    temp=r_minor/r_major
    eccent=math.sqrt(1-temp**2)
    phi=math.radians(lat)
    sinphi=math.sin(phi)
    con=eccent*sinphi
    com=eccent/2
    con=((1.0-con)/(1.0+con))**com
    ts=math.tan((math.pi/2-phi)/2)/con
    y=0-r_major*math.log(ts)
    return y

# %%
lon_wm = df['LONGITUDE'].apply(geo_to_web_lon)
lat_wm = df['LATITUDE'].apply(geo_to_web_lat)
