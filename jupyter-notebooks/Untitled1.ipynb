# %% [markdown]
# Using Numpy Arrays and DataFrames for powering glyph properties

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
import numpy as np

p = figure(plot_width=300, plot_height=300)
p.
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="eecda629-158d-4c5c-8454-3439cddc27b5">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-c675fd9eec1f> in <module>()
#       6
#       7 output_notebook()
# ----> 8 show(p)
#
# /usr/local/lib/python3.6/site-packages/bokeh/io.py in show(obj, browser, new, notebook_handle, notebook_url)
#     281
#     282     if obj not in _state.document.roots:
# --> 283         _state.document.add_root(obj)
#     284     return _show_with_state(obj, _state, browser, new, notebook_handle=notebook_handle)
#     285
#
# /usr/local/lib/python3.6/site-packages/bokeh/document.py in add_root(self, model, setter)
#     277             self._roots.append(model)
#     278         finally:
# ...
