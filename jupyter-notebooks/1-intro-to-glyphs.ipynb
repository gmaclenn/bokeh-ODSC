# %% [markdown]
# ## Where to start?
# - The **`bokeh.plotting`** API is a great balance between ease of use and customization

# %% [markdown]
# ### Other Options
# - **`bokeh.models`**
#     - low level plotting with high degree of customization.
# - **`bokeh.charts`**
#     - high level plotting that is very easy to use with less customization.
#     - Easy to generate charts quickly.

# %% [markdown]
# ### bokeh.plotting
#
# * centered around the **`figure()`** method.
#     * basic empty plot with default values.

# %% [markdown]
# ## Base figure
# * Need three items:
#     * figure()
#     * output_notebook() or output_file()
#     * show()

# %%
# base figure with no data input
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure()
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c3d79116-7fc7-42d8-b2be-9d5151326d71">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ece10cb1-1710-49f2-aa2b-83976a95b869"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ece10cb1-1710-49f2-aa2b-83976a95b869");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ece10cb1-1710-49f2-aa2b-83976a95b869");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ece10cb1-1710-49f2-aa2b-83976a95b869' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0fc915b8-e884-45bf-9a31-8a572dbcd2ce":{"roots":{"references":[{"attributes":{"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"},"ticker":{"id":"73f167c7-a5e6-4f2f-9f38-0e0e67d47c33","type":"BasicTicker"}},"id":"cc2bbaac-8642-459c-925c-7db80edd622e","type":"Grid"},{"attributes":{"overlay":{"id":"4ffcf081-456c-4d48-b2ac-b1318c7b0cf4","type":"BoxAnnotation"},"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"}},"id":"687a9ff3-4b6f-4f0b-b832-149ec16ad1db","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"}},"id":"a42d3a24-c2e7-4d20-979d-3491df1e51b2","type":"ResetTool"},{"attributes":{"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"}},"id":"88a9a17f-1f81-4dc0-b4d4-59cdf5601a1b","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4ffcf081-456c-4d48-b2ac-b1318c7b0cf4","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"e8896263-23ea-4d7f-bd43-6bf687069155","type":"BasicTickFormatter"},"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"},"ticker":{"id":"73f167c7-a5e6-4f2f-9f38-0e0e67d47c33","type":"BasicTicker"}},"id":"64061029-bc31-41fe-9663-a2ec5ce57c20","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"3d4e5fab-f7be-4e47-913e-f7ad52ca939a","type":"Title"},{"attributes":{},"id":"e8896263-23ea-4d7f-bd43-6bf687069155","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"}},"id":"ca187131-9e90-491d-a83d-27caabe340d3","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"}},"id":"e8a970bc-a8a5-438f-bec5-6a8758155ea1","type":"SaveTool"},{"attributes":{"below":[{"id":"64061029-bc31-41fe-9663-a2ec5ce57c20","type":"LinearAxis"}],"left":[{"id":"4e38270d-70ba-464f-bb04-5ed7d57e3076","type":"LinearAxis"}],"renderers":[{"id":"64061029-bc31-41fe-9663-a2ec5ce57c20","type":"LinearAxis"},{"id":"cc2bbaac-8642-459c-925c-7db80edd622e","type":"Grid"},{"id":"4e38270d-70ba-464f-bb04-5ed7d57e3076","type":"LinearAxis"},{"id":"d93135d1-680f-4cdf-a762-fab9c90eb843","type":"Grid"},{"id":"4ffcf081-456c-4d48-b2ac-b1318c7b0cf4","type":"BoxAnnotation"}],"title":{"id":"3d4e5fab-f7be-4e47-913e-f7ad52ca939a","type":"Title"},"tool_events":{"id":"90891e5e-ab41-4cbf-a6cc-221363bf1e05","type":"ToolEvents"},"toolbar":{"id":"7e3d360b-5805-478b-8bbf-b02033d4bef7","type":"Toolbar"},"x_range":{"id":"02e05f21-e8d6-4e83-b73a-0224e5b44fa6","type":"DataRange1d"},"y_range":{"id":"cde1301a-3951-40e9-b1a2-c0654c2d776f","type":"DataRange1d"}},"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"}},"id":"e0936f21-bcae-4674-9019-1bae73c96a2c","type":"HelpTool"},{"attributes":{},"id":"90891e5e-ab41-4cbf-a6cc-221363bf1e05","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"c9fbb3e3-4db5-4f98-8db6-0f58e36e9dca","subtype":"Figure","type":"Plot"},"ticker":{"id":"71b3d1ff-8a6f-4de8-97d7-e36b27521529","type":"BasicTicker"}},"id":"d93135d1-680f-4cdf-a762-fab9c90eb843","type":"Grid"},{"attributes":{"callback":null},"id":"cde1301a-3951-40e9-b1a2-c0654c2d776f","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"88a9a17f-1f81-4dc0-b4d4-59cdf5601a1b","type":"PanTool"},{"id":"ca187131-9e90-491d-a83d-27caabe340d3","type":"WheelZoomTool"},{"id":"687a9ff3-4b6f-4f0b-b832-149ec16ad1db","type":"BoxZoomTool"},{"id":"e8a970bc- ...

# %% [markdown]
# <img src="images/blank-figure.png">

# %% [markdown]
# ## Modifying the Figure Size
# * **`plot_height`** & **`plot_width`**

# %%
# Making the chart a bit smaller so we don't take up so much real estate
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure(plot_width=300, plot_height=300)
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b1b7790c-097a-48ae-9420-f6d3bded885b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="812be256-aacd-45ab-ae58-b966e32ca330"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("812be256-aacd-45ab-ae58-b966e32ca330");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("812be256-aacd-45ab-ae58-b966e32ca330");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '812be256-aacd-45ab-ae58-b966e32ca330' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c9b0bee8-14a8-4417-8a98-8c7e34b3eeec":{"roots":{"references":[{"attributes":{},"id":"71ae5145-9506-457e-af08-9a7adbade074","type":"ToolEvents"},{"attributes":{"plot":{"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"}},"id":"8657266c-31bb-42bc-8333-1e9f0ac3264c","type":"SaveTool"},{"attributes":{"plot":{"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"}},"id":"6229e228-044e-40af-aa37-9947622458a5","type":"ResetTool"},{"attributes":{"plot":null,"text":""},"id":"44582067-e120-4555-8de7-8ae8796509ea","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"801f7afd-ce5c-4753-be41-6c9e4f1d51f5","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"650282df-b031-42ef-9e47-fd2a6486af0a","type":"BasicTickFormatter"},"plot":{"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"},"ticker":{"id":"8aca9ab4-d2c4-44dd-92e4-63a4bd513cfc","type":"BasicTicker"}},"id":"56cf6ca7-b2ab-412b-864c-7da4b59c4262","type":"LinearAxis"},{"attributes":{"plot":{"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"},"ticker":{"id":"51524102-31d1-4659-b1d4-f1d7caa9faa8","type":"BasicTicker"}},"id":"8d2e41d2-1ffd-4572-99e6-a5a387702477","type":"Grid"},{"attributes":{},"id":"8aca9ab4-d2c4-44dd-92e4-63a4bd513cfc","type":"BasicTicker"},{"attributes":{},"id":"650282df-b031-42ef-9e47-fd2a6486af0a","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"}},"id":"e07cc777-cb42-47d7-b04f-12c2be8c000e","type":"PanTool"},{"attributes":{"callback":null},"id":"8ff50ae2-14b4-42ad-8ba5-88e3dc878438","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e07cc777-cb42-47d7-b04f-12c2be8c000e","type":"PanTool"},{"id":"d2bec044-aa44-41ed-88b3-334fbc8e933d","type":"WheelZoomTool"},{"id":"a61892cd-33de-46a0-aaca-07c0db3d4dd9","type":"BoxZoomTool"},{"id":"8657266c-31bb-42bc-8333-1e9f0ac3264c","type":"SaveTool"},{"id":"6229e228-044e-40af-aa37-9947622458a5","type":"ResetTool"},{"id":"329a1282-718f-4340-ab4a-c1b9602b495c","type":"HelpTool"}]},"id":"d9b6375e-efe5-4cd6-9526-35de1d5b5df9","type":"Toolbar"},{"attributes":{"below":[{"id":"70c65167-4227-4767-85db-a46808101c8c","type":"LinearAxis"}],"left":[{"id":"56cf6ca7-b2ab-412b-864c-7da4b59c4262","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"70c65167-4227-4767-85db-a46808101c8c","type":"LinearAxis"},{"id":"8d2e41d2-1ffd-4572-99e6-a5a387702477","type":"Grid"},{"id":"56cf6ca7-b2ab-412b-864c-7da4b59c4262","type":"LinearAxis"},{"id":"79499d69-3db6-428c-9a8b-b29bf50b8dfc","type":"Grid"},{"id":"801f7afd-ce5c-4753-be41-6c9e4f1d51f5","type":"BoxAnnotation"}],"title":{"id":"44582067-e120-4555-8de7-8ae8796509ea","type":"Title"},"tool_events":{"id":"71ae5145-9506-457e-af08-9a7adbade074","type":"ToolEvents"},"toolbar":{"id":"d9b6375e-efe5-4cd6-9526-35de1d5b5df9","type":"Toolbar"},"x_range":{"id":"8ff50ae2-14b4-42ad-8ba5-88e3dc878438","type":"DataRange1d"},"y_range":{"id":"c3477ea3-1b1a-4598-8176-c9bc6ba0d112","type":"DataRange1d"}},"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"88735e42-8ea8-4c57-8c63-c1ccb80347bb","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"},"ticker":{"id":"8aca9ab4-d2c4-44dd-92e4-63a4bd513cfc","type":"BasicTicker"}},"id":"79499d69-3db6-428c-9a8b-b29bf50b8dfc","type":"Grid"},{"attributes":{"plot":{"id":"8f5ae5f2-b2a8-47cc-8861-ee77995ea115","subtype":"Figure","type":"Plot"}},"id":"329a1282-718f-4340-ab4a-c ...

# %% [markdown]
# <img src="images/blank-figure-small.png">

# %% [markdown]
# ## Introduction to Glyphs
# Bokeh uses **`"Glyphs"`** which are the base visual structures to overlay on top of any plots.

# %% [markdown]
# - glyphs add visual shapes to the empty **`figure()`** plot

# %% [markdown]
# - glyphs can take on a number of different shapes
#     - i.e. circle, diamond, arc, asterisk, patch, cross, etc.

# %% [markdown]
# - visual shapes can be customized by modifying glyph properties
#     - i.e. color, alpha, size, radius, angle, hover_color, etc.

# %% [markdown]
# ## Adding a Single Circle Glyph
# * Added a circle glyph with **`p.circle()`** to the plot **`p`**
# * defined the x and y coordinate values within **`p.circle()`**
# * **`output_notebook()`** and **`show(p)`**

# %%
# base figure with one circle glyph
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure(plot_width=300, plot_height=300)
p.circle(x=5, y=10)
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e6962577-81c8-47fd-bd51-13a99b047ac6">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="15740c11-77e0-4809-b37c-4056cbd9aea4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("15740c11-77e0-4809-b37c-4056cbd9aea4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("15740c11-77e0-4809-b37c-4056cbd9aea4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '15740c11-77e0-4809-b37c-4056cbd9aea4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6c6116c9-e827-4e6e-b191-d6d522c10120":{"roots":{"references":[{"attributes":{"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"},"ticker":{"id":"9f8a6845-ee3c-4b85-b692-0f61360d3462","type":"BasicTicker"}},"id":"898c4430-87c0-4426-a952-fc0185310752","type":"Grid"},{"attributes":{"formatter":{"id":"742dd8bb-f852-45ee-8786-e4bb4352a182","type":"BasicTickFormatter"},"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"},"ticker":{"id":"9f8a6845-ee3c-4b85-b692-0f61360d3462","type":"BasicTicker"}},"id":"86efc48f-0de1-4f4c-b4d6-6414b95be65e","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"2d04a986-a968-4c1f-a8c5-62f4e48bd073","type":"Title"},{"attributes":{"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"}},"id":"88530ec5-fddb-46cf-8bc4-f12404f37d07","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"value":5},"y":{"value":10}},"id":"a5b2c010-394d-462f-863a-dc97b1e01883","type":"Circle"},{"attributes":{"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"}},"id":"2b574a77-4541-462f-9a39-f461e929ee6a","type":"ResetTool"},{"attributes":{"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"}},"id":"32d8ff32-7c2e-40bc-aafc-e0fea00d9601","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"},"ticker":{"id":"dcaa7f74-3ee2-4eb3-96c6-652e2beafc29","type":"BasicTicker"}},"id":"46ad843c-9068-4481-a5d7-3e809a489be1","type":"Grid"},{"attributes":{"callback":null},"id":"a6474290-865c-4ea3-afee-e5d103e85971","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8e99a925-b358-4bce-bdce-ce55f9f89487","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"}},"id":"a112e6b2-cdad-4799-9853-d49ef60bb6d9","type":"HelpTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"value":5},"y":{"value":10}},"id":"72b0b6aa-28fe-46b7-939b-50084f5a69f2","type":"Circle"},{"attributes":{},"id":"fe1e3f70-db01-4e37-8611-8b03c53b4ce5","type":"BasicTickFormatter"},{"attributes":{},"id":"9f8a6845-ee3c-4b85-b692-0f61360d3462","type":"BasicTicker"},{"attributes":{},"id":"dcaa7f74-3ee2-4eb3-96c6-652e2beafc29","type":"BasicTicker"},{"attributes":{"callback":null,"data":{}},"id":"1970ac80-0393-409d-8ed7-38ae191bad17","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"556e531b-0ba1-4b25-9225-b7adaabda699","subtype":"Figure","type":"Plot"}},"id":"928e77f2-3202-4d6f-af92-7ac1c0631917","type":"WheelZoomTool"},{"attributes":{},"id":"742dd8bb-f852-45ee-8786-e4bb4352a182","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"32d8ff32-7c2e-40bc-aafc-e0fea00d9601","type":"PanTool"},{"id":"928e77f2-3202-4d6f-af92-7ac1c0631917","type":"WheelZoomTool"},{"id":"519869b4-d098-45e7-a87e-4affa7144d9c","type":"BoxZoomTool"},{"id":"88530ec5-fddb-46cf-8bc4-f12404f37d07","type":"SaveTool"},{"id":"2b574a77-4541-462f-9a39-f461e929ee6a","type":"ResetTool"},{"id":"a112e6b2-cdad-4799-9853-d49ef60bb6d9","type":"HelpTool"}]},"id":"614c039d-2179-496e-83f8-bcaaa6d27fc1","type":"Toolbar"},{"attributes":{},"id":"53e6fd93-c12d-4495-a71d-540243833914","type":"ToolEvents"},{"attributes":{"below":[{"id":"86efc48f-0de1-4f4c-b4d6-6414b95be65e","type":"LinearAxis"}],"left":[{"id":"14db6ce0-ab58-4eb8-be29-0906831c2515","type":"LinearAxis"}],"plot_height":300,"pl ...

# %% [markdown]
# ## Passing Lists of Values

# %%
# base figure with one multiple circle points
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure(plot_width=300, plot_height=300)
p.circle(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4])
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="01c376ba-2a3a-48a4-a687-92e34f5507f9">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="42d91963-6db3-43a4-af82-c973815bc0bd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("42d91963-6db3-43a4-af82-c973815bc0bd");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("42d91963-6db3-43a4-af82-c973815bc0bd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '42d91963-6db3-43a4-af82-c973815bc0bd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f4bad81b-9d79-4049-aa8c-e11291734839":{"roots":{"references":[{"attributes":{"plot":{"id":"52a5c30e-4d00-4d42-8133-8fa959fb8462","subtype":"Figure","type":"Plot"}},"id":"0c466ee7-7e87-46b6-93ff-3d78cb17c25e","type":"PanTool"},{"attributes":{},"id":"e82dbea8-4f9e-4044-ab6d-b809f589bcf8","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"7063dd4b-5aab-4cd4-b57e-a70b7891f9c7","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"9ec0ec14-93a0-4336-9e05-49489fc82e7f","type":"DataRange1d"},{"attributes":{"plot":{"id":"52a5c30e-4d00-4d42-8133-8fa959fb8462","subtype":"Figure","type":"Plot"}},"id":"e156e09f-1b9b-49fa-ba73-39872f7d6d1d","type":"HelpTool"},{"attributes":{},"id":"d89b9b6b-6b55-42be-a63a-1f0ea4c31aca","type":"ToolEvents"},{"attributes":{},"id":"1f6ddf5b-a312-404b-bb55-70a3927bce67","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"956035f5-2447-44a4-bc6e-bf0eeaf75619","type":"DataRange1d"},{"attributes":{"plot":{"id":"52a5c30e-4d00-4d42-8133-8fa959fb8462","subtype":"Figure","type":"Plot"},"ticker":{"id":"c166b9ae-8d3b-4820-b1b0-4aba417d5fdc","type":"BasicTicker"}},"id":"024397c6-fc50-4be6-bcb0-48129239992a","type":"Grid"},{"attributes":{"plot":{"id":"52a5c30e-4d00-4d42-8133-8fa959fb8462","subtype":"Figure","type":"Plot"}},"id":"ecd60578-24b7-4df1-89af-19e0c6bdad01","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"52a5c30e-4d00-4d42-8133-8fa959fb8462","subtype":"Figure","type":"Plot"},"ticker":{"id":"e82dbea8-4f9e-4044-ab6d-b809f589bcf8","type":"BasicTicker"}},"id":"9a823bbc-bcd2-4814-8abd-18a830f3a893","type":"Grid"},{"attributes":{"formatter":{"id":"1f6ddf5b-a312-404b-bb55-70a3927bce67","type":"BasicTickFormatter"},"plot":{"id":"52a5c30e-4d00-4d42-8133-8fa959fb8462","subtype":"Figure","type":"Plot"},"ticker":{"id":"e82dbea8-4f9e-4044-ab6d-b809f589bcf8","type":"BasicTicker"}},"id":"a096667a-9762-4fcc-a549-f6ee1fc08ab2","type":"LinearAxis"},{"attributes":{"plot":{"id":"52a5c30e-4d00-4d42-8133-8fa959fb8462","subtype":"Figure","type":"Plot"}},"id":"38c9e587-0c0b-45b2-a1b6-b7647fb2bc73","type":"SaveTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2c13b50f-ebd1-46e3-962a-4994a4a9a8d7","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0c466ee7-7e87-46b6-93ff-3d78cb17c25e","type":"PanTool"},{"id":"3a441d2b-22f2-46dc-bd5c-11396e9d54e5","type":"WheelZoomTool"},{"id":"91d2bee3-46ac-4eef-9997-356886dcb68a","type":"BoxZoomTool"},{"id":"38c9e587-0c0b-45b2-a1b6-b7647fb2bc73","type":"SaveTool"},{"id":"ecd60578-24b7-4df1-89af-19e0c6bdad01","type":"ResetTool"},{"id":"e156e09f-1b9b-49fa-ba73-39872f7d6d1d","type":"HelpTool"}]},"id":"a296da48-32f2-4cf3-b6fa-14ef35c5eaa2","type":"Toolbar"},{"attributes":{"overlay":{"id":"cea3620b-09b4-4a65-a54e-9f1ce6ffd83d","type":"BoxAnnotation"},"plot":{"id":"52a5c30e-4d00-4d42-8133-8fa959fb8462","subtype":"Figure","type":"Plot"}},"id":"91d2bee3-46ac-4eef-9997-356886dcb68a","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"aa128493-0213-4063-8970-07fdf7d3adcd","type":"Circle"},{"attributes":{"formatter":{"id":"c9591a55-201f-4388-85d0-95aa6b262dbc","type":"BasicTickFormatter"},"plot":{"id":"52a5c30e-4d00-4d42-8133-8fa959fb8462","subtype":"Figure","type":"Plot"},"ticker":{"id":"c166b9ae-8d3b-4820-b1b0-4aba417d5fdc","type":"BasicTicker"}},"id":"f278d4dd-3fec-498c-b45b-04587154677b","type":"LinearAxis"},{"attributes":{},"id":"c166b9ae-8d3b-4820-b1b0-4aba417d5fdc","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":" ...

# %% [markdown]
# ## Default Figure Properties
# * Axes automatically fit the data points
# * Figure attributes take on default values that can be modified
# * Glyphs are assigned default values that can be modified

# %% [markdown]
# ## Modifying Glyph Properties
# * Properties can take single fixed values or any valid sequence of values
# * Three common properties we modify are as follows:

# %% [markdown]
# ### size
# - modifies the diameter of the circle you create for **`p.circle()`**

# %% [markdown]
# ### alpha
# - A value from 0 to 1 indicating the level of transparency of the glyph
#     - 0 being fully transparent and 1 being completely non-transparent

# %% [markdown]
# ### color
# - Color value of the glyph.
#     - Can take a Xterm 256 values, Hex values and other color palettes.

# %% [markdown]
# ## Modifying Size, Alpha & Color

# %%
# base figure with one multiple circle points
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure(plot_width=300, plot_height=300)

p.circle(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4],
         size=10, alpha=0.3, color='firebrick')

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fa700a95-883d-4302-a76a-bd9b0ca88dff">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="55b05557-2f32-4a06-850a-b088c903cdab"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("55b05557-2f32-4a06-850a-b088c903cdab");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("55b05557-2f32-4a06-850a-b088c903cdab");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '55b05557-2f32-4a06-850a-b088c903cdab' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"eb784881-7407-4852-841a-c3e87a2655c6":{"roots":{"references":[{"attributes":{"plot":{"id":"00198d40-71cb-4436-bd36-e4116e881461","subtype":"Figure","type":"Plot"}},"id":"5687b09f-18b3-45f7-b2b2-eb1691783db9","type":"SaveTool"},{"attributes":{"data_source":{"id":"39c9d7ba-ae48-4b98-a651-552c92eb1359","type":"ColumnDataSource"},"glyph":{"id":"7272ab7f-b096-4296-934d-ab5db62c6851","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0116b081-2f1f-4dee-95e7-1241f948a7fd","type":"Circle"},"selection_glyph":null},"id":"821c2eda-7a5a-404e-aa5a-0b8ad03b25dc","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"00198d40-71cb-4436-bd36-e4116e881461","subtype":"Figure","type":"Plot"}},"id":"9ac86f6e-dd4e-4c1c-8dea-655a6c5c09a0","type":"HelpTool"},{"attributes":{"below":[{"id":"46f59a4a-f224-40c3-acff-1742da8f96ff","type":"LinearAxis"}],"left":[{"id":"d0bb6e47-b583-49b4-b74e-5cb56bb287bc","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"46f59a4a-f224-40c3-acff-1742da8f96ff","type":"LinearAxis"},{"id":"e05dfd61-5141-44c8-8369-102671f8b691","type":"Grid"},{"id":"d0bb6e47-b583-49b4-b74e-5cb56bb287bc","type":"LinearAxis"},{"id":"d266b532-8f48-461c-9b25-4f033234b4f0","type":"Grid"},{"id":"15c1416d-b2ce-41f9-887d-15181203aea5","type":"BoxAnnotation"},{"id":"821c2eda-7a5a-404e-aa5a-0b8ad03b25dc","type":"GlyphRenderer"}],"title":{"id":"a6d0b6d0-13fb-4284-9c5f-137c581cad62","type":"Title"},"tool_events":{"id":"2ffb9435-1014-453b-9b7b-d49377374a94","type":"ToolEvents"},"toolbar":{"id":"582f68bc-b80b-49df-a3ba-771b7877fe25","type":"Toolbar"},"x_range":{"id":"f28201c5-4447-463e-818a-c7d06642e773","type":"DataRange1d"},"y_range":{"id":"ec658733-9554-4b05-a5d0-407b7d80e88b","type":"DataRange1d"}},"id":"00198d40-71cb-4436-bd36-e4116e881461","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":""},"id":"a6d0b6d0-13fb-4284-9c5f-137c581cad62","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"0116b081-2f1f-4dee-95e7-1241f948a7fd","type":"Circle"},{"attributes":{"plot":{"id":"00198d40-71cb-4436-bd36-e4116e881461","subtype":"Figure","type":"Plot"},"ticker":{"id":"da7703eb-5a52-462e-b7a4-b9c70d1607b7","type":"BasicTicker"}},"id":"e05dfd61-5141-44c8-8369-102671f8b691","type":"Grid"},{"attributes":{"callback":null},"id":"f28201c5-4447-463e-818a-c7d06642e773","type":"DataRange1d"},{"attributes":{},"id":"2ffb9435-1014-453b-9b7b-d49377374a94","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8ac5bd75-f0ff-4252-ae42-5667953bb8ed","type":"PanTool"},{"id":"dac8fdf6-4c9c-4f74-b547-39e37a2eaa83","type":"WheelZoomTool"},{"id":"66ee1968-38ce-46d8-93b1-94152052ef19","type":"BoxZoomTool"},{"id":"5687b09f-18b3-45f7-b2b2-eb1691783db9","type":"SaveTool"},{"id":"0ec0ec83-2d59-4767-b9d4-5c72372973f8","type":"ResetTool"},{"id":"9ac86f6e-dd4e-4c1c-8dea-655a6c5c09a0","type":"HelpTool"}]},"id":"582f68bc-b80b-49df-a3ba-771b7877fe25","type":"Toolbar"},{"attributes":{"formatter":{"id":"1e3a447c-7df7-463b-a198-dc0f4fde3812","type":"BasicTickFormatter"},"plot":{"id":"00198d40-71cb-4436-bd36-e4116e881461","subtype":"Figure","type":"Plot"},"ticker":{"id":"da7703eb-5a52-462e-b7a4-b9c70d1607b7","type":"BasicTicker"}},"id":"46f59a4a-f224-40c3-acff-1742da8f96ff","type":"LinearAxis"},{"attributes":{"overlay":{"id":"15c1416d-b2ce-41f9-887d-15181203aea5","type":"BoxAnnotation"},"plot":{"id":"00198d40-71cb-4436-bd36-e4116e881461","subtype":"Figure","type":"Plot"}},"id":"66ee1968-38ce-46d8-93b1-94152052ef19","type":"BoxZoomTool"},{"attributes":{},"id":"1e3a447c-7df7-463b-a198-dc0f4fde3812","type":"BasicTickFormatter"},{"attributes":{},"id":"47c64fbc-7002-4970-b44e-2e7fc689a691","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x ...

# %% [markdown]
# ## Using Lists to Modify Glyph Properties

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create lists for the properties to modify
color_list = ['firebrick', 'wheat', 'blue', 'darkcyan', 'aqua', 'magenta']
size_list = [4, 6, 8, 12, 18, 24]
alpha_list = [1, 1, 0.8, 0.6, 0.4, 0.2]

# create the plot
p = figure(plot_width=300, plot_height=300)

# add the circle glyph
p.circle(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4],
         size=size_list, alpha=alpha_list, color=color_list)

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="393f24d3-6163-4a5c-a77e-5fb72a2615a9">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5aeb6e05-cd28-4cca-a9ee-7c970e4f05d0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5aeb6e05-cd28-4cca-a9ee-7c970e4f05d0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5aeb6e05-cd28-4cca-a9ee-7c970e4f05d0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5aeb6e05-cd28-4cca-a9ee-7c970e4f05d0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7a8f5298-7631-4d6d-b196-3ef5693935f7":{"roots":{"references":[{"attributes":{"formatter":{"id":"e824e49b-f6ef-4f2c-9415-5dcb4acb2031","type":"BasicTickFormatter"},"plot":{"id":"815614d1-77b4-4258-b4ce-50091fbb7606","subtype":"Figure","type":"Plot"},"ticker":{"id":"4c2d7017-49df-44fe-8506-da59ac5e19fb","type":"BasicTicker"}},"id":"b711b833-a25b-4c46-b343-71a5dd3d4661","type":"LinearAxis"},{"attributes":{},"id":"e824e49b-f6ef-4f2c-9415-5dcb4acb2031","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"815614d1-77b4-4258-b4ce-50091fbb7606","subtype":"Figure","type":"Plot"}},"id":"669e25f1-43ad-4de9-8bd3-effcfa4779a5","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"815614d1-77b4-4258-b4ce-50091fbb7606","subtype":"Figure","type":"Plot"}},"id":"6971bbe4-a15e-4dc8-8472-e0abef3f7ae6","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["size","x","y","fill_color","line_color","fill_alpha","line_alpha"],"data":{"fill_alpha":[1,1,0.8,0.6,0.4,0.2],"fill_color":["firebrick","wheat","blue","darkcyan","aqua","magenta"],"line_alpha":[1,1,0.8,0.6,0.4,0.2],"line_color":["firebrick","wheat","blue","darkcyan","aqua","magenta"],"size":[4,6,8,12,18,24],"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"07cbbee1-cdc1-4f70-a0c0-5e2beb470c85","type":"ColumnDataSource"},{"attributes":{},"id":"4dd2b1bf-0b61-4c0c-bb1a-f43bd53a5cb6","type":"BasicTicker"},{"attributes":{},"id":"4c2d7017-49df-44fe-8506-da59ac5e19fb","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"249df858-1eb1-48c3-a489-20a864313baa","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"12099fe4-910e-479e-b897-d31d7b29047c","type":"LinearAxis"}],"left":[{"id":"b711b833-a25b-4c46-b343-71a5dd3d4661","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"12099fe4-910e-479e-b897-d31d7b29047c","type":"LinearAxis"},{"id":"4a478dc5-6218-4f47-a940-109edbf1c3b3","type":"Grid"},{"id":"b711b833-a25b-4c46-b343-71a5dd3d4661","type":"LinearAxis"},{"id":"38e3d419-4dab-4b46-9f1e-57e3dd151f7b","type":"Grid"},{"id":"249df858-1eb1-48c3-a489-20a864313baa","type":"BoxAnnotation"},{"id":"ae8dc7f6-a50a-4484-9498-61deef37c2be","type":"GlyphRenderer"}],"title":{"id":"16c81cea-1f82-4ac6-bee3-24dfc11f4772","type":"Title"},"tool_events":{"id":"b7f2e379-f237-444b-a818-c07e5e92ada2","type":"ToolEvents"},"toolbar":{"id":"e27f332a-c303-42db-b522-6494bae4617c","type":"Toolbar"},"x_range":{"id":"46a017fb-3ffb-4494-a29c-42804a990e9e","type":"DataRange1d"},"y_range":{"id":"6b8e6097-2d89-4248-bd59-14342423b461","type":"DataRange1d"}},"id":"815614d1-77b4-4258-b4ce-50091fbb7606","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"23d0312d-ff9f-491e-a0d1-86999264e6fa","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"815614d1-77b4-4258-b4ce-50091fbb7606","subtype":"Figure","type":"Plot"}},"id":"faebc427-5325-4a40-8827-6c490ac459ae","type":"SaveTool"},{"attributes":{"data_source":{"id":"07cbbee1-cdc1-4f70-a0c0-5e2beb470c85","type":"ColumnDataSource"},"glyph":{"id":"8d26b0a1-7129-49a6-b31b-488246a4c49c","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"500f6846-022a-473c-a0e0-751e094fb5ad","type":"Circle"},"selection_glyph":null},"id":"ae8dc7f6-a50a-4484-9498-61deef37c2be","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"249df858-1eb1-48c3-a489-20a864313baa","type":"BoxAnnotation"},"plot":{"id":"815614d1-77b4-4258-b4ce-50091fbb7606","subtype":"Figure","type":"Plot"}},"id":"f7fdb62b-94fd-494b-8300-02aaf6d19bd8","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"46a017fb-3ffb-4494-a29c-42804a990e9e","type":"DataRange1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"fill_color"},"li ...

# %% [markdown]
# ## Plotting other glyph shapes

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create the plot
p = figure(plot_width=300, plot_height=300)

# add a line glyph
p.line(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4])

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fae5300f-c3fa-41f0-ab2f-d1cecf855692">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3d9e7dc8-dd8c-4203-a3ad-1124ccbb6d4a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3d9e7dc8-dd8c-4203-a3ad-1124ccbb6d4a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3d9e7dc8-dd8c-4203-a3ad-1124ccbb6d4a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3d9e7dc8-dd8c-4203-a3ad-1124ccbb6d4a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ef001e42-0606-44df-8467-2cdb45a9a2b0":{"roots":{"references":[{"attributes":{"plot":{"id":"cb67d672-a226-4905-ab35-338b294bdc68","subtype":"Figure","type":"Plot"}},"id":"87ab78ea-4efd-4c5d-8394-279533217c99","type":"SaveTool"},{"attributes":{"plot":{"id":"cb67d672-a226-4905-ab35-338b294bdc68","subtype":"Figure","type":"Plot"}},"id":"1b1d7617-2bba-4963-8b70-09b281e7b2c5","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"cb67d672-a226-4905-ab35-338b294bdc68","subtype":"Figure","type":"Plot"},"ticker":{"id":"aa2ad5e8-4f16-4592-8ecb-2391f2db7956","type":"BasicTicker"}},"id":"6f5c5c5d-a7f7-4c7b-a67f-9872be4c02a0","type":"Grid"},{"attributes":{"overlay":{"id":"0b394863-7050-4aa7-94f7-e5ae37fe3d43","type":"BoxAnnotation"},"plot":{"id":"cb67d672-a226-4905-ab35-338b294bdc68","subtype":"Figure","type":"Plot"}},"id":"52da332e-22dc-474e-8226-dc9d423c19c4","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0b394863-7050-4aa7-94f7-e5ae37fe3d43","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b77adf4a-e1ab-4aa9-9b4a-d7992fc89cdf","type":"Line"},{"attributes":{"plot":{"id":"cb67d672-a226-4905-ab35-338b294bdc68","subtype":"Figure","type":"Plot"}},"id":"74b2d040-be34-4afd-a96a-3be7dacccfab","type":"PanTool"},{"attributes":{},"id":"87742c79-8297-4c17-a1bf-06eaaea2586d","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"2e6da366-3852-4b41-b5df-82858d97a198","type":"ColumnDataSource"},"glyph":{"id":"2d5c0ad9-dcbc-4546-aa5b-d7eabb21866a","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b77adf4a-e1ab-4aa9-9b4a-d7992fc89cdf","type":"Line"},"selection_glyph":null},"id":"7a2b675d-88af-4e67-ae6d-90c173af805a","type":"GlyphRenderer"},{"attributes":{},"id":"eb87abb6-bf53-424a-b28f-3644ecca734f","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"cb67d672-a226-4905-ab35-338b294bdc68","subtype":"Figure","type":"Plot"},"ticker":{"id":"e68c14ba-afd6-430b-971e-b04b9a744aba","type":"BasicTicker"}},"id":"d1eff370-b470-4c3f-903f-3f9f57abfcee","type":"Grid"},{"attributes":{},"id":"e68c14ba-afd6-430b-971e-b04b9a744aba","type":"BasicTicker"},{"attributes":{"callback":null},"id":"0f071fc2-2ef8-498f-a4e9-2ecf44a0ffdc","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"2e6da366-3852-4b41-b5df-82858d97a198","type":"ColumnDataSource"},{"attributes":{},"id":"efb8c880-f635-4cf1-8a16-e5a6a0a1b11e","type":"ToolEvents"},{"attributes":{"formatter":{"id":"87742c79-8297-4c17-a1bf-06eaaea2586d","type":"BasicTickFormatter"},"plot":{"id":"cb67d672-a226-4905-ab35-338b294bdc68","subtype":"Figure","type":"Plot"},"ticker":{"id":"e68c14ba-afd6-430b-971e-b04b9a744aba","type":"BasicTicker"}},"id":"ec33d0c7-191f-487c-b3f5-890de0c76081","type":"LinearAxis"},{"attributes":{"plot":{"id":"cb67d672-a226-4905-ab35-338b294bdc68","subtype":"Figure","type":"Plot"}},"id":"ac24f6cf-fb3e-48f5-ab7a-c3968cb60835","type":"WheelZoomTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2d5c0ad9-dcbc-4546-aa5b-d7eabb21866a","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"74b2d040-be34-4afd-a96a-3be7dacccfab","type":"PanTool"},{"id":"ac24f6cf-fb3e-48f5-ab7a-c3968cb60835","type":"WheelZoomTool"},{"id":"52da332e-22dc-474e-8226-dc9d423c19c4","type":"BoxZoomTool"},{"id":"87ab78ea-4efd-4c5d-8394-279533217c99","type":"SaveTool"},{"id":"1b1d7617-2bba-4963-8b70-09b281e7b2c5","type":"ResetTool"},{"id":"263201f1-bbc5-4de1-86ef-e419569dad19","type":"HelpTool"}] ...

# %% [markdown]
# ## Plotting Multiple Line Glyphs
# * Use **`p.line()`** twice to create two line glyphs
# * You can also use **`p.multi_line()`** and pass a list of lists as the x & y coordinates to create multiple lines.

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create the plot
p = figure(plot_width=300, plot_height=300)

# add multiple line glyph
p.line(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4])
p.line(x=[1, 2, 3, 4, 5, 6], y=[1, 1, 1, 1, 4, 6], color='red')

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ca6f947d-84a6-409a-818b-9aaa944401cc">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9da5fdb3-2c0d-41de-8e2a-6bceffccdab8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9da5fdb3-2c0d-41de-8e2a-6bceffccdab8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9da5fdb3-2c0d-41de-8e2a-6bceffccdab8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9da5fdb3-2c0d-41de-8e2a-6bceffccdab8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7a0d020a-fb01-40cb-965a-ae1b5567c6b7":{"roots":{"references":[{"attributes":{"plot":{"id":"2d46bba2-85ab-4064-9989-271944b4e1e1","subtype":"Figure","type":"Plot"},"ticker":{"id":"4e9b998f-64e2-41f1-a65e-fe51e2624c12","type":"BasicTicker"}},"id":"44e6891c-3489-4653-b7d5-d1f88a2fde5b","type":"Grid"},{"attributes":{},"id":"55c698a0-e0f0-4036-a9b8-b93357018e55","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5a8d01cc-d026-464c-9f03-a4f4aca887bb","type":"PanTool"},{"id":"eba1a5d6-b68e-4a59-a64e-f7cc6d8a9ff9","type":"WheelZoomTool"},{"id":"4d482cc7-0b8e-4153-ad04-97ee9065e21d","type":"BoxZoomTool"},{"id":"58fe4c4b-e3fe-442a-b37a-fe4ea888b14a","type":"SaveTool"},{"id":"d55bf33d-7bd4-4560-9ce5-4c6a92c075a7","type":"ResetTool"},{"id":"d4ab23a1-8cc0-4203-afc0-5e5b757a26ae","type":"HelpTool"}]},"id":"2f9881c3-76f4-44be-8eda-70b670dcc923","type":"Toolbar"},{"attributes":{},"id":"4e9b998f-64e2-41f1-a65e-fe51e2624c12","type":"BasicTicker"},{"attributes":{"callback":null},"id":"6abc4c0f-4869-43bd-958c-a3e35a93d7d2","type":"DataRange1d"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8076cb69-a5db-4743-ba25-632a31382661","type":"Line"},{"attributes":{},"id":"c6e46f48-a42b-4fda-8baf-0b94a0526faf","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"580a60a5-c404-48e6-a619-2802a04aab1e","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2914bc61-987f-478b-a3a2-22365df4e191","type":"Line"},{"attributes":{"plot":{"id":"2d46bba2-85ab-4064-9989-271944b4e1e1","subtype":"Figure","type":"Plot"}},"id":"5a8d01cc-d026-464c-9f03-a4f4aca887bb","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a4d3d2fd-cd99-486b-a8bb-2fac985036b0","type":"BoxAnnotation"},{"attributes":{},"id":"6dc8f38f-5880-42b7-8e72-5e364dfa5f03","type":"BasicTickFormatter"},{"attributes":{},"id":"58538af6-e2ec-453f-bfd7-db615f44c6ae","type":"BasicTicker"},{"attributes":{"formatter":{"id":"55c698a0-e0f0-4036-a9b8-b93357018e55","type":"BasicTickFormatter"},"plot":{"id":"2d46bba2-85ab-4064-9989-271944b4e1e1","subtype":"Figure","type":"Plot"},"ticker":{"id":"58538af6-e2ec-453f-bfd7-db615f44c6ae","type":"BasicTicker"}},"id":"233b11e3-f210-4e1b-a709-6643d8ed5e43","type":"LinearAxis"},{"attributes":{"plot":{"id":"2d46bba2-85ab-4064-9989-271944b4e1e1","subtype":"Figure","type":"Plot"}},"id":"eba1a5d6-b68e-4a59-a64e-f7cc6d8a9ff9","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"580a60a5-c404-48e6-a619-2802a04aab1e","type":"ColumnDataSource"},"glyph":{"id":"8076cb69-a5db-4743-ba25-632a31382661","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2914bc61-987f-478b-a3a2-22365df4e191","type":"Line"},"selection_glyph":null},"id":"ed467b55-1c4f-4045-8bf8-7ab6d217c679","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"2d46bba2-85ab-4064-9989-271944b4e1e1","subtype":"Figure","type":"Plot"}},"id":"d55bf33d-7bd4-4560-9ce5-4c6a92c075a7","type":"ResetTool"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fa533392-c1f4-4114-b9bb-1a8305ddc74c","type":"Line"},{"attributes":{"plot":{"id":"2d46bba2-85ab-4064-9989-271944b4e1e1","subtype":"Figure","type":"Plot"}},"id":"58fe4c4b-e3fe-442a-b37a-fe4ea888b14a","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[1,1,1,1,4,6]}},"id":"c92f8749-69c7-4944-b44b-77420140d282","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""}, ...

# %% [markdown]
# ## Creating Patch Glyphs
# * patches are single polygonal patch shapes created from a sequence of x and y coordinates
# * The patch glyph will automatically connect the first point and the last point.
# * Use **`patches()`** and pass a list of lists to create multiple patch glyphs in one line.

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create the plot
p = figure(plot_width=300, plot_height=300)

# add multiple line glyph
p.patch(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4], alpha=0.5)
p.patch(x=[1, 2, 3, 4, 5, 6], y=[1, 1, 1, 1, 4, 6], alpha=0.5, color='red')

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6958acc7-9561-4744-a0ba-2b1497707b92">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ff1d5a9d-44a2-481d-b7d0-3b655ed5a8f0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ff1d5a9d-44a2-481d-b7d0-3b655ed5a8f0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ff1d5a9d-44a2-481d-b7d0-3b655ed5a8f0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ff1d5a9d-44a2-481d-b7d0-3b655ed5a8f0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8ce575f5-5a05-4d1d-a215-1d89538767b6":{"roots":{"references":[{"attributes":{},"id":"0dd16724-f564-415b-9499-84137b3ec9f9","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"442ce221-d2dd-4502-aaf0-5e4c45466c49","type":"Title"},{"attributes":{"plot":{"id":"80649475-87fb-4dff-b38f-2ac5c121a128","subtype":"Figure","type":"Plot"}},"id":"48b6774a-4de6-4d25-938b-4068b4c0d0a6","type":"PanTool"},{"attributes":{},"id":"256c4c95-d94a-4390-a8cc-93b63c1b0936","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"0c8b8287-880c-4824-9cd9-8b806af208e8","type":"BoxAnnotation"},"plot":{"id":"80649475-87fb-4dff-b38f-2ac5c121a128","subtype":"Figure","type":"Plot"}},"id":"4033b188-3977-436f-a5f7-0fee2c2013c0","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0c8b8287-880c-4824-9cd9-8b806af208e8","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"db7c0e92-5cb6-44fc-a064-fedbf03f4ffa","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[1,1,1,1,4,6]}},"id":"38c8cad0-c66e-40a7-b2a1-4f12f75e02c3","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"f0dc4ed8-eec9-47c1-a50d-3377a9617f6d","type":"DataRange1d"},{"attributes":{"plot":{"id":"80649475-87fb-4dff-b38f-2ac5c121a128","subtype":"Figure","type":"Plot"}},"id":"e089d526-031e-4e56-8dc9-38b17eaa5fda","type":"SaveTool"},{"attributes":{"data_source":{"id":"ea376fd3-3c81-45ec-8c8c-c65316694bdb","type":"ColumnDataSource"},"glyph":{"id":"8e70d3bd-12d1-4d7c-aef3-115a7b238789","type":"Patch"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7f253f90-e098-421a-82b5-c0ab14e12bda","type":"Patch"},"selection_glyph":null},"id":"8ce42cb3-5940-4ff2-900b-0058cb8a50bb","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"256c4c95-d94a-4390-a8cc-93b63c1b0936","type":"BasicTickFormatter"},"plot":{"id":"80649475-87fb-4dff-b38f-2ac5c121a128","subtype":"Figure","type":"Plot"},"ticker":{"id":"7a46690e-5f64-4780-8220-1a0ae1dd0fa2","type":"BasicTicker"}},"id":"5281e77c-357c-43d2-aeaf-a8b226fa715a","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7f253f90-e098-421a-82b5-c0ab14e12bda","type":"Patch"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"ea376fd3-3c81-45ec-8c8c-c65316694bdb","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"4d1df5ed-dcb7-49f8-909d-8995662a0694","type":"LinearAxis"}],"left":[{"id":"5281e77c-357c-43d2-aeaf-a8b226fa715a","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"4d1df5ed-dcb7-49f8-909d-8995662a0694","type":"LinearAxis"},{"id":"81985f32-d445-4ec8-8b7b-5ee0a2a80724","type":"Grid"},{"id":"5281e77c-357c-43d2-aeaf-a8b226fa715a","type":"LinearAxis"},{"id":"5634b983-38bb-4741-ad4b-8cfce877d1ac","type":"Grid"},{"id":"0c8b8287-880c-4824-9cd9-8b806af208e8","type":"BoxAnnotation"},{"id":"8ce42cb3-5940-4ff2-900b-0058cb8a50bb","type":"GlyphRenderer"},{"id":"768c0819-cdfd-4281-848a-0712aff83c5d","type":"GlyphRenderer"}],"title":{"id":"442ce221-d2dd-4502-aaf0-5e4c45466c49","type":"Title"},"tool_events":{"id":"a9fc244f-083f-4a59-b847-d05fcf941f29","type":"ToolEvents"},"toolbar":{"id":"73d0553f-fd93-4a2b-9adb-f77543303cb3","type":"Toolbar"},"x_range":{"id":"db7c0e92-5cb6-44fc-a064-fedbf03f4ffa","type":"DataRange1d"},"y_range":{"id":"f0dc4ed8-eec9-47c1-a50d-3377a9617f6d","type":"DataRange1d"}},"id":"80649475-87fb-4dff-b38f-2ac5c121a128","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"80649475-87fb-4dff-b38f ...
