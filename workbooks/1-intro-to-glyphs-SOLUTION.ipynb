# %% [markdown]
# ## Where to start?
# - The **`bokeh.plotting`** API is a great balance between ease of use and customization

# %% [markdown]
# ### Other Options
# - **`bokeh.models`**
#     - low level plotting with high degree of customization.
# - **`bokeh.charts`**
#     - high level plotting that is very easy to use with less customization.
#     - Easy to generate charts quickly.

# %% [markdown]
# ### bokeh.plotting
#
# * centered around the **`figure()`** method.
#     * basic empty plot with default values.

# %% [markdown]
# ## Base figure
# * Need three items:
#     * figure()
#     * output_notebook() or output_file()
#     * show()

# %%
# base figure with no data input
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure()
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0e77e92f-8991-4904-8c07-78784675bf0e">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="da816d44-6bda-4535-a92f-8016e81b0a94"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("da816d44-6bda-4535-a92f-8016e81b0a94");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("da816d44-6bda-4535-a92f-8016e81b0a94");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'da816d44-6bda-4535-a92f-8016e81b0a94' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f794743e-d2ba-471b-9b49-d1010a5f862e":{"roots":{"references":[{"attributes":{"callback":null},"id":"f6a3d61e-5a94-4ed9-b83f-5a1b9a374f46","type":"DataRange1d"},{"attributes":{"plot":{"id":"93d3f2ff-b6df-412d-982c-6dc0ee386b95","subtype":"Figure","type":"Plot"}},"id":"d980c93d-6f9b-48d8-be9a-620441f8f772","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"93d3f2ff-b6df-412d-982c-6dc0ee386b95","subtype":"Figure","type":"Plot"}},"id":"1c17196d-a9ae-4927-bf47-f5a7577a97c7","type":"ResetTool"},{"attributes":{"formatter":{"id":"81b2bedf-dd44-48ec-84b9-1e9e9c49f4bc","type":"BasicTickFormatter"},"plot":{"id":"93d3f2ff-b6df-412d-982c-6dc0ee386b95","subtype":"Figure","type":"Plot"},"ticker":{"id":"eaf4c97b-a93f-4536-a943-4c440e2c8e98","type":"BasicTicker"}},"id":"3b7ec46e-2b59-4421-ab8e-b3e1181020cc","type":"LinearAxis"},{"attributes":{"plot":{"id":"93d3f2ff-b6df-412d-982c-6dc0ee386b95","subtype":"Figure","type":"Plot"},"ticker":{"id":"09b0a34b-6ec5-4d04-b2c4-7e97d4376d16","type":"BasicTicker"}},"id":"572f0804-7d78-4466-a293-22da83f55bcc","type":"Grid"},{"attributes":{},"id":"cec23381-67d2-4894-8025-42abde4b4411","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"93d3f2ff-b6df-412d-982c-6dc0ee386b95","subtype":"Figure","type":"Plot"},"ticker":{"id":"eaf4c97b-a93f-4536-a943-4c440e2c8e98","type":"BasicTicker"}},"id":"b4f22714-62b5-4a71-ba9c-8b802d46c006","type":"Grid"},{"attributes":{"overlay":{"id":"4abeeddb-2496-43aa-8660-ba8280a99f8c","type":"BoxAnnotation"},"plot":{"id":"93d3f2ff-b6df-412d-982c-6dc0ee386b95","subtype":"Figure","type":"Plot"}},"id":"a05f8799-6eb7-46cc-b156-04cdd783ab11","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"93d3f2ff-b6df-412d-982c-6dc0ee386b95","subtype":"Figure","type":"Plot"}},"id":"022a0a69-8703-4fbf-b67a-336b44d0b073","type":"PanTool"},{"attributes":{},"id":"81b2bedf-dd44-48ec-84b9-1e9e9c49f4bc","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"d586b2af-5087-4e1c-83b6-e3f35a3dafe3","type":"BasicTickFormatter"},"plot":{"id":"93d3f2ff-b6df-412d-982c-6dc0ee386b95","subtype":"Figure","type":"Plot"},"ticker":{"id":"09b0a34b-6ec5-4d04-b2c4-7e97d4376d16","type":"BasicTicker"}},"id":"8a7b1191-a24a-4874-845a-4d84337c5ebe","type":"LinearAxis"},{"attributes":{},"id":"09b0a34b-6ec5-4d04-b2c4-7e97d4376d16","type":"BasicTicker"},{"attributes":{},"id":"d586b2af-5087-4e1c-83b6-e3f35a3dafe3","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"b7e07fb6-5737-4020-9cd6-7c13da9ba510","type":"DataRange1d"},{"attributes":{},"id":"eaf4c97b-a93f-4536-a943-4c440e2c8e98","type":"BasicTicker"},{"attributes":{"below":[{"id":"8a7b1191-a24a-4874-845a-4d84337c5ebe","type":"LinearAxis"}],"left":[{"id":"3b7ec46e-2b59-4421-ab8e-b3e1181020cc","type":"LinearAxis"}],"renderers":[{"id":"8a7b1191-a24a-4874-845a-4d84337c5ebe","type":"LinearAxis"},{"id":"572f0804-7d78-4466-a293-22da83f55bcc","type":"Grid"},{"id":"3b7ec46e-2b59-4421-ab8e-b3e1181020cc","type":"LinearAxis"},{"id":"b4f22714-62b5-4a71-ba9c-8b802d46c006","type":"Grid"},{"id":"4abeeddb-2496-43aa-8660-ba8280a99f8c","type":"BoxAnnotation"}],"title":{"id":"dbaed5b1-92e2-462f-899d-b6a58c14ad4c","type":"Title"},"tool_events":{"id":"cec23381-67d2-4894-8025-42abde4b4411","type":"ToolEvents"},"toolbar":{"id":"8b2a8c3b-dfd8-4f6d-becd-73c73aac6054","type":"Toolbar"},"x_range":{"id":"f6a3d61e-5a94-4ed9-b83f-5a1b9a374f46","type":"DataRange1d"},"y_range":{"id":"b7e07fb6-5737-4020-9cd6-7c13da9ba510","type":"DataRange1d"}},"id":"93d3f2ff-b6df-412d-982c-6dc0ee386b95","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":""},"id":"dbaed5b1-92e2-462f-899d-b6a58c14ad4c","type":"Title"},{"attributes":{"plot":{"id":"93d3f2ff-b6df-412d-982c-6dc0ee386b95","subtype":"Figure","type":"Plot"}},"id":"05818b35-7e7f-4788-a0cf-42f1441c9435","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"lin ...

# %% [markdown]
# ## Modifying the Figure Size
# * **`plot_height`** & **`plot_width`**

# %%
# Making the chart a bit smaller so we don't take up so much real estate
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure(plot_width=300, plot_height=300)
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f08e18a0-4fd4-4fd1-9374-d49a0c055368">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="75e7d6e2-7d3c-4409-949f-51f652e8c4be"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("75e7d6e2-7d3c-4409-949f-51f652e8c4be");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("75e7d6e2-7d3c-4409-949f-51f652e8c4be");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '75e7d6e2-7d3c-4409-949f-51f652e8c4be' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d323d57d-3216-455f-9a4d-018d335b0024":{"roots":{"references":[{"attributes":{"formatter":{"id":"d08f2851-bb0a-4e39-adf5-5ae46d3a7ecd","type":"BasicTickFormatter"},"plot":{"id":"5d0a5c54-c374-4cb7-a665-09e7b2fa5567","subtype":"Figure","type":"Plot"},"ticker":{"id":"aae898c5-12a3-42e9-aa3c-ff62e5e60960","type":"BasicTicker"}},"id":"5702ea88-211f-4525-b0c2-9957f562a5e2","type":"LinearAxis"},{"attributes":{"plot":{"id":"5d0a5c54-c374-4cb7-a665-09e7b2fa5567","subtype":"Figure","type":"Plot"}},"id":"a529fb50-8c5d-443c-9c80-9d78f3f7c1c5","type":"ResetTool"},{"attributes":{"formatter":{"id":"e5efdecc-248e-455b-9c5b-8a2957df1764","type":"BasicTickFormatter"},"plot":{"id":"5d0a5c54-c374-4cb7-a665-09e7b2fa5567","subtype":"Figure","type":"Plot"},"ticker":{"id":"ee2d87ab-2a6d-4b72-a7c6-6addd714281e","type":"BasicTicker"}},"id":"b90d6efe-2198-4b6a-91c8-7e076db0a24a","type":"LinearAxis"},{"attributes":{"plot":{"id":"5d0a5c54-c374-4cb7-a665-09e7b2fa5567","subtype":"Figure","type":"Plot"},"ticker":{"id":"aae898c5-12a3-42e9-aa3c-ff62e5e60960","type":"BasicTicker"}},"id":"47d26796-fcbb-4482-8f45-5083f5524168","type":"Grid"},{"attributes":{"below":[{"id":"5702ea88-211f-4525-b0c2-9957f562a5e2","type":"LinearAxis"}],"left":[{"id":"b90d6efe-2198-4b6a-91c8-7e076db0a24a","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"5702ea88-211f-4525-b0c2-9957f562a5e2","type":"LinearAxis"},{"id":"47d26796-fcbb-4482-8f45-5083f5524168","type":"Grid"},{"id":"b90d6efe-2198-4b6a-91c8-7e076db0a24a","type":"LinearAxis"},{"id":"a6011b5e-dc65-43dd-a5bd-5e5ca922a997","type":"Grid"},{"id":"d222496e-0100-44f5-8a8f-4760db995b6e","type":"BoxAnnotation"}],"title":{"id":"28407079-8cf4-4542-8c06-2343e5f340a0","type":"Title"},"tool_events":{"id":"16a739ab-b39a-4912-801f-4951f07ad366","type":"ToolEvents"},"toolbar":{"id":"da66a0e5-3ae4-497e-892c-7035dc746d00","type":"Toolbar"},"x_range":{"id":"2dd47302-4967-4362-add4-557bb29a1046","type":"DataRange1d"},"y_range":{"id":"c540e9d9-03b2-4547-9eb7-fe4d2d8324a7","type":"DataRange1d"}},"id":"5d0a5c54-c374-4cb7-a665-09e7b2fa5567","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"d08f2851-bb0a-4e39-adf5-5ae46d3a7ecd","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"5d0a5c54-c374-4cb7-a665-09e7b2fa5567","subtype":"Figure","type":"Plot"}},"id":"5bf52790-b873-4b32-bff2-d924ec355c6e","type":"PanTool"},{"attributes":{},"id":"ee2d87ab-2a6d-4b72-a7c6-6addd714281e","type":"BasicTicker"},{"attributes":{},"id":"e5efdecc-248e-455b-9c5b-8a2957df1764","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"5d0a5c54-c374-4cb7-a665-09e7b2fa5567","subtype":"Figure","type":"Plot"},"ticker":{"id":"ee2d87ab-2a6d-4b72-a7c6-6addd714281e","type":"BasicTicker"}},"id":"a6011b5e-dc65-43dd-a5bd-5e5ca922a997","type":"Grid"},{"attributes":{"plot":{"id":"5d0a5c54-c374-4cb7-a665-09e7b2fa5567","subtype":"Figure","type":"Plot"}},"id":"41456910-f8de-4039-be34-0a1d496afec4","type":"HelpTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5bf52790-b873-4b32-bff2-d924ec355c6e","type":"PanTool"},{"id":"e2a22bee-ea89-4ab5-a506-b14d78d47841","type":"WheelZoomTool"},{"id":"22e4a089-97ec-4067-bc22-8b1ac7fe57ab","type":"BoxZoomTool"},{"id":"6b2dddb8-2a9a-4173-a605-d05cd88baef4","type":"SaveTool"},{"id":"a529fb50-8c5d-443c-9c80-9d78f3f7c1c5","type":"ResetTool"},{"id":"41456910-f8de-4039-be34-0a1d496afec4","type":"HelpTool"}]},"id":"da66a0e5-3ae4-497e-892c-7035dc746d00","type":"Toolbar"},{"attributes":{"plot":null,"text":""},"id":"28407079-8cf4-4542-8c06-2343e5f340a0","type":"Title"},{"attributes":{},"id":"16a739ab-b39a-4912-801f-4951f07ad366","type":"ToolEvents"},{"attributes":{"plot":{"id":"5d0a5c54-c374-4cb7-a665-09e7b2fa5567","subtype":"Figure","type":"Plot"}},"id":"6b2dddb8-2a9a-4173-a605-d05cd88baef4","type":"SaveTool"},{"attributes":{"overlay":{"id":"d222496e-0100-44f5-8a8f-4760db995b6e","type":"BoxAnnotation"},"plot":{"id":"5d0a5c54-c374-4c ...

# %% [markdown]
# ## Introduction to Glyphs
# Bokeh uses **`"Glyphs"`** which are the base visual structures to overlay on top of any plots.

# %% [markdown]
# - glyphs add visual shapes to the empty **`figure()`** plot

# %% [markdown]
# - glyphs can take on a number of different shapes
#     - i.e. circle, diamond, arc, asterisk, patch, cross, etc.

# %% [markdown]
# - visual shapes can be customized by modifying glyph properties
#     - i.e. color, alpha, size, radius, angle, hover_color, etc.

# %% [markdown]
# ## Adding a Single Circle Glyph
# * Added a circle glyph with **`p.circle()`** to the plot **`p`**
# * defined the x and y coordinate values within **`p.circle()`**
# * **`output_notebook()`** and **`show(p)`**

# %%
# base figure with one circle glyph
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure(plot_width=300, plot_height=300)
p.circle(x=5, y=10)
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="016bbb0f-84ef-4ddd-95fa-1fefd0e23c58">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1ac333b5-ceb1-4bb0-aedf-589b3db0e943"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1ac333b5-ceb1-4bb0-aedf-589b3db0e943");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1ac333b5-ceb1-4bb0-aedf-589b3db0e943");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1ac333b5-ceb1-4bb0-aedf-589b3db0e943' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3e567995-0f6b-45be-a43e-0b9091357a04":{"roots":{"references":[{"attributes":{"overlay":{"id":"376a9b79-81b9-41d8-89e6-0f7ba58d6abc","type":"BoxAnnotation"},"plot":{"id":"baf70608-d19f-41f1-9bad-7aa4e800f6b1","subtype":"Figure","type":"Plot"}},"id":"73395086-f9fd-4bdc-b43d-1e08d3fadea2","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":""},"id":"dc7ed56c-e1f5-4c77-9214-f0f551626909","type":"Title"},{"attributes":{"plot":{"id":"baf70608-d19f-41f1-9bad-7aa4e800f6b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"8da11951-1776-40ff-8896-c778bbfae696","type":"BasicTicker"}},"id":"95ef08b1-401c-4ecc-a57b-fe4d558999e7","type":"Grid"},{"attributes":{"below":[{"id":"114dbb08-948e-4bca-973c-569d4228856f","type":"LinearAxis"}],"left":[{"id":"b4307c3c-ebd7-4d5f-aa74-5b6959f13809","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"114dbb08-948e-4bca-973c-569d4228856f","type":"LinearAxis"},{"id":"95ef08b1-401c-4ecc-a57b-fe4d558999e7","type":"Grid"},{"id":"b4307c3c-ebd7-4d5f-aa74-5b6959f13809","type":"LinearAxis"},{"id":"b0000b7c-3d65-4732-be05-aedfb46a68fd","type":"Grid"},{"id":"376a9b79-81b9-41d8-89e6-0f7ba58d6abc","type":"BoxAnnotation"},{"id":"6d779b38-9560-47c3-807f-469a695be02a","type":"GlyphRenderer"}],"title":{"id":"dc7ed56c-e1f5-4c77-9214-f0f551626909","type":"Title"},"tool_events":{"id":"414a2779-d8a0-4ebe-a292-2eafc20f009f","type":"ToolEvents"},"toolbar":{"id":"97abbb0a-5e4b-4792-a527-76fecf58cdcb","type":"Toolbar"},"x_range":{"id":"9df396d6-81bf-4588-85b8-685ad9c15302","type":"DataRange1d"},"y_range":{"id":"0c2a855e-1ad9-4b70-9b14-e63f47080eae","type":"DataRange1d"}},"id":"baf70608-d19f-41f1-9bad-7aa4e800f6b1","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"baf70608-d19f-41f1-9bad-7aa4e800f6b1","subtype":"Figure","type":"Plot"}},"id":"cc17b73d-7d0f-4254-8492-d07cd0c72781","type":"HelpTool"},{"attributes":{},"id":"414a2779-d8a0-4ebe-a292-2eafc20f009f","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"baf70608-d19f-41f1-9bad-7aa4e800f6b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"c430d454-91db-4765-aab1-2956c41f9d76","type":"BasicTicker"}},"id":"b0000b7c-3d65-4732-be05-aedfb46a68fd","type":"Grid"},{"attributes":{"callback":null,"data":{}},"id":"706a6150-2767-4dcd-9ca0-e5b5fe8e4b39","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"706a6150-2767-4dcd-9ca0-e5b5fe8e4b39","type":"ColumnDataSource"},"glyph":{"id":"58a9d6e2-6620-4242-a2c8-ecc69c3a061c","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"170ba18a-0720-48c1-a747-6526eb773fa8","type":"Circle"},"selection_glyph":null},"id":"6d779b38-9560-47c3-807f-469a695be02a","type":"GlyphRenderer"},{"attributes":{},"id":"d73fa9f5-a9eb-471a-80f1-2fe2188f42cd","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d5ba8f10-6e82-4a5d-9b5d-637e69e0f68c","type":"PanTool"},{"id":"1be656f5-2a5b-438d-ae69-e31524362afd","type":"WheelZoomTool"},{"id":"73395086-f9fd-4bdc-b43d-1e08d3fadea2","type":"BoxZoomTool"},{"id":"ee649c66-39b4-4f08-88f7-221a1b09a63f","type":"SaveTool"},{"id":"f776098d-26ad-4783-ae5b-6dbaaa3e2051","type":"ResetTool"},{"id":"cc17b73d-7d0f-4254-8492-d07cd0c72781","type":"HelpTool"}]},"id":"97abbb0a-5e4b-4792-a527-76fecf58cdcb","type":"Toolbar"},{"attributes":{"callback":null},"id":"0c2a855e-1ad9-4b70-9b14-e63f47080eae","type":"DataRange1d"},{"attributes":{"formatter":{"id":"d73fa9f5-a9eb-471a-80f1-2fe2188f42cd","type":"BasicTickFormatter"},"plot":{"id":"baf70608-d19f-41f1-9bad-7aa4e800f6b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"8da11951-1776-40ff-8896-c778bbfae696","type":"BasicTicker"}},"id":"114dbb08-948e-4bca-973c-569d4228856f","type":"LinearAxis"},{"attributes":{},"id":"8da11951-1776-40ff-8896-c778bbfae696","type":"BasicTicker"},{"attributes":{},"id":"c430d454-91db-4765-aab1-2956c41f9d76","type":"BasicTicker"},{"attributes":{"plot":{"id":"baf70608-d19f-4 ...

# %% [markdown]
# ## Passing Lists of Values

# %%
# base figure with one multiple circle points
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure(plot_width=300, plot_height=300)
p.circle(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4])
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cfeb7beb-1014-4398-9197-b68d03161da0">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c1f16147-7617-44ca-8741-b053bf96ae30"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c1f16147-7617-44ca-8741-b053bf96ae30");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c1f16147-7617-44ca-8741-b053bf96ae30");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c1f16147-7617-44ca-8741-b053bf96ae30' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a1811ad8-29bd-4c60-abdc-75a5c84ae365":{"roots":{"references":[{"attributes":{"plot":{"id":"3069bafe-d081-4fd1-b427-a8a4f4410a45","subtype":"Figure","type":"Plot"}},"id":"34a3a9d3-b39a-4ae0-8b9f-e89a9842bcdb","type":"PanTool"},{"attributes":{"callback":null},"id":"2653e293-5570-4c51-9423-7a846e6981e2","type":"DataRange1d"},{"attributes":{"plot":{"id":"3069bafe-d081-4fd1-b427-a8a4f4410a45","subtype":"Figure","type":"Plot"}},"id":"a7679ebe-a2e2-413c-8bc6-7dd05c599b89","type":"SaveTool"},{"attributes":{"below":[{"id":"842da1e5-f61a-4ffd-ac93-337897ad1cab","type":"LinearAxis"}],"left":[{"id":"8431ded8-24eb-46ca-b889-019bc27e9d09","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"842da1e5-f61a-4ffd-ac93-337897ad1cab","type":"LinearAxis"},{"id":"f7470408-0644-4b0c-95ac-d0abc198e428","type":"Grid"},{"id":"8431ded8-24eb-46ca-b889-019bc27e9d09","type":"LinearAxis"},{"id":"163bb426-23ac-4a6c-8c30-1155c5d72e53","type":"Grid"},{"id":"82708d77-9e4b-453c-a64e-75a7eff13c3d","type":"BoxAnnotation"},{"id":"367e07d4-fc17-4460-91bf-e1b2e375dab3","type":"GlyphRenderer"}],"title":{"id":"81443b70-c348-41fc-bc75-44693e253963","type":"Title"},"tool_events":{"id":"8807e545-540b-443a-87ab-1b32ba4cde70","type":"ToolEvents"},"toolbar":{"id":"f1c71442-9392-4777-aa84-6b29f3fa450d","type":"Toolbar"},"x_range":{"id":"2653e293-5570-4c51-9423-7a846e6981e2","type":"DataRange1d"},"y_range":{"id":"082b7b17-59fd-4f92-bd37-8fc958858853","type":"DataRange1d"}},"id":"3069bafe-d081-4fd1-b427-a8a4f4410a45","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"3069bafe-d081-4fd1-b427-a8a4f4410a45","subtype":"Figure","type":"Plot"}},"id":"02550705-b4a8-42ad-a7ad-559dc501981f","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"82708d77-9e4b-453c-a64e-75a7eff13c3d","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"29e7b414-c5d4-42d7-896c-3b5318d33f60","type":"Circle"},{"attributes":{"formatter":{"id":"9322e219-ff65-4866-83e8-cc231c4d2159","type":"BasicTickFormatter"},"plot":{"id":"3069bafe-d081-4fd1-b427-a8a4f4410a45","subtype":"Figure","type":"Plot"},"ticker":{"id":"b65af643-2f81-4cef-8ab2-f796aaaa7e31","type":"BasicTicker"}},"id":"8431ded8-24eb-46ca-b889-019bc27e9d09","type":"LinearAxis"},{"attributes":{"overlay":{"id":"82708d77-9e4b-453c-a64e-75a7eff13c3d","type":"BoxAnnotation"},"plot":{"id":"3069bafe-d081-4fd1-b427-a8a4f4410a45","subtype":"Figure","type":"Plot"}},"id":"e153ce7b-3b97-4227-abbd-473c533690ee","type":"BoxZoomTool"},{"attributes":{},"id":"8807e545-540b-443a-87ab-1b32ba4cde70","type":"ToolEvents"},{"attributes":{"plot":{"id":"3069bafe-d081-4fd1-b427-a8a4f4410a45","subtype":"Figure","type":"Plot"},"ticker":{"id":"92af3c2f-b37f-4c90-9480-6ca308e67161","type":"BasicTicker"}},"id":"f7470408-0644-4b0c-95ac-d0abc198e428","type":"Grid"},{"attributes":{"plot":{"id":"3069bafe-d081-4fd1-b427-a8a4f4410a45","subtype":"Figure","type":"Plot"}},"id":"d086c0ad-3126-404f-95d6-fa5c73daace7","type":"HelpTool"},{"attributes":{"plot":{"id":"3069bafe-d081-4fd1-b427-a8a4f4410a45","subtype":"Figure","type":"Plot"}},"id":"8e5b8b22-6a6b-463d-ba17-3e51acffe8ad","type":"ResetTool"},{"attributes":{"callback":null},"id":"082b7b17-59fd-4f92-bd37-8fc958858853","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"9b16d78d-b3a9-4316-b796-17ac139a87fb","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"9b16d78d-b3a9-4316-b796-17ac139a87fb","type":"ColumnDataSource"},"glyph":{"id":"64daa3a9-14dc-42d ...

# %% [markdown]
# ## Default Figure Properties
# * Axes automatically fit the data points
# * Figure attributes take on default values that can be modified
# * Glyphs are assigned default values that can be modified

# %% [markdown]
# ## Modifying Glyph Properties
# * Properties can take single fixed values or any valid sequence of values
# * Three common properties we modify are as follows:

# %% [markdown]
# ### size
# - modifies the diameter of the circle you create for **`p.circle()`**

# %% [markdown]
# ### alpha
# - A value from 0 to 1 indicating the level of transparency of the glyph
#     - 0 being fully transparent and 1 being completely non-transparent

# %% [markdown]
# ### color
# - Color value of the glyph.
#     - Can take a Xterm 256 values, Hex values and other color palettes.

# %% [markdown]
# ## Modifying Size, Alpha & Color

# %%
# base figure with one multiple circle points
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure(plot_width=300, plot_height=300)

p.circle(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4],
         size=10, alpha=0.3, color='firebrick')

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0915b78c-c967-4b19-b48b-2e57311ad0e0">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="24d23d6f-baca-44cd-8546-cee2a3b02654"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("24d23d6f-baca-44cd-8546-cee2a3b02654");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("24d23d6f-baca-44cd-8546-cee2a3b02654");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '24d23d6f-baca-44cd-8546-cee2a3b02654' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1f1c7e21-bb6d-4b58-ad1e-25bd28037e96":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"18f40bac-0e96-4cef-8ac8-19f4141c7dda","type":"Title"},{"attributes":{"overlay":{"id":"0c3967bc-8bc4-48da-b1b6-d506a3bf02e7","type":"BoxAnnotation"},"plot":{"id":"87d1eb46-d466-4e7f-9eb5-19ecd4c6bf78","subtype":"Figure","type":"Plot"}},"id":"39a2f849-2577-4f01-a63a-e8e0a438ae24","type":"BoxZoomTool"},{"attributes":{},"id":"ee4a9875-08cd-4a62-a5e6-e734b085586d","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"65e8a841-4ed6-4556-add7-1d1f0abc4c42","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"87d1eb46-d466-4e7f-9eb5-19ecd4c6bf78","subtype":"Figure","type":"Plot"}},"id":"782b96de-e3c3-46a7-8cc8-dff948a0663b","type":"HelpTool"},{"attributes":{},"id":"4fa12bbd-9e97-4ae2-83b2-301a11145faa","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"d9902e93-4928-4e02-945a-14496486a925","type":"LinearAxis"}],"left":[{"id":"76c2e188-c400-4cbe-8ba5-da6599bccbfd","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"d9902e93-4928-4e02-945a-14496486a925","type":"LinearAxis"},{"id":"b5d3264a-840a-4c4e-ab86-fa351597945c","type":"Grid"},{"id":"76c2e188-c400-4cbe-8ba5-da6599bccbfd","type":"LinearAxis"},{"id":"244bb06d-b930-43bd-8b9f-7aa1aca1c0fb","type":"Grid"},{"id":"0c3967bc-8bc4-48da-b1b6-d506a3bf02e7","type":"BoxAnnotation"},{"id":"b98498cd-40a8-4df8-aa1c-db1f5bc19eaf","type":"GlyphRenderer"}],"title":{"id":"18f40bac-0e96-4cef-8ac8-19f4141c7dda","type":"Title"},"tool_events":{"id":"ee4a9875-08cd-4a62-a5e6-e734b085586d","type":"ToolEvents"},"toolbar":{"id":"68e1cfcc-f668-43d7-bd1d-f460c1134f6c","type":"Toolbar"},"x_range":{"id":"9ff2c580-d29c-441e-91ea-d6ceb7855e7a","type":"DataRange1d"},"y_range":{"id":"48bf6113-4cc2-4b4a-b5fc-8e8c17eacaa7","type":"DataRange1d"}},"id":"87d1eb46-d466-4e7f-9eb5-19ecd4c6bf78","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"4fa12bbd-9e97-4ae2-83b2-301a11145faa","type":"BasicTickFormatter"},"plot":{"id":"87d1eb46-d466-4e7f-9eb5-19ecd4c6bf78","subtype":"Figure","type":"Plot"},"ticker":{"id":"23daaaed-0f45-4267-afe8-3f5e569044cb","type":"BasicTicker"}},"id":"d9902e93-4928-4e02-945a-14496486a925","type":"LinearAxis"},{"attributes":{"plot":{"id":"87d1eb46-d466-4e7f-9eb5-19ecd4c6bf78","subtype":"Figure","type":"Plot"}},"id":"392d2751-8261-4b56-b9b8-a42b0aaee8b2","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.3},"fill_color":{"value":"firebrick"},"line_alpha":{"value":0.3},"line_color":{"value":"firebrick"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"4fd1607a-fb09-40eb-8b9e-3ab538bd76c7","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ede1647b-41a6-49a2-a53d-297cd69f04f5","type":"PanTool"},{"id":"392d2751-8261-4b56-b9b8-a42b0aaee8b2","type":"WheelZoomTool"},{"id":"39a2f849-2577-4f01-a63a-e8e0a438ae24","type":"BoxZoomTool"},{"id":"c8c4be8b-3330-4412-bb61-84df9303ec7e","type":"SaveTool"},{"id":"357240f5-1738-49f1-a9c6-f0b30a5bddc5","type":"ResetTool"},{"id":"782b96de-e3c3-46a7-8cc8-dff948a0663b","type":"HelpTool"}]},"id":"68e1cfcc-f668-43d7-bd1d-f460c1134f6c","type":"Toolbar"},{"attributes":{"data_source":{"id":"65e8a841-4ed6-4556-add7-1d1f0abc4c42","type":"ColumnDataSource"},"glyph":{"id":"4fd1607a-fb09-40eb-8b9e-3ab538bd76c7","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"bd6ff095-7785-4c05-95e7-f09bcdb40d20","type":"Circle"},"selection_glyph":null},"id":"b98498cd-40a8-4df8-aa1c-db1f5bc19eaf","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"48bf6113-4cc2-4b4a-b5fc-8e8c17eacaa7","type":"DataRange1d"},{"attributes":{"plot":{"id":"87d1eb46-d466-4e7f-9eb5-19ecd4c6bf78","subtype":"Figure","type":"Plot"}},"id":"ede1647b-41a6-49a2-a53d-297cd69f04f5","type":"PanTool"},{"attributes":{"callback":nul ...

# %% [markdown]
# ## Using Lists to Modify Glyph Properties

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create lists for the properties to modify
color_list = ['firebrick', 'wheat', 'blue', 'darkcyan', 'aqua', 'magenta']
size_list = [4, 6, 8, 12, 18, 24]
alpha_list = [1, 1, 0.8, 0.6, 0.4, 0.2]

# create the plot
p = figure(plot_width=300, plot_height=300)

# add the circle glyph
p.circle(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4],
         size=size_list, alpha=alpha_list, color=color_list)

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d7e34ea1-e398-4899-93e3-0be7cf84b94a">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="233afae2-e234-45b7-83ac-57fba958e2d0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("233afae2-e234-45b7-83ac-57fba958e2d0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("233afae2-e234-45b7-83ac-57fba958e2d0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '233afae2-e234-45b7-83ac-57fba958e2d0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"97a3011c-c8ea-465b-85bc-7c5cc038d478":{"roots":{"references":[{"attributes":{"below":[{"id":"f7431307-11c8-45ca-9086-69cb9f4a1a9f","type":"LinearAxis"}],"left":[{"id":"8cfb1b06-e439-4252-81b7-be6a460cea00","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"f7431307-11c8-45ca-9086-69cb9f4a1a9f","type":"LinearAxis"},{"id":"7267d0f0-18a3-4fd1-be1c-000ec7c80afb","type":"Grid"},{"id":"8cfb1b06-e439-4252-81b7-be6a460cea00","type":"LinearAxis"},{"id":"d6389c83-5ab3-4193-a2e5-562585ac7937","type":"Grid"},{"id":"8dc73b66-b0c3-4151-9d5b-b0fdcd2c6553","type":"BoxAnnotation"},{"id":"5327b2e8-699c-499d-bb28-f2fed0e479b4","type":"GlyphRenderer"}],"title":{"id":"bd5d33e3-d9f3-4214-9e9f-3196d5e68659","type":"Title"},"tool_events":{"id":"56c07c74-19ab-4e79-8a15-f987a877f032","type":"ToolEvents"},"toolbar":{"id":"07b1dac9-276e-43f1-8800-871a841fd4e5","type":"Toolbar"},"x_range":{"id":"c9a086f2-1a35-46f1-ad0c-4e1b02e430ff","type":"DataRange1d"},"y_range":{"id":"daa565e7-8252-4675-8ad2-8ba5c5b537bf","type":"DataRange1d"}},"id":"599ac09a-bd2e-430c-a1e6-181452f4b507","subtype":"Figure","type":"Plot"},{"attributes":{"overlay":{"id":"8dc73b66-b0c3-4151-9d5b-b0fdcd2c6553","type":"BoxAnnotation"},"plot":{"id":"599ac09a-bd2e-430c-a1e6-181452f4b507","subtype":"Figure","type":"Plot"}},"id":"65eedc35-9838-4611-b06c-b1aaab9ccccb","type":"BoxZoomTool"},{"attributes":{},"id":"4032b61a-05f0-48cd-acd5-9bce88a5a34d","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8dc73b66-b0c3-4151-9d5b-b0fdcd2c6553","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"599ac09a-bd2e-430c-a1e6-181452f4b507","subtype":"Figure","type":"Plot"}},"id":"12aeeb44-e48d-40e9-88c4-f352408f080d","type":"HelpTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"fill_color"},"line_alpha":{"field":"line_alpha"},"line_color":{"field":"line_color"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"51bbf7d4-9f4c-41c5-9e48-08ca5c420e00","type":"Circle"},{"attributes":{"plot":{"id":"599ac09a-bd2e-430c-a1e6-181452f4b507","subtype":"Figure","type":"Plot"}},"id":"6ad80f7b-1f77-4163-9e38-95a1c206a8cf","type":"WheelZoomTool"},{"attributes":{},"id":"84b5091d-df3c-4c0f-9467-3aeab3323a56","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"bd5d33e3-d9f3-4214-9e9f-3196d5e68659","type":"Title"},{"attributes":{"plot":{"id":"599ac09a-bd2e-430c-a1e6-181452f4b507","subtype":"Figure","type":"Plot"}},"id":"240c76b4-6e6b-4d1b-8f1d-988732186418","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["size","x","y","fill_color","line_color","fill_alpha","line_alpha"],"data":{"fill_alpha":[1,1,0.8,0.6,0.4,0.2],"fill_color":["firebrick","wheat","blue","darkcyan","aqua","magenta"],"line_alpha":[1,1,0.8,0.6,0.4,0.2],"line_color":["firebrick","wheat","blue","darkcyan","aqua","magenta"],"size":[4,6,8,12,18,24],"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"c91e9a54-fc54-4e39-892f-93e9b26b9388","type":"ColumnDataSource"},{"attributes":{},"id":"56c07c74-19ab-4e79-8a15-f987a877f032","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dca6e4ca-f066-49c3-a7c8-5b6fde681eb6","type":"Circle"},{"attributes":{"formatter":{"id":"84b5091d-df3c-4c0f-9467-3aeab3323a56","type":"BasicTickFormatter"},"plot":{"id":"599ac09a-bd2e-430c-a1e6-181452f4b507","subtype":"Figure","type":"Plot"},"ticker":{"id":"ac0f822f-031a-4ba0-92b1-fe0c3649bc04","type":"BasicTicker"}},"id":"8cfb1b06-e439-4252-81b7-be6a460cea00","type": ...

# %% [markdown]
# ## Plotting other glyph shapes

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create the plot
p = figure(plot_width=300, plot_height=300)

# add a line glyph
p.line(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4])

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="64851aef-8f3e-48b8-8fc6-02d80f52c422">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f7a9a686-4f3f-4987-9104-bdc95b9e0b83"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f7a9a686-4f3f-4987-9104-bdc95b9e0b83");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f7a9a686-4f3f-4987-9104-bdc95b9e0b83");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f7a9a686-4f3f-4987-9104-bdc95b9e0b83' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b3dd32b6-c931-4226-ba00-b19f80e6ab5a":{"roots":{"references":[{"attributes":{"plot":{"id":"0ea7da05-b052-4f15-bb05-001f862a7905","subtype":"Figure","type":"Plot"}},"id":"08f274f2-5893-41c0-8368-126e7c210d85","type":"ResetTool"},{"attributes":{"formatter":{"id":"431ecf9e-10b4-4e0b-9413-2f4e7392a95d","type":"BasicTickFormatter"},"plot":{"id":"0ea7da05-b052-4f15-bb05-001f862a7905","subtype":"Figure","type":"Plot"},"ticker":{"id":"fd8752f8-ffb1-4eec-9dbe-f153c4f2f321","type":"BasicTicker"}},"id":"bb9e6e97-f5c8-48eb-bb54-4feb22716c44","type":"LinearAxis"},{"attributes":{"plot":{"id":"0ea7da05-b052-4f15-bb05-001f862a7905","subtype":"Figure","type":"Plot"}},"id":"ed31a593-cb27-4a9d-a349-19379459677c","type":"SaveTool"},{"attributes":{"formatter":{"id":"58eec782-573d-4877-a4e5-e7f3e68f5b4f","type":"BasicTickFormatter"},"plot":{"id":"0ea7da05-b052-4f15-bb05-001f862a7905","subtype":"Figure","type":"Plot"},"ticker":{"id":"7c2859c8-d703-42d4-b800-642c1384b6cd","type":"BasicTicker"}},"id":"15f3bfe6-c9de-4f7b-8d5e-e478c895f50a","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0ecd8c78-9ea4-4bfe-bf88-51643d5119f1","type":"BoxAnnotation"},{"attributes":{},"id":"fd8752f8-ffb1-4eec-9dbe-f153c4f2f321","type":"BasicTicker"},{"attributes":{"plot":{"id":"0ea7da05-b052-4f15-bb05-001f862a7905","subtype":"Figure","type":"Plot"},"ticker":{"id":"fd8752f8-ffb1-4eec-9dbe-f153c4f2f321","type":"BasicTicker"}},"id":"84f3eff3-0996-4edd-82b6-0313a747d9b0","type":"Grid"},{"attributes":{"overlay":{"id":"0ecd8c78-9ea4-4bfe-bf88-51643d5119f1","type":"BoxAnnotation"},"plot":{"id":"0ea7da05-b052-4f15-bb05-001f862a7905","subtype":"Figure","type":"Plot"}},"id":"5a052754-3cf7-49c6-acd7-65753238bfa5","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"0ea7da05-b052-4f15-bb05-001f862a7905","subtype":"Figure","type":"Plot"}},"id":"b9d55047-424b-4350-840d-a1f5f9f867a0","type":"HelpTool"},{"attributes":{"plot":{"id":"0ea7da05-b052-4f15-bb05-001f862a7905","subtype":"Figure","type":"Plot"}},"id":"a54fa4d7-45aa-4271-93a0-f4afb7b01ef4","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"b12c1eb3-c084-4161-b94b-c34dc1fe9a7d","type":"ColumnDataSource"},{"attributes":{},"id":"431ecf9e-10b4-4e0b-9413-2f4e7392a95d","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"bb9e6e97-f5c8-48eb-bb54-4feb22716c44","type":"LinearAxis"}],"left":[{"id":"15f3bfe6-c9de-4f7b-8d5e-e478c895f50a","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"bb9e6e97-f5c8-48eb-bb54-4feb22716c44","type":"LinearAxis"},{"id":"84f3eff3-0996-4edd-82b6-0313a747d9b0","type":"Grid"},{"id":"15f3bfe6-c9de-4f7b-8d5e-e478c895f50a","type":"LinearAxis"},{"id":"7514f7ea-0eb5-4168-bb58-375b94ec1313","type":"Grid"},{"id":"0ecd8c78-9ea4-4bfe-bf88-51643d5119f1","type":"BoxAnnotation"},{"id":"4dca3d79-c193-460d-a74d-da29d6c71912","type":"GlyphRenderer"}],"title":{"id":"02653017-3c37-481f-81a4-2bc247f3b40b","type":"Title"},"tool_events":{"id":"e53cc1ae-fcf7-4b66-93bf-84f65eba9504","type":"ToolEvents"},"toolbar":{"id":"8739f7a4-871e-444e-8e37-98b1f81b475f","type":"Toolbar"},"x_range":{"id":"fd54fbd9-ca60-41ad-9788-4d0a2f760041","type":"DataRange1d"},"y_range":{"id":"7dceb875-7589-4096-a5ae-703cdbebed62","type":"DataRange1d"}},"id":"0ea7da05-b052-4f15-bb05-001f862a7905","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"e53cc1ae-fcf7-4b66-93bf-84f65eba9504","type":"ToolEvents"},{"attributes":{"callback":null},"id":"fd54fbd9-ca60-41ad-9788-4d0a2f760041","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"884f5471-1388-47c3-ad19-861e821 ...

# %% [markdown]
# ## Plotting Multiple Line Glyphs
# * Use **`p.line()`** twice to create two line glyphs
# * You can also use **`p.multi_line()`** and pass a list of lists as the x & y coordinates to create multiple lines.

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create the plot
p = figure(plot_width=300, plot_height=300)

# add multiple line glyph
p.line(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4])
p.line(x=[1, 2, 3, 4, 5, 6], y=[1, 1, 1, 1, 4, 6], color='red')

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4a298ad2-785c-45c8-b11b-344b615fb39d">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="85dec7ae-3dfc-42d0-9c9a-e482db8daf20"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("85dec7ae-3dfc-42d0-9c9a-e482db8daf20");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("85dec7ae-3dfc-42d0-9c9a-e482db8daf20");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '85dec7ae-3dfc-42d0-9c9a-e482db8daf20' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ad6c06f6-75db-4ee9-8dc2-e144f9e61281":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[1,1,1,1,4,6]}},"id":"767123ae-f673-4f8b-972f-0409a137a749","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"767123ae-f673-4f8b-972f-0409a137a749","type":"ColumnDataSource"},"glyph":{"id":"8ec52eef-1bcb-4abe-bd61-572812514c99","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"deb0c70b-5390-4837-9940-0608ec99a9c1","type":"Line"},"selection_glyph":null},"id":"4fa7d78b-fe32-4e6e-ba15-74d74d414a9e","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":""},"id":"28228371-a385-4fae-9c9f-7096c347ee5f","type":"Title"},{"attributes":{"plot":{"id":"daefbe5f-48eb-4169-bdbe-1c590a18c233","subtype":"Figure","type":"Plot"}},"id":"3034fbcd-6278-4aa2-99d8-1d67f1ce6932","type":"ResetTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"97ed4866-acba-47c6-99e8-272defe86565","type":"Line"},{"attributes":{"plot":{"id":"daefbe5f-48eb-4169-bdbe-1c590a18c233","subtype":"Figure","type":"Plot"}},"id":"fa78fd4c-054d-4481-b0d7-e0c2ec80024a","type":"HelpTool"},{"attributes":{},"id":"3de84c49-c87b-4885-b963-a123788982e9","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"deb0c70b-5390-4837-9940-0608ec99a9c1","type":"Line"},{"attributes":{},"id":"8e0746e4-be4d-4211-97a6-fd39ed2328f8","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"c5b4dc51-958b-45fe-814f-28e10431a6a4","type":"DataRange1d"},{"attributes":{"callback":null},"id":"5ba68144-718d-4b5b-93bb-ede368059ea9","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7cd0d2ef-84bf-4e7e-9857-8cdee4173f95","type":"PanTool"},{"id":"8cc58959-bb8b-45bf-baf7-5c1bc6a200d5","type":"WheelZoomTool"},{"id":"3986a9db-10fe-4c22-97b6-d5706708be53","type":"BoxZoomTool"},{"id":"46cfb9f3-6111-4fcd-8d93-b8aba1bff6e7","type":"SaveTool"},{"id":"3034fbcd-6278-4aa2-99d8-1d67f1ce6932","type":"ResetTool"},{"id":"fa78fd4c-054d-4481-b0d7-e0c2ec80024a","type":"HelpTool"}]},"id":"8d510c6a-a580-4808-a407-1c722806fcde","type":"Toolbar"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8ec52eef-1bcb-4abe-bd61-572812514c99","type":"Line"},{"attributes":{"below":[{"id":"08d76716-2520-4c34-accb-c175affda827","type":"LinearAxis"}],"left":[{"id":"3f3f4b1f-7d07-448e-b589-e9e00d01b61e","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"08d76716-2520-4c34-accb-c175affda827","type":"LinearAxis"},{"id":"ce223ae7-6fb5-4288-84d1-baf8ea7ff988","type":"Grid"},{"id":"3f3f4b1f-7d07-448e-b589-e9e00d01b61e","type":"LinearAxis"},{"id":"93ad91f0-016d-463a-bb0a-6a09eccedb3a","type":"Grid"},{"id":"58497451-ee46-41c2-9863-8a99bb1b7623","type":"BoxAnnotation"},{"id":"635dbc1f-3f80-451c-a37e-1bd654546a98","type":"GlyphRenderer"},{"id":"4fa7d78b-fe32-4e6e-ba15-74d74d414a9e","type":"GlyphRenderer"}],"title":{"id":"28228371-a385-4fae-9c9f-7096c347ee5f","type":"Title"},"tool_events":{"id":"3de84c49-c87b-4885-b963-a123788982e9","type":"ToolEvents"},"toolbar":{"id":"8d510c6a-a580-4808-a407-1c722806fcde","type":"Toolbar"},"x_range":{"id":"c5b4dc51-958b-45fe-814f-28e10431a6a4","type":"DataRange1d"},"y_range":{"id":"5ba68144-718d-4b5b-93bb-ede368059ea9","type":"DataRange1d"}},"id":"daefbe5f-48eb-4169-bdbe-1c590a18c233","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"325c33c6-8da2-44b0-b708-aaaeac147b73","type":"BasicTickFormatter"},"plot":{"id":"daefbe5f-48eb-4169-bdbe-1c590a18c233","subtype":"Figure","type":"Plot"},"ticker":{"id":"5071d2a0-885b-4f67-a377-fa503a3b0445","type":"BasicTicker"}},"id":"3f3f4b1f-7d07-448e-b589-e9e00d01b61e","type":"LinearAxis"},{"attributes":{},"id":"325c33c6-8da2-44b0-b708-aaaeac147b73","type":"BasicTickFormatter"},{"attribute ...

# %% [markdown]
# ## Creating Patch Glyphs
# * patches are single polygonal patch shapes created from a sequence of x and y coordinates
# * The patch glyph will automatically connect the first point and the last point.
# * Use **`patches()`** and pass a list of lists to create multiple patch glyphs in one line.

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create the plot
p = figure(plot_width=300, plot_height=300)

# add multiple line glyph
p.patch(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4], alpha=0.5)
p.patch(x=[1, 2, 3, 4, 5, 6], y=[1, 1, 1, 1, 4, 6], alpha=0.5, color='red')

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="645c4be6-a0cf-4bc1-9c89-0efc64c50c65">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f1122e93-15be-48db-95c6-2d20c5688a0f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f1122e93-15be-48db-95c6-2d20c5688a0f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f1122e93-15be-48db-95c6-2d20c5688a0f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f1122e93-15be-48db-95c6-2d20c5688a0f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0d4f3ba8-4768-42de-a0a2-6146b63a3233":{"roots":{"references":[{"attributes":{"plot":{"id":"ceed1a30-b7b0-46e8-8ce5-ffed2294fccc","subtype":"Figure","type":"Plot"}},"id":"219572b4-02b5-4c39-8135-63e80ca2a8f7","type":"SaveTool"},{"attributes":{"plot":{"id":"ceed1a30-b7b0-46e8-8ce5-ffed2294fccc","subtype":"Figure","type":"Plot"}},"id":"6086bebc-77ed-448d-a185-773795cbb51a","type":"ResetTool"},{"attributes":{"plot":{"id":"ceed1a30-b7b0-46e8-8ce5-ffed2294fccc","subtype":"Figure","type":"Plot"}},"id":"48df00b3-c884-482d-9e97-178ca60c4d89","type":"HelpTool"},{"attributes":{"data_source":{"id":"793e33fc-c6e0-4533-9bef-5350441c837f","type":"ColumnDataSource"},"glyph":{"id":"d831fda9-93d8-46f5-bda8-7178ea9b2282","type":"Patch"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f469c173-33ad-4c0f-850c-6a3dcd6f4f32","type":"Patch"},"selection_glyph":null},"id":"cf91e0c2-6003-4c98-b05b-47f10705cc24","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c7c1725e-7590-46c1-be51-af21796fa8fd","type":"Patch"},{"attributes":{},"id":"e61d3d93-b314-46ee-9730-8370b918c27f","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"red"},"line_alpha":{"value":0.5},"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"af591036-3975-47b9-b91a-df169f10e1d8","type":"Patch"},{"attributes":{"data_source":{"id":"6f6204a0-cb79-4c27-9b1a-3c883f7e23db","type":"ColumnDataSource"},"glyph":{"id":"af591036-3975-47b9-b91a-df169f10e1d8","type":"Patch"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c7c1725e-7590-46c1-be51-af21796fa8fd","type":"Patch"},"selection_glyph":null},"id":"44eae694-154c-45b9-95ba-a3062b0b0daf","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"193e3579-4141-4d6d-902e-07222d9de0e9","type":"DataRange1d"},{"attributes":{},"id":"cca11cb3-6595-49f1-a528-f6e012588b2b","type":"BasicTickFormatter"},{"attributes":{},"id":"cac3e7dc-81c1-448d-87a2-404819de4a4a","type":"ToolEvents"},{"attributes":{"plot":null,"text":""},"id":"34159080-33cf-4142-889d-3d60d314d8f2","type":"Title"},{"attributes":{},"id":"fc6de37b-95c4-4584-b769-8aa4b6f477cf","type":"BasicTicker"},{"attributes":{"plot":{"id":"ceed1a30-b7b0-46e8-8ce5-ffed2294fccc","subtype":"Figure","type":"Plot"},"ticker":{"id":"fc6de37b-95c4-4584-b769-8aa4b6f477cf","type":"BasicTicker"}},"id":"e898af31-3e0b-431e-9e70-f9f435cd354d","type":"Grid"},{"attributes":{"formatter":{"id":"cca11cb3-6595-49f1-a528-f6e012588b2b","type":"BasicTickFormatter"},"plot":{"id":"ceed1a30-b7b0-46e8-8ce5-ffed2294fccc","subtype":"Figure","type":"Plot"},"ticker":{"id":"1ab2520a-f593-4a29-a2fb-156d5ce5e16c","type":"BasicTicker"}},"id":"f421fbff-f15c-4bdc-b4ec-8e71bc5cf806","type":"LinearAxis"},{"attributes":{},"id":"1ab2520a-f593-4a29-a2fb-156d5ce5e16c","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"ceed1a30-b7b0-46e8-8ce5-ffed2294fccc","subtype":"Figure","type":"Plot"},"ticker":{"id":"1ab2520a-f593-4a29-a2fb-156d5ce5e16c","type":"BasicTicker"}},"id":"9e273675-9507-4e72-9159-eee38bd9fed8","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b67bf9de-9860-44ec-be55-1d9b54469ac9","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5296678d-fa18-48b2-8312-3b98cbc88a18","type":"PanTool"},{"id":"0bde6e77-e94e-461f-bc0c-dad5ac46de7a","type":"WheelZoomTool"},{"id":"82f89c27-3ef7-4fd7-9200-8546e7bb7eb9","type":"BoxZoomTool"},{"id":"219572b4-02b5-4c39-8135-63e80ca2a8f7","type":"SaveTool"},{"id":"6086be ...
