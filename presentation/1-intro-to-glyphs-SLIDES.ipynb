# %% [markdown]
# ## Where to start?
# - The **`bokeh.plotting`** API is a great balance between ease of use and customization

# %% [markdown]
# ### Other Options
# - **`bokeh.models`**
#     - low level plotting with high degree of customization.
# - **`bokeh.charts`**
#     - high level plotting that is very easy to use with less customization.
#     - Easy to generate charts quickly.

# %% [markdown]
# ### bokeh.plotting
#
# * centered around the **`figure()`** method.
#     * basic empty plot with default values.

# %% [markdown]
# ## Base figure
# * Need three items:
#     * figure()
#     * output_notebook() or output_file()
#     * show()

# %%
# base figure with no data input
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure()
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a63d3932-45eb-435a-8164-780b141291b3">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6bf8f25a-00ea-4bfb-b82a-d696b318c514"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6bf8f25a-00ea-4bfb-b82a-d696b318c514");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6bf8f25a-00ea-4bfb-b82a-d696b318c514");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6bf8f25a-00ea-4bfb-b82a-d696b318c514' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"15757caa-a67e-4de0-8a88-94459b707fc8":{"roots":{"references":[{"attributes":{"formatter":{"id":"abf2f3a4-9ab6-46bf-9616-30d61f70d00c","type":"BasicTickFormatter"},"plot":{"id":"4591948b-23b3-4515-8060-ff4ace9646f8","subtype":"Figure","type":"Plot"},"ticker":{"id":"8fb76d7a-0aad-4bd2-aac1-8399db89b03c","type":"BasicTicker"}},"id":"f2b348b9-4aa8-4116-b20f-2f8ee99a8e1f","type":"LinearAxis"},{"attributes":{},"id":"78cc5850-4067-4cbd-8d18-e5a183dc7804","type":"ToolEvents"},{"attributes":{},"id":"8fb76d7a-0aad-4bd2-aac1-8399db89b03c","type":"BasicTicker"},{"attributes":{"plot":{"id":"4591948b-23b3-4515-8060-ff4ace9646f8","subtype":"Figure","type":"Plot"},"ticker":{"id":"b1e08b2e-2959-4f31-9810-09afdeb5f2ac","type":"BasicTicker"}},"id":"46f84719-3669-45ba-aec9-b8cd092de889","type":"Grid"},{"attributes":{"callback":null},"id":"7da20fa6-09ea-48bd-a1a1-54a52896e0cb","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"4591948b-23b3-4515-8060-ff4ace9646f8","subtype":"Figure","type":"Plot"},"ticker":{"id":"8fb76d7a-0aad-4bd2-aac1-8399db89b03c","type":"BasicTicker"}},"id":"effa3428-293c-4a12-ada2-5e68170f22b3","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ffe5c11d-1c96-415d-bb4c-699a315eafcb","type":"BoxAnnotation"},{"attributes":{"plot":null,"text":""},"id":"f9f209af-70cb-4179-9a16-734046f3ea39","type":"Title"},{"attributes":{"plot":{"id":"4591948b-23b3-4515-8060-ff4ace9646f8","subtype":"Figure","type":"Plot"}},"id":"ee5afcdd-03b5-4521-923d-57c13b62223b","type":"PanTool"},{"attributes":{},"id":"b1e08b2e-2959-4f31-9810-09afdeb5f2ac","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ee5afcdd-03b5-4521-923d-57c13b62223b","type":"PanTool"},{"id":"0e1ec46b-88fc-4dca-aec3-53d8a79b2503","type":"WheelZoomTool"},{"id":"52403259-fb92-4537-97d5-66ec2ac92ca5","type":"BoxZoomTool"},{"id":"2064e710-3436-4dc7-b794-9e7fc3ee554d","type":"SaveTool"},{"id":"41d8a4d3-a7c4-4b8d-a54c-ff85d3dfef54","type":"ResetTool"},{"id":"f40560aa-16ec-4aba-bdea-34c912c843b8","type":"HelpTool"}]},"id":"fdd12c00-04bb-4ae8-a34d-1bc47a81617a","type":"Toolbar"},{"attributes":{},"id":"a1036c05-94d4-43d8-9924-ba527d7cc7e5","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"4cfa3b17-02d9-4193-93d8-ec5897687720","type":"DataRange1d"},{"attributes":{"plot":{"id":"4591948b-23b3-4515-8060-ff4ace9646f8","subtype":"Figure","type":"Plot"}},"id":"0e1ec46b-88fc-4dca-aec3-53d8a79b2503","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"ffe5c11d-1c96-415d-bb4c-699a315eafcb","type":"BoxAnnotation"},"plot":{"id":"4591948b-23b3-4515-8060-ff4ace9646f8","subtype":"Figure","type":"Plot"}},"id":"52403259-fb92-4537-97d5-66ec2ac92ca5","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"a1036c05-94d4-43d8-9924-ba527d7cc7e5","type":"BasicTickFormatter"},"plot":{"id":"4591948b-23b3-4515-8060-ff4ace9646f8","subtype":"Figure","type":"Plot"},"ticker":{"id":"b1e08b2e-2959-4f31-9810-09afdeb5f2ac","type":"BasicTicker"}},"id":"2a8e2a9d-cea0-4c7c-bb32-bcde4ed9f06e","type":"LinearAxis"},{"attributes":{"plot":{"id":"4591948b-23b3-4515-8060-ff4ace9646f8","subtype":"Figure","type":"Plot"}},"id":"2064e710-3436-4dc7-b794-9e7fc3ee554d","type":"SaveTool"},{"attributes":{"plot":{"id":"4591948b-23b3-4515-8060-ff4ace9646f8","subtype":"Figure","type":"Plot"}},"id":"41d8a4d3-a7c4-4b8d-a54c-ff85d3dfef54","type":"ResetTool"},{"attributes":{"plot":{"id":"4591948b-23b3-4515-8060-ff4ace9646f8","subtype":"Figure","type":"Plot"}},"id":"f40560aa-16ec-4aba-bdea-34c912c843b8","type":"HelpTool"},{"attributes":{},"id":"abf2f3a4-9ab6-46bf-9616-30d61f70d00c","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"2 ...

# %% [markdown]
# <img src="../images/blank-figure.png">

# %% [markdown]
# ## Modifying the Figure Size
# * **`plot_height`** & **`plot_width`**

# %%
# Making the chart a bit smaller so we don't take up so much real estate
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure(plot_width=300, plot_height=300)
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1ee8ccc5-8c21-4ee6-b432-c0e1db98760b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a9126e28-410f-4013-8a45-4fe9d54d0acd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a9126e28-410f-4013-8a45-4fe9d54d0acd");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a9126e28-410f-4013-8a45-4fe9d54d0acd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a9126e28-410f-4013-8a45-4fe9d54d0acd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bda58bdd-8ad2-48e5-85db-f192a0ee9926":{"roots":{"references":[{"attributes":{"plot":{"id":"6aeb73d3-d623-4c30-9f93-077d6655d231","subtype":"Figure","type":"Plot"}},"id":"b342e1be-7399-4330-b2ab-b2cfebd1c196","type":"PanTool"},{"attributes":{"plot":{"id":"6aeb73d3-d623-4c30-9f93-077d6655d231","subtype":"Figure","type":"Plot"}},"id":"a755c453-2df1-4db6-ae18-2c507d14ebdf","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ae3a0c9e-0fd6-4289-808e-06d163b3b493","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"6aeb73d3-d623-4c30-9f93-077d6655d231","subtype":"Figure","type":"Plot"}},"id":"bd371a70-b676-4b08-8c06-befb2e0e94c9","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"6aeb73d3-d623-4c30-9f93-077d6655d231","subtype":"Figure","type":"Plot"}},"id":"6c70f6a0-62d7-4e36-bca7-ad69bc35d230","type":"ResetTool"},{"attributes":{"overlay":{"id":"ae3a0c9e-0fd6-4289-808e-06d163b3b493","type":"BoxAnnotation"},"plot":{"id":"6aeb73d3-d623-4c30-9f93-077d6655d231","subtype":"Figure","type":"Plot"}},"id":"5dd93f78-0746-468f-920b-dba764b1ff5d","type":"BoxZoomTool"},{"attributes":{},"id":"14c1e6ef-ff3d-4415-a755-a421e77e8d95","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"92265d53-9e65-4bd8-9cbf-350331be52c4","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"6aeb73d3-d623-4c30-9f93-077d6655d231","subtype":"Figure","type":"Plot"},"ticker":{"id":"7f13e4bf-1294-48a2-84ea-bd73119888e1","type":"BasicTicker"}},"id":"7024657b-3f7c-4ec0-93a9-7879826ab77e","type":"Grid"},{"attributes":{},"id":"b111d2f2-24cd-425e-87fd-726154c4f9d5","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"6aeb73d3-d623-4c30-9f93-077d6655d231","subtype":"Figure","type":"Plot"},"ticker":{"id":"31b74b70-565f-4d56-ba34-5da87f57d5cd","type":"BasicTicker"}},"id":"8326de95-e119-4e92-bdbf-787d15231d43","type":"Grid"},{"attributes":{"callback":null},"id":"77655083-bbe0-4106-a774-bf02f2b8bb7c","type":"DataRange1d"},{"attributes":{"formatter":{"id":"14c1e6ef-ff3d-4415-a755-a421e77e8d95","type":"BasicTickFormatter"},"plot":{"id":"6aeb73d3-d623-4c30-9f93-077d6655d231","subtype":"Figure","type":"Plot"},"ticker":{"id":"7f13e4bf-1294-48a2-84ea-bd73119888e1","type":"BasicTicker"}},"id":"e9b16864-4c17-4008-afa7-74875b85da50","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b342e1be-7399-4330-b2ab-b2cfebd1c196","type":"PanTool"},{"id":"bd371a70-b676-4b08-8c06-befb2e0e94c9","type":"WheelZoomTool"},{"id":"5dd93f78-0746-468f-920b-dba764b1ff5d","type":"BoxZoomTool"},{"id":"a755c453-2df1-4db6-ae18-2c507d14ebdf","type":"SaveTool"},{"id":"6c70f6a0-62d7-4e36-bca7-ad69bc35d230","type":"ResetTool"},{"id":"3ce33749-8e33-498e-bdb3-4a7908bb6c68","type":"HelpTool"}]},"id":"595c8f1f-c589-4c1f-ba87-f4a3764dc012","type":"Toolbar"},{"attributes":{},"id":"791196e2-a2d4-44a6-aeb5-3b5d45d05d04","type":"ToolEvents"},{"attributes":{},"id":"7f13e4bf-1294-48a2-84ea-bd73119888e1","type":"BasicTicker"},{"attributes":{"plot":{"id":"6aeb73d3-d623-4c30-9f93-077d6655d231","subtype":"Figure","type":"Plot"}},"id":"3ce33749-8e33-498e-bdb3-4a7908bb6c68","type":"HelpTool"},{"attributes":{"below":[{"id":"fe37a302-9e8e-4adb-af69-28362cb20c59","type":"LinearAxis"}],"left":[{"id":"e9b16864-4c17-4008-afa7-74875b85da50","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"fe37a302-9e8e-4adb-af69-28362cb20c59","type":"LinearAxis"},{"id":"8326de95-e119-4e92-bdbf-787d15231d43","type":"Grid"},{"id":"e9b16864-4c17-4008-afa7-74875b85da50","type":"LinearAxis"},{"id":"7024657b-3f7c-4ec0-93a9-7879826ab77e","type":"Grid"},{"id":"ae3a0c9e-0fd6-4289-808e-06d163b3b493","type":"BoxAnnotation"}],"title ...

# %% [markdown]
# <img src="../images/blank-figure-small.png">

# %% [markdown]
# ## Introduction to Glyphs
# Bokeh uses **`"Glyphs"`** which are the base visual structures to overlay on top of any plots.

# %% [markdown]
# - glyphs add visual shapes to the empty **`figure()`** plot

# %% [markdown]
# - glyphs can take on a number of different shapes
#     - i.e. circle, diamond, arc, asterisk, patch, cross, etc.

# %% [markdown]
# - visual shapes can be customized by modifying glyph properties
#     - i.e. color, alpha, size, radius, angle, hover_color, etc.

# %% [markdown]
# ## Adding a Single Circle Glyph
# * Added a circle glyph with **`p.circle()`** to the plot **`p`**
# * defined the x and y coordinate values within **`p.circle()`**
# * **`output_notebook()`** and **`show(p)`**

# %%
# base figure with one circle glyph
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure(plot_width=300, plot_height=300)
p.circle(x=5, y=10)
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="22ac1f7f-30a1-43fd-90ba-7ad0ff249d99">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8b765071-0a55-4cef-a869-f99c2433346c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8b765071-0a55-4cef-a869-f99c2433346c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8b765071-0a55-4cef-a869-f99c2433346c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8b765071-0a55-4cef-a869-f99c2433346c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9074c8b4-8485-420c-94c3-e4fb47b7838d":{"roots":{"references":[{"attributes":{"data_source":{"id":"b23a2d73-c98f-40e6-bf85-f5d113ea7e58","type":"ColumnDataSource"},"glyph":{"id":"29f29af1-e23b-4406-8262-f1a91b142f69","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"fec95465-9da6-4a76-9f60-8f476b9e10b4","type":"Circle"},"selection_glyph":null},"id":"b18f713a-ea5e-48a2-8008-44f43e734a39","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"c0ad3c9a-5ad1-46c1-b2e5-c84857c24657","subtype":"Figure","type":"Plot"}},"id":"b5047342-6b71-40fb-95b9-626a678e38c9","type":"SaveTool"},{"attributes":{"plot":null,"text":""},"id":"3ce8df60-a020-443e-b65f-7f25f0232cff","type":"Title"},{"attributes":{"plot":{"id":"c0ad3c9a-5ad1-46c1-b2e5-c84857c24657","subtype":"Figure","type":"Plot"}},"id":"45dcd583-6cae-41b7-91f3-3180f0cfc328","type":"ResetTool"},{"attributes":{"callback":null},"id":"3649f294-5006-4390-962b-f083bb0f7bd0","type":"DataRange1d"},{"attributes":{"formatter":{"id":"ca5c87dc-afc5-4e0c-8b90-90e25c6c2c01","type":"BasicTickFormatter"},"plot":{"id":"c0ad3c9a-5ad1-46c1-b2e5-c84857c24657","subtype":"Figure","type":"Plot"},"ticker":{"id":"a652c2d0-8f99-4aa1-b8f1-74f0c9ba5e56","type":"BasicTicker"}},"id":"062d896a-db8c-4b97-832f-ee5f7ffd3237","type":"LinearAxis"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"value":5},"y":{"value":10}},"id":"29f29af1-e23b-4406-8262-f1a91b142f69","type":"Circle"},{"attributes":{"plot":{"id":"c0ad3c9a-5ad1-46c1-b2e5-c84857c24657","subtype":"Figure","type":"Plot"},"ticker":{"id":"a652c2d0-8f99-4aa1-b8f1-74f0c9ba5e56","type":"BasicTicker"}},"id":"53217f8a-4c9d-47af-9833-435de4d49f33","type":"Grid"},{"attributes":{"plot":{"id":"c0ad3c9a-5ad1-46c1-b2e5-c84857c24657","subtype":"Figure","type":"Plot"}},"id":"73e9e38e-3152-408f-9a46-ab100471eddf","type":"PanTool"},{"attributes":{},"id":"a652c2d0-8f99-4aa1-b8f1-74f0c9ba5e56","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"value":5},"y":{"value":10}},"id":"fec95465-9da6-4a76-9f60-8f476b9e10b4","type":"Circle"},{"attributes":{"callback":null,"data":{}},"id":"b23a2d73-c98f-40e6-bf85-f5d113ea7e58","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"c0ad3c9a-5ad1-46c1-b2e5-c84857c24657","subtype":"Figure","type":"Plot"},"ticker":{"id":"7e127249-537b-4569-b0bf-ac3ffb6205ce","type":"BasicTicker"}},"id":"93e0c410-1a4d-4b1e-809d-13fbd24ee3ea","type":"Grid"},{"attributes":{},"id":"7e127249-537b-4569-b0bf-ac3ffb6205ce","type":"BasicTicker"},{"attributes":{},"id":"1c76f688-27fb-4b04-adf4-85e9dad7d6c1","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e0fca1a1-af6e-4c28-91da-9e81202ff73c","type":"BoxAnnotation"},{"attributes":{},"id":"cf523016-1fce-4840-ac9e-e924504eee56","type":"ToolEvents"},{"attributes":{},"id":"ca5c87dc-afc5-4e0c-8b90-90e25c6c2c01","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"e0fca1a1-af6e-4c28-91da-9e81202ff73c","type":"BoxAnnotation"},"plot":{"id":"c0ad3c9a-5ad1-46c1-b2e5-c84857c24657","subtype":"Figure","type":"Plot"}},"id":"730b5882-a33e-430a-afb0-f0a1fcd4dd7b","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"1c76f688-27fb-4b04-adf4-85e9dad7d6c1","type":"BasicTickFormatter"},"plot":{"id":"c0ad3c9a-5ad1-46c1-b2e5-c84857c24657","subtype":"Figure","type":"Plot"},"ticker":{"id":"7e127249-537b-4569-b0bf-ac3ffb6205ce","type":"BasicTicker"}},"id":"d7858aab-f39e-4bb5-8703-ac9b6ac59e29","type":"LinearAxis"},{"attributes":{"plot":{"id":"c0ad3c9a-5ad1-46c1-b2e5-c84857c24657","subtype":"Figure","type":"Plot"}},"id" ...

# %% [markdown]
# <img src="../images/single-glyph.png">

# %% [markdown]
# ## Passing Lists of Values

# %%
# base figure with one multiple circle points
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure(plot_width=300, plot_height=300)
p.circle(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4])
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="48b06c00-7184-4c38-9dfe-c7a1934a8092">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e29ef317-28e0-4f34-a002-e7e4cabc9bda"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e29ef317-28e0-4f34-a002-e7e4cabc9bda");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e29ef317-28e0-4f34-a002-e7e4cabc9bda");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e29ef317-28e0-4f34-a002-e7e4cabc9bda' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"39a0644b-ea4c-455e-ac57-849c5129833e":{"roots":{"references":[{"attributes":{"formatter":{"id":"bdc969b9-093f-4ef6-8497-a5f882bce6fb","type":"BasicTickFormatter"},"plot":{"id":"1c9c847c-f39b-4d02-94ac-c1e892852128","subtype":"Figure","type":"Plot"},"ticker":{"id":"d685b43d-caa9-4dcb-ad4c-f9661a2ad2f3","type":"BasicTicker"}},"id":"a70bb8ab-9a77-4f30-ad1a-20379617bb6c","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"9128984e-cbf7-402f-95b8-4d3a3a3caa30","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"e567a7be-f868-4638-9053-9760ab7a1ca2","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"dd29859b-bde0-4fc4-bc0f-42f80c0a995d","type":"PanTool"},{"id":"a1186102-54c5-40e5-9014-4ae02dfd8209","type":"WheelZoomTool"},{"id":"194c6d47-901f-44b4-8ae3-e29d99d985df","type":"BoxZoomTool"},{"id":"f7f792b4-85a0-4eca-92bc-3e74ccc33e49","type":"SaveTool"},{"id":"3814ade1-f76b-4f85-a778-b006cd7b4527","type":"ResetTool"},{"id":"bf3f044b-8717-46ff-8474-bb6b30d5b06a","type":"HelpTool"}]},"id":"11f3b335-9592-4be3-a5b6-eaf2f821929a","type":"Toolbar"},{"attributes":{},"id":"d685b43d-caa9-4dcb-ad4c-f9661a2ad2f3","type":"BasicTicker"},{"attributes":{"data_source":{"id":"9128984e-cbf7-402f-95b8-4d3a3a3caa30","type":"ColumnDataSource"},"glyph":{"id":"249f91b9-6bca-400d-a5ff-6b8e053587be","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b0d25a9e-9d4a-40cd-9ef6-d6163332340e","type":"Circle"},"selection_glyph":null},"id":"b93b58d2-16e3-4784-a969-8d768c293f13","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"5bc56fff-83cf-4809-b42a-6083073f7956","type":"BasicTickFormatter"},"plot":{"id":"1c9c847c-f39b-4d02-94ac-c1e892852128","subtype":"Figure","type":"Plot"},"ticker":{"id":"0f8c9121-d341-4edc-be81-f0997794ee01","type":"BasicTicker"}},"id":"bbeabe8a-6a8f-4880-afa0-c5d5171fe94a","type":"LinearAxis"},{"attributes":{"plot":{"id":"1c9c847c-f39b-4d02-94ac-c1e892852128","subtype":"Figure","type":"Plot"},"ticker":{"id":"d685b43d-caa9-4dcb-ad4c-f9661a2ad2f3","type":"BasicTicker"}},"id":"981358f3-cbc8-414b-887b-fee036de96c9","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"fd9147ea-cad5-4ee1-aa2e-f979cdc01f15","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"1c9c847c-f39b-4d02-94ac-c1e892852128","subtype":"Figure","type":"Plot"},"ticker":{"id":"0f8c9121-d341-4edc-be81-f0997794ee01","type":"BasicTicker"}},"id":"10605ed8-5805-4a42-a9a4-5afd2fc141e3","type":"Grid"},{"attributes":{"plot":{"id":"1c9c847c-f39b-4d02-94ac-c1e892852128","subtype":"Figure","type":"Plot"}},"id":"dd29859b-bde0-4fc4-bc0f-42f80c0a995d","type":"PanTool"},{"attributes":{},"id":"0f8c9121-d341-4edc-be81-f0997794ee01","type":"BasicTicker"},{"attributes":{"overlay":{"id":"cde02b0f-62a2-467b-9455-3d5c05ee9bee","type":"BoxAnnotation"},"plot":{"id":"1c9c847c-f39b-4d02-94ac-c1e892852128","subtype":"Figure","type":"Plot"}},"id":"194c6d47-901f-44b4-8ae3-e29d99d985df","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cde02b0f-62a2-467b-9455-3d5c05ee9bee","type":"BoxAnnotation"},{"attributes":{},"id":"5bc56fff-83cf-4809-b42a-6083073f7956","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b0d25a9e-9d4a-40cd-9ef6-d6163332340e","type":"Circle"},{"attributes":{"plot":{"id":"1c9c847c-f39b-4d02-94ac-c1e892852128","subtype":"Figure","type":"Plot"}},"id":"a1186102-54c5-40e5-9014-4ae02dfd8209","type":"WheelZoomTool"},{"attri ...

# %% [markdown]
# <img src="../images/list-glyph.png">

# %% [markdown]
# ## Default Figure Properties
# * Axes automatically fit the data points
# * Figure attributes take on default values that can be modified
# * Glyphs are assigned default values that can be modified

# %% [markdown]
# ## Modifying Glyph Properties
# * Properties can take single fixed values or any valid sequence of values
# * Three common properties we modify are as follows:

# %% [markdown]
# ### size
# - modifies the diameter of the circle you create for **`p.circle()`**

# %% [markdown]
# ### alpha
# - A value from 0 to 1 indicating the level of transparency of the glyph
#     - 0 being fully transparent and 1 being completely non-transparent

# %% [markdown]
# ### color
# - Color value of the glyph.
#     - Can take a Xterm 256 values, Hex values and other color palettes.

# %% [markdown]
# ## Modifying Size, Alpha & Color

# %%
# base figure with one multiple circle points
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

p = figure(plot_width=300, plot_height=300)

p.circle(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4],
         size=10, alpha=0.3, color='firebrick')

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="988cc9d7-13d7-4bad-a12a-114255c69126">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d66d4654-5fa7-46d4-a0b2-06cf5780adad"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d66d4654-5fa7-46d4-a0b2-06cf5780adad");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d66d4654-5fa7-46d4-a0b2-06cf5780adad");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd66d4654-5fa7-46d4-a0b2-06cf5780adad' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"10df8b33-560a-49c4-aa21-3adf72a59cc5":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a02cd369-c75a-4516-85e8-3e1b15995442","type":"PanTool"},{"id":"2753c406-907e-478b-b48e-cadcc79c15ac","type":"WheelZoomTool"},{"id":"85c9f6ad-9bf1-4809-8dfa-b7ac7e76ead5","type":"BoxZoomTool"},{"id":"3233aa6b-37d9-4f6b-9c62-d7df05cf797c","type":"SaveTool"},{"id":"2371b3b3-88ff-49a6-914b-0a83bb989491","type":"ResetTool"},{"id":"b51ac067-6882-46e9-abe9-924d9fa3d1e2","type":"HelpTool"}]},"id":"37fb630b-ef23-4053-a0f6-cc3519c0e012","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"50a3d64f-51fc-469e-9455-1e99f330e3fc","type":"ColumnDataSource"},{"attributes":{},"id":"14380265-d865-45ea-9b41-2d36d37f65c2","type":"BasicTicker"},{"attributes":{},"id":"12302370-ba78-4a0d-948d-b919960b0c47","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.3},"fill_color":{"value":"firebrick"},"line_alpha":{"value":0.3},"line_color":{"value":"firebrick"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"8c0258e0-e655-4316-95ec-e8c4c197f090","type":"Circle"},{"attributes":{"below":[{"id":"80c58191-0c9a-4054-8de9-521bb3038e06","type":"LinearAxis"}],"left":[{"id":"a0e4b1e7-4a95-4fb0-89e9-7b7a5ff2699e","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"80c58191-0c9a-4054-8de9-521bb3038e06","type":"LinearAxis"},{"id":"d8dca994-9fc2-4263-aaab-f81e430ab69f","type":"Grid"},{"id":"a0e4b1e7-4a95-4fb0-89e9-7b7a5ff2699e","type":"LinearAxis"},{"id":"fa265d44-22b1-4583-af81-2a0bb346956b","type":"Grid"},{"id":"341414ba-c8cf-4c1a-828b-ecba7326d0cd","type":"BoxAnnotation"},{"id":"4dae7f7b-bd6b-4248-939c-4e11ab42ff7f","type":"GlyphRenderer"}],"title":{"id":"60426a87-77c4-4a74-a7ff-ee162b999c46","type":"Title"},"tool_events":{"id":"07ef0371-8027-4529-8195-f32b05b32d9c","type":"ToolEvents"},"toolbar":{"id":"37fb630b-ef23-4053-a0f6-cc3519c0e012","type":"Toolbar"},"x_range":{"id":"38db69b9-5f60-4eda-bf60-50e0bb9c9324","type":"DataRange1d"},"y_range":{"id":"07ff46d9-ddb4-4100-82db-425f759042ec","type":"DataRange1d"}},"id":"0ec97727-05a6-45ef-a43a-d37cd2c488d7","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"07ef0371-8027-4529-8195-f32b05b32d9c","type":"ToolEvents"},{"attributes":{"callback":null},"id":"38db69b9-5f60-4eda-bf60-50e0bb9c9324","type":"DataRange1d"},{"attributes":{"data_source":{"id":"50a3d64f-51fc-469e-9455-1e99f330e3fc","type":"ColumnDataSource"},"glyph":{"id":"8c0258e0-e655-4316-95ec-e8c4c197f090","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4eca4ada-8d87-4d19-a4ac-ef3c5d23f4a0","type":"Circle"},"selection_glyph":null},"id":"4dae7f7b-bd6b-4248-939c-4e11ab42ff7f","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"29e18135-43fe-479c-91c7-dafb76289108","type":"BasicTickFormatter"},"plot":{"id":"0ec97727-05a6-45ef-a43a-d37cd2c488d7","subtype":"Figure","type":"Plot"},"ticker":{"id":"12302370-ba78-4a0d-948d-b919960b0c47","type":"BasicTicker"}},"id":"80c58191-0c9a-4054-8de9-521bb3038e06","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"0ec97727-05a6-45ef-a43a-d37cd2c488d7","subtype":"Figure","type":"Plot"},"ticker":{"id":"14380265-d865-45ea-9b41-2d36d37f65c2","type":"BasicTicker"}},"id":"fa265d44-22b1-4583-af81-2a0bb346956b","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"341414ba-c8cf-4c1a-828b-ecba7326d0cd","type":"BoxAnnotation"},{"attributes":{},"id":"29e18135-43fe-479c-91c7-dafb76289108","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f7 ...

# %% [markdown]
# <img src="../images/list.png">

# %% [markdown]
# ## Using Lists to Modify Glyph Properties

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create lists for the properties to modify
color_list = ['firebrick', 'wheat', 'blue', 'darkcyan', 'aqua', 'magenta']
size_list = [4, 6, 8, 12, 18, 24]
alpha_list = [1, 1, 0.8, 0.6, 0.4, 0.2]

# create the plot
p = figure(plot_width=300, plot_height=300)

# add the circle glyph
p.circle(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4],
         size=size_list, alpha=alpha_list, color=color_list)

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6a26be03-ea98-4437-ac10-609eca1be21e">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7ad3e7a2-efca-470b-850a-586302df0ce1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7ad3e7a2-efca-470b-850a-586302df0ce1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7ad3e7a2-efca-470b-850a-586302df0ce1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7ad3e7a2-efca-470b-850a-586302df0ce1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"38679fbc-1bda-40e2-86b7-f8b402036100":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"08a278c9-a189-4769-af2e-07d2870854ab","type":"Title"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"fill_color"},"line_alpha":{"field":"line_alpha"},"line_color":{"field":"line_color"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5e2b88e3-cd45-4bd7-adc5-175f606d27b7","type":"Circle"},{"attributes":{"below":[{"id":"d3666e30-4c55-4301-bfcd-2041be8ae0f4","type":"LinearAxis"}],"left":[{"id":"8b87cf74-5d74-4a12-a587-7251c286a589","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"d3666e30-4c55-4301-bfcd-2041be8ae0f4","type":"LinearAxis"},{"id":"27653296-29ad-4b98-b2e1-bb850d46ee49","type":"Grid"},{"id":"8b87cf74-5d74-4a12-a587-7251c286a589","type":"LinearAxis"},{"id":"6582a42c-c40d-44ec-97ad-2b46538f9cca","type":"Grid"},{"id":"63b4df20-6136-4eb4-9fa4-43b4cec3d2d4","type":"BoxAnnotation"},{"id":"567670ff-17fe-48ff-a79f-092a8385826a","type":"GlyphRenderer"}],"title":{"id":"08a278c9-a189-4769-af2e-07d2870854ab","type":"Title"},"tool_events":{"id":"2359eaa4-262c-4120-b7c7-00e85e6c5c82","type":"ToolEvents"},"toolbar":{"id":"370dced0-7ad2-47af-b096-849729fd32a6","type":"Toolbar"},"x_range":{"id":"89fcb189-0189-441b-bf51-b8a03427bb5a","type":"DataRange1d"},"y_range":{"id":"6668c443-0514-460c-9b35-ad8ec687ce18","type":"DataRange1d"}},"id":"3d8ca1b2-29be-40a8-8b95-495576c024c9","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["size","x","y","fill_color","line_color","fill_alpha","line_alpha"],"data":{"fill_alpha":[1,1,0.8,0.6,0.4,0.2],"fill_color":["firebrick","wheat","blue","darkcyan","aqua","magenta"],"line_alpha":[1,1,0.8,0.6,0.4,0.2],"line_color":["firebrick","wheat","blue","darkcyan","aqua","magenta"],"size":[4,6,8,12,18,24],"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"c5029110-6058-4ccb-acab-defc5e155e5e","type":"ColumnDataSource"},{"attributes":{},"id":"2359eaa4-262c-4120-b7c7-00e85e6c5c82","type":"ToolEvents"},{"attributes":{"callback":null},"id":"89fcb189-0189-441b-bf51-b8a03427bb5a","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a8e3867c-d17e-45d6-be6d-34f331180769","type":"PanTool"},{"id":"736160ad-628d-4a0e-a852-f041b739345a","type":"WheelZoomTool"},{"id":"525e085c-1b86-4554-a41a-88a5af6e9ed5","type":"BoxZoomTool"},{"id":"1790b785-a838-4631-901a-17a9bd8613da","type":"SaveTool"},{"id":"457b7f5f-dbbe-414a-aba9-250f0d4020ad","type":"ResetTool"},{"id":"a9c54c25-c1c1-4c0b-9e7c-6fbe03e84ed5","type":"HelpTool"}]},"id":"370dced0-7ad2-47af-b096-849729fd32a6","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d6cbf38e-e37e-47e5-bfb7-4a6cfd2f8182","type":"Circle"},{"attributes":{"callback":null},"id":"6668c443-0514-460c-9b35-ad8ec687ce18","type":"DataRange1d"},{"attributes":{"formatter":{"id":"dd976976-92d0-419a-bd69-c9b804c2b100","type":"BasicTickFormatter"},"plot":{"id":"3d8ca1b2-29be-40a8-8b95-495576c024c9","subtype":"Figure","type":"Plot"},"ticker":{"id":"98d58cfa-573c-4512-b24d-c14b3e69d1a8","type":"BasicTicker"}},"id":"d3666e30-4c55-4301-bfcd-2041be8ae0f4","type":"LinearAxis"},{"attributes":{},"id":"98d58cfa-573c-4512-b24d-c14b3e69d1a8","type":"BasicTicker"},{"attributes":{"plot":{"id":"3d8ca1b2-29be-40a8-8b95-495576c024c9","subtype":"Figure","type":"Plot"},"ticker":{"id":"98d58cfa-573c-4512-b24d-c14b3e69d1a8","type":"BasicTicker"}},"id":"27653296-29ad-4b98-b2e1-bb850d46ee49","type":"Grid"},{"attributes":{"formatter":{"id":"66d0ea4a-8f9f-4bdd-8f82-171c65cfd4bb","type":"BasicTickFormatter"},"plot":{"id":"3d8ca1b2-29be-40a8-8b95-495576c024c9","subtype":"Figure","type":"Plot"},"ticker":{"id":"4db326ac-414b-4595-9362-3521a38bdb52" ...

# %% [markdown]
# <img src="../images/multiple.png">

# %% [markdown]
# ## Plotting other glyph shapes

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create the plot
p = figure(plot_width=300, plot_height=300)

# add a line glyph
p.line(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4])

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ef23c990-491f-4e6a-8438-6d80bcfc9ee7">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="78f6496c-eb02-4a13-8f12-c248ad9995fe"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("78f6496c-eb02-4a13-8f12-c248ad9995fe");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("78f6496c-eb02-4a13-8f12-c248ad9995fe");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '78f6496c-eb02-4a13-8f12-c248ad9995fe' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dc080013-e89c-4766-977a-256951b7a7a4":{"roots":{"references":[{"attributes":{"formatter":{"id":"d538aaef-a536-4a38-83e6-a84e30d1d318","type":"BasicTickFormatter"},"plot":{"id":"88ab7016-7373-4ca7-b459-894da7f40c8a","subtype":"Figure","type":"Plot"},"ticker":{"id":"36bd2172-a900-409d-91a7-0d312d45eb7a","type":"BasicTicker"}},"id":"cae23f44-2474-477e-800a-86f154fdebf4","type":"LinearAxis"},{"attributes":{"data_source":{"id":"9fdc7155-342b-4d2f-9204-3d03bf7ba705","type":"ColumnDataSource"},"glyph":{"id":"5ca60ee9-0945-477f-8f4f-aca66f259b8d","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"68789851-84ca-48a7-9d94-4812f7d186c7","type":"Line"},"selection_glyph":null},"id":"d78381cb-dd13-4184-b762-258663c0475f","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"88ab7016-7373-4ca7-b459-894da7f40c8a","subtype":"Figure","type":"Plot"}},"id":"5f71c526-afca-412b-a309-19070656e783","type":"PanTool"},{"attributes":{},"id":"36bd2172-a900-409d-91a7-0d312d45eb7a","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5f9ff09f-8187-43d7-bc7a-2cad5c3c0b3c","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"c17f6ada-f792-41ef-9de3-9bf271de6dfb","type":"LinearAxis"}],"left":[{"id":"cae23f44-2474-477e-800a-86f154fdebf4","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"c17f6ada-f792-41ef-9de3-9bf271de6dfb","type":"LinearAxis"},{"id":"9942a2a4-ebf7-4bb2-bd2d-73329f00f58d","type":"Grid"},{"id":"cae23f44-2474-477e-800a-86f154fdebf4","type":"LinearAxis"},{"id":"6be028e4-7070-460e-bfbc-a74f7ac3f718","type":"Grid"},{"id":"5f9ff09f-8187-43d7-bc7a-2cad5c3c0b3c","type":"BoxAnnotation"},{"id":"d78381cb-dd13-4184-b762-258663c0475f","type":"GlyphRenderer"}],"title":{"id":"33b269eb-6921-4321-85ce-0eebab14a5e3","type":"Title"},"tool_events":{"id":"8bb4d1f2-da91-4420-971d-9fea2c2921d6","type":"ToolEvents"},"toolbar":{"id":"ba9fa4dc-8650-425d-8673-cd67426fe1f8","type":"Toolbar"},"x_range":{"id":"24d8c585-5c85-4e28-b1a7-0a7410d627e7","type":"DataRange1d"},"y_range":{"id":"13f70eb1-27c7-4505-80bf-5b0f85134909","type":"DataRange1d"}},"id":"88ab7016-7373-4ca7-b459-894da7f40c8a","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"24d8c585-5c85-4e28-b1a7-0a7410d627e7","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"88ab7016-7373-4ca7-b459-894da7f40c8a","subtype":"Figure","type":"Plot"},"ticker":{"id":"36bd2172-a900-409d-91a7-0d312d45eb7a","type":"BasicTicker"}},"id":"6be028e4-7070-460e-bfbc-a74f7ac3f718","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"33b269eb-6921-4321-85ce-0eebab14a5e3","type":"Title"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5f71c526-afca-412b-a309-19070656e783","type":"PanTool"},{"id":"b7f65fe4-8c10-41aa-9c03-5ee77b636403","type":"WheelZoomTool"},{"id":"247e8ca3-48fc-489f-a624-6616452d4f3b","type":"BoxZoomTool"},{"id":"172ef4e6-46fb-4e72-9090-36ff278544f1","type":"SaveTool"},{"id":"1265ee16-4e0e-4879-87df-04dc145a26c9","type":"ResetTool"},{"id":"cb78db1c-2ad6-499b-90ec-53d891636f10","type":"HelpTool"}]},"id":"ba9fa4dc-8650-425d-8673-cd67426fe1f8","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"68789851-84ca-48a7-9d94-4812f7d186c7","type":"Line"},{"attributes":{},"id":"d538aaef-a536-4a38-83e6-a84e30d1d318","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"88ab7016-7373-4ca7-b459-894da7f40c8a","subtype":"Figure","type":"Plot"}},"id":"b7f65fe4-8c10-41aa-9c03-5ee77b636403","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"5f9ff09f-8187-43d7-bc7a-2cad5c3c0b3c","type":"BoxAn ...

# %% [markdown]
# <img src="../images/line.png">

# %% [markdown]
# ## Plotting Multiple Line Glyphs
# * Use **`p.line()`** twice to create two line glyphs
# * You can also use **`p.multi_line()`** and pass a list of lists as the x & y coordinates to create multiple lines.

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create the plot
p = figure(plot_width=300, plot_height=300)

# add multiple line glyph
p.line(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4])
p.line(x=[1, 2, 3, 4, 5, 6], y=[1, 1, 1, 1, 4, 6], color='red')

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3a32a709-62a2-4071-85ad-71def3b966a0">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1cfe0e08-8ff0-489f-84a0-cb699eb4ab55"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1cfe0e08-8ff0-489f-84a0-cb699eb4ab55");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1cfe0e08-8ff0-489f-84a0-cb699eb4ab55");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1cfe0e08-8ff0-489f-84a0-cb699eb4ab55' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"beef9c86-3b36-4c84-8172-1ac86b25ca54":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"baae2fab-1f45-43de-a8be-b17d550ce8e2","subtype":"Figure","type":"Plot"},"ticker":{"id":"bf749ca4-cabb-4956-af3a-fef48a7f8a62","type":"BasicTicker"}},"id":"e5efcbe5-2dbf-4f1f-9f04-b0aaff826ab0","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[1,1,1,1,4,6]}},"id":"1d4ec080-d2fc-49ca-9d7b-e18ef38600d0","type":"ColumnDataSource"},{"attributes":{},"id":"bf749ca4-cabb-4956-af3a-fef48a7f8a62","type":"BasicTicker"},{"attributes":{"formatter":{"id":"65aa8aa5-db0f-4ca9-9b0e-5397813ab5f4","type":"BasicTickFormatter"},"plot":{"id":"baae2fab-1f45-43de-a8be-b17d550ce8e2","subtype":"Figure","type":"Plot"},"ticker":{"id":"bf749ca4-cabb-4956-af3a-fef48a7f8a62","type":"BasicTicker"}},"id":"eadd2799-2e6b-4161-853a-53710b99d645","type":"LinearAxis"},{"attributes":{"plot":{"id":"baae2fab-1f45-43de-a8be-b17d550ce8e2","subtype":"Figure","type":"Plot"},"ticker":{"id":"b45ce4a6-8819-4cb9-ad5d-2c5a74eae612","type":"BasicTicker"}},"id":"a548de9d-4a72-4b63-bca0-e91be9eb021f","type":"Grid"},{"attributes":{},"id":"b45ce4a6-8819-4cb9-ad5d-2c5a74eae612","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"5621a884-068e-4b2d-8365-066ffbf490f5","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c09fa78d-0604-458a-b2bc-3161de401583","type":"Line"},{"attributes":{"formatter":{"id":"6bd84828-733a-4191-8f57-f61b1c341c9a","type":"BasicTickFormatter"},"plot":{"id":"baae2fab-1f45-43de-a8be-b17d550ce8e2","subtype":"Figure","type":"Plot"},"ticker":{"id":"b45ce4a6-8819-4cb9-ad5d-2c5a74eae612","type":"BasicTicker"}},"id":"9f4cb522-4d1d-477d-a778-7e4a517bd2db","type":"LinearAxis"},{"attributes":{},"id":"65aa8aa5-db0f-4ca9-9b0e-5397813ab5f4","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"5544b9a5-dbd1-4b45-8edb-0b11e7e3a677","type":"Title"},{"attributes":{"plot":{"id":"baae2fab-1f45-43de-a8be-b17d550ce8e2","subtype":"Figure","type":"Plot"}},"id":"928fbe84-b415-4758-8e33-a871a16ee17f","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"782959e1-941d-4b7a-b83d-cedd9e8c6b4a","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"9d36f69c-ee75-416e-9aa5-8d617f813dce","type":"DataRange1d"},{"attributes":{"overlay":{"id":"782959e1-941d-4b7a-b83d-cedd9e8c6b4a","type":"BoxAnnotation"},"plot":{"id":"baae2fab-1f45-43de-a8be-b17d550ce8e2","subtype":"Figure","type":"Plot"}},"id":"2d993cef-8a76-465d-9836-9c1fa4434416","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"baae2fab-1f45-43de-a8be-b17d550ce8e2","subtype":"Figure","type":"Plot"}},"id":"34e1c63d-c60d-4f46-a754-f40d34ec207b","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"baae2fab-1f45-43de-a8be-b17d550ce8e2","subtype":"Figure","type":"Plot"}},"id":"38f587d6-56a6-4a4c-9fc7-c1ae2774bef9","type":"ResetTool"},{"attributes":{"plot":{"id":"baae2fab-1f45-43de-a8be-b17d550ce8e2","subtype":"Figure","type":"Plot"}},"id":"4f8055ed-ecf7-4285-9c5e-fdcd883c1829","type":"SaveTool"},{"attributes":{"plot":{"id":"baae2fab-1f45-43de-a8be-b17d550ce8e2","subtype":"Figure","type":"Plot"}},"id":"eca74dc3-7a97-4076-91bc-6ac601be322c","type":"HelpTool"},{"attributes":{},"id":"6bd84828-733a-4191-8f57-f61b1c341c9a","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0d91b5b7-0ec4-460a-9074-952c6e5d5345","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{ ...

# %% [markdown]
# <img src="../images/multi-line.png">

# %% [markdown]
# ## Creating Patch Glyphs
# * patches are single polygonal patch shapes created from a sequence of x and y coordinates
# * The patch glyph will automatically connect the first point and the last point.
# * Use **`patches()`** and pass a list of lists to create multiple patch glyphs in one line.

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# create the plot
p = figure(plot_width=300, plot_height=300)

# add multiple line glyph
p.patch(x=[1, 2, 3, 4, 5, 6], y=[2, -1, 8, 5, 3, 4], alpha=0.5)
p.patch(x=[1, 2, 3, 4, 5, 6], y=[1, 1, 1, 1, 4, 6], alpha=0.5, color='red')

# output the plot in the jupyter notebook
output_notebook()

# show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6958acc7-9561-4744-a0ba-2b1497707b92">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ff1d5a9d-44a2-481d-b7d0-3b655ed5a8f0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ff1d5a9d-44a2-481d-b7d0-3b655ed5a8f0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ff1d5a9d-44a2-481d-b7d0-3b655ed5a8f0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ff1d5a9d-44a2-481d-b7d0-3b655ed5a8f0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8ce575f5-5a05-4d1d-a215-1d89538767b6":{"roots":{"references":[{"attributes":{},"id":"0dd16724-f564-415b-9499-84137b3ec9f9","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"442ce221-d2dd-4502-aaf0-5e4c45466c49","type":"Title"},{"attributes":{"plot":{"id":"80649475-87fb-4dff-b38f-2ac5c121a128","subtype":"Figure","type":"Plot"}},"id":"48b6774a-4de6-4d25-938b-4068b4c0d0a6","type":"PanTool"},{"attributes":{},"id":"256c4c95-d94a-4390-a8cc-93b63c1b0936","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"0c8b8287-880c-4824-9cd9-8b806af208e8","type":"BoxAnnotation"},"plot":{"id":"80649475-87fb-4dff-b38f-2ac5c121a128","subtype":"Figure","type":"Plot"}},"id":"4033b188-3977-436f-a5f7-0fee2c2013c0","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0c8b8287-880c-4824-9cd9-8b806af208e8","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"db7c0e92-5cb6-44fc-a064-fedbf03f4ffa","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[1,1,1,1,4,6]}},"id":"38c8cad0-c66e-40a7-b2a1-4f12f75e02c3","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"f0dc4ed8-eec9-47c1-a50d-3377a9617f6d","type":"DataRange1d"},{"attributes":{"plot":{"id":"80649475-87fb-4dff-b38f-2ac5c121a128","subtype":"Figure","type":"Plot"}},"id":"e089d526-031e-4e56-8dc9-38b17eaa5fda","type":"SaveTool"},{"attributes":{"data_source":{"id":"ea376fd3-3c81-45ec-8c8c-c65316694bdb","type":"ColumnDataSource"},"glyph":{"id":"8e70d3bd-12d1-4d7c-aef3-115a7b238789","type":"Patch"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7f253f90-e098-421a-82b5-c0ab14e12bda","type":"Patch"},"selection_glyph":null},"id":"8ce42cb3-5940-4ff2-900b-0058cb8a50bb","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"256c4c95-d94a-4390-a8cc-93b63c1b0936","type":"BasicTickFormatter"},"plot":{"id":"80649475-87fb-4dff-b38f-2ac5c121a128","subtype":"Figure","type":"Plot"},"ticker":{"id":"7a46690e-5f64-4780-8220-1a0ae1dd0fa2","type":"BasicTicker"}},"id":"5281e77c-357c-43d2-aeaf-a8b226fa715a","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7f253f90-e098-421a-82b5-c0ab14e12bda","type":"Patch"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5,6],"y":[2,-1,8,5,3,4]}},"id":"ea376fd3-3c81-45ec-8c8c-c65316694bdb","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"4d1df5ed-dcb7-49f8-909d-8995662a0694","type":"LinearAxis"}],"left":[{"id":"5281e77c-357c-43d2-aeaf-a8b226fa715a","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"4d1df5ed-dcb7-49f8-909d-8995662a0694","type":"LinearAxis"},{"id":"81985f32-d445-4ec8-8b7b-5ee0a2a80724","type":"Grid"},{"id":"5281e77c-357c-43d2-aeaf-a8b226fa715a","type":"LinearAxis"},{"id":"5634b983-38bb-4741-ad4b-8cfce877d1ac","type":"Grid"},{"id":"0c8b8287-880c-4824-9cd9-8b806af208e8","type":"BoxAnnotation"},{"id":"8ce42cb3-5940-4ff2-900b-0058cb8a50bb","type":"GlyphRenderer"},{"id":"768c0819-cdfd-4281-848a-0712aff83c5d","type":"GlyphRenderer"}],"title":{"id":"442ce221-d2dd-4502-aaf0-5e4c45466c49","type":"Title"},"tool_events":{"id":"a9fc244f-083f-4a59-b847-d05fcf941f29","type":"ToolEvents"},"toolbar":{"id":"73d0553f-fd93-4a2b-9adb-f77543303cb3","type":"Toolbar"},"x_range":{"id":"db7c0e92-5cb6-44fc-a064-fedbf03f4ffa","type":"DataRange1d"},"y_range":{"id":"f0dc4ed8-eec9-47c1-a50d-3377a9617f6d","type":"DataRange1d"}},"id":"80649475-87fb-4dff-b38f-2ac5c121a128","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"80649475-87fb-4dff-b38f ...

# %% [markdown]
# <img src="../images/patch.png">
